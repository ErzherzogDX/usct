# %% [markdown]
# # 29_geo_deeponet_v2.ipynb
#
# GeoDeepONet v2 — расширенная capacity версия v1 (`17_geo_deeponet_train_v1`).
#
# ## Что изменилось vs v1
#
# | Параметр | v1 | **v2** |
# |---|---|---|
# | `embed_dim` | 32 | **64** |
# | `branch_hidden` | 64 | **128** |
# | `branch_width` (= trunk_width) | 192 | **384** |
# | `trunk_hidden` | 256 | **512** |
# | `num_fourier_features` | 24 | **32** |
# | total params | ~256K | **~1.2M** (≈5×) |
#
# ## Что НЕ изменилось
#
# Это критично:
#
# - **Source/receiver aggregation: sum затем mean.** Это и есть тот шаг, который
#   даёт **точную** геометрическую инвариантность (1e-7 на v1). Любое изменение
#   её сломает.
# - **Per-token MLP применяется поэлементно**, ни одно из изменений не вводит
#   взаимодействие между токенами до aggregation. Инвариантность сохранится.
# - **Trunk** — та же архитектура, просто шире и глубже по hidden.
# - **Тренировочный протокол** — AdamW + ReduceLROnPlateau, weight_decay=1e-6,
#   dropout=0. v2 GeoUNet/FNO показали, что регуляризация в этой задаче
#   снижает качество — поэтому не добавляем.
#
# ## Зачем расширять именно эти компоненты
#
# В диагностике мы видели, что:
#
# - **DeepONet (vanilla) — самая OOD-устойчивая** модель (test=13.93), и её
#   выразительность лежит в **trunk-базисе** + dot product, а не в branch CNN.
# - **GeoDeepONet v1** при том же дизайне, но per-token MLP branch'е (256K vs
#   5M у DeepONet) дал test=17.08 — отставание 3 м/с при capacity в 20× меньше.
#
# Этот ноутбук пытается это отставание сократить расширением:
#
# 1. **Trunk** — больше базисных функций (`trunk_width 192→384`) и более
#    глубокого hidden (`256→512`). Trunk — главный носитель OOD-обобщения
#    (он не зависит от входа, только от координат пикселей).
# 2. **branch_proj** автоматически расширяется до `branch_width=384`, чтобы
#    формы matmul сошлись.
# 3. **`embed_dim`/`branch_hidden`** — модерация: даём branch'у больше
#    capacity, но без переусердствования (v2 GeoUNet с capacity x17 показал,
#    что просто capacity не помогает).
# 4. **Fourier features 24→32** — позволяет trunk'у выразить более мелкие
#    пространственные структуры в реконструкции.
#
# ## Ожидаемые результаты
#
# - **Геометрическая инвариантность**: остается **0** или ~1e-7 (как в v1).
#   Sanity-тесты должны это подтвердить.
# - **OOD test RMSE**: 14-16 м/с (с 17.08 в v1), приближается к vanilla
#   DeepONet (13.93).
# - **Within-distribution (val)**: 10-12 м/с (с 12.95 в v1).
# - **best_epoch**: 70-100 (v1 тренировалась долго — больше capacity = ещё дольше).

# %% [markdown]
# ## 1. Импорты и конфиг

# %%
import os

os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"
os.environ.pop("LD_LIBRARY_PATH", None)
# Out:
# '/usr/local/cuda/lib64'

# %%
from pathlib import Path
import json
import math
import random
import time

import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Subset

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = False
torch.backends.cudnn.benchmark = True

print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("device name:", torch.cuda.get_device_name(0))
# Out:
# torch: 2.11.0+cu128
# cuda available: True
# device name: NVIDIA GeForce RTX 5090

# %%
CFG = {
    "dataset_root": "/workspace/usct_dataset_v2",
    "run_name": "geo_deeponet_v2",
    "batch_size": 8,
    "epochs": 1000,
    "patience": 35,
    "lr": 1e-3,
    "min_lr": 1e-5,
    "weight_decay": 1e-6,            # unchanged from v1
    "num_workers": 0,
    "mask_half_width": 2,
    "use_residual": True,

    # Branch (geometry-conditioned) — EXPANDED in v2
    "token_dim": 8,
    "branch_hidden": 128,             # v1: 64
    "embed_dim": 64,                  # v1: 32
    "source_aggregation": "sum",
    "receiver_aggregation": "mean",
    "branch_width": 384,              # v1: 192

    # Trunk — EXPANDED in v2
    "trunk_width": 384,               # v1: 192 (must equal branch_width)
    "trunk_hidden": 512,              # v1: 256
    "num_fourier_features": 32,       # v1: 24
    "dropout": 0.0,                   # unchanged

    # LR schedule
    "scheduler_factor": 0.5,
    "scheduler_patience": 8,

    # Optional debug
    "overfit_debug_enabled": True,
    "overfit_subset_size": 8,
    "overfit_epochs": 300,
    "overfit_lr": 1e-3,
}
CFG
# Out:
# {'dataset_root': '/workspace/usct_dataset_v2',
#  'run_name': 'geo_deeponet_v2',
#  'batch_size': 8,
#  'epochs': 1000,
#  'patience': 35,
#  'lr': 0.001,
#  'min_lr': 1e-05,
#  'weight_decay': 1e-06,
#  'num_workers': 0,
#  'mask_half_width': 2,
#  'use_residual': True,
#  'token_dim': 8,
#  'branch_hidden': 128,
#  'embed_dim': 64,
#  'source_aggregation': 'sum',
#  'receiver_aggregation': 'mean',
#  'branch_width': 384,
#  'trunk_width': 384,
#  'trunk_hidden': 512,
#  'num_fourier_features': 32,
#  'dropout': 0.0,
#  'scheduler_factor': 0.5,
#  'scheduler_patience': 8,
#  'overfit_debug_enabled': True,
#  'overfit_subset_size': 8,
#  'overfit_epochs': 300,
#  'overfit_lr': 0.001}

# %% [markdown]
# ## 2. Файлы и статистика по target

# %%
OUT_ROOT = Path(CFG["dataset_root"])
TRAIN_DIR = OUT_ROOT / "train"
VAL_DIR = OUT_ROOT / "val"
TEST_DIR = OUT_ROOT / "test"

assert TRAIN_DIR.exists(), TRAIN_DIR
assert VAL_DIR.exists(), VAL_DIR
assert TEST_DIR.exists(), TEST_DIR

train_files = sorted(TRAIN_DIR.glob("*.npz"))
val_files = sorted(VAL_DIR.glob("*.npz"))
test_files = sorted(TEST_DIR.glob("*.npz"))

print("train:", len(train_files))
print("val:", len(val_files))
print("test:", len(test_files))
assert len(train_files) > 0 and len(val_files) > 0 and len(test_files) > 0

sample0 = np.load(train_files[0])

S, R = sample0["x"].shape[1], sample0["x"].shape[2]
H, W = sample0["c"].shape
dx = tuple(sample0["dx"].astype(np.float32))
freq_hz = float(sample0["freq_hz"][0])

receiver_y = np.array(sample0["receiver_y"].astype(np.int32))
receiver_x = np.array(sample0["receiver_x"].astype(np.int32))
source_ring_idx_full = np.array(sample0["source_ring_idx"].astype(np.int32))

all_c_values = []
for p in train_files:
    c = np.load(p)["c"].astype(np.float32)
    all_c_values.append(c)
all_c_values = np.stack(all_c_values, axis=0)

stats = {"c_min": float(all_c_values.min()), "c_max": float(all_c_values.max())}
print("S, R:", S, R)
print("H, W:", H, W)
print("dx:", dx)
print("freq_hz:", freq_hz)
print("stats:", stats)
# Out:
# train: 6200
# val: 1000
# test: 800
# S, R: 16 256
# H, W: 192 192
# dx: (np.float32(0.00075), np.float32(0.00075))
# freq_hz: 500000.0
# stats: {'c_min': 1404.1473388671875, 'c_max': 1598.34423828125}

# %% [markdown]
# ## 3. `M_hom` через j-Wave
#
# Точная копия блока из всех остальных ноутбуков.

# %%
import jax
import jax.numpy as jnp
from jax import jit

from jwave import FourierSeries
from jwave.geometry import Domain, Medium
from jwave.acoustics.time_harmonic import helmholtz_solver

print("jax version:", jax.__version__)
print("jax devices:", jax.devices())
# Out:
# jax version: 0.4.38
# jax devices: [CudaDevice(id=0)]

# %%
domain = Domain((H, W), dx)
omega = 2 * np.pi * freq_hz

def gaussian_source(H, W, y0, x0, sigma=1.8):
    yy, xx = np.mgrid[0:H, 0:W]
    g = np.exp(-((yy - y0) ** 2 + (xx - x0) ** 2) / (2 * sigma**2))
    g = g / g.sum()
    return g.astype(np.float32)

full_source_fields = []
for ridx in source_ring_idx_full:
    y0 = int(receiver_y[ridx])
    x0 = int(receiver_x[ridx])
    src_np = gaussian_source(H, W, y0, x0, sigma=1.8)
    full_source_fields.append(jnp.array(src_np, dtype=jnp.complex64))
full_source_fields = tuple(full_source_fields)

def make_medium(c_map):
    sound_speed = FourierSeries(jnp.expand_dims(jnp.array(c_map), -1), domain)
    medium = Medium(domain=domain, sound_speed=sound_speed, density=1000.0, pml_size=16)
    return medium

def forward_measurements_full(c_map):
    medium = make_medium(c_map)
    ms = []
    for i in range(len(full_source_fields)):
        src = FourierSeries(jnp.expand_dims(full_source_fields[i], -1), domain)
        field = helmholtz_solver(medium, omega, src * omega)
        u = field.params[..., 0]
        ms.append(u[receiver_y, receiver_x])
    return jnp.stack(ms, axis=0)

forward_measurements_full_jit = jit(forward_measurements_full)
# Out:
# /tmp/ipykernel_1516/1657452440.py:1: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   domain = Domain((H, W), dx)

# %%
c_hom = jnp.full((H, W), 1500.0, dtype=jnp.float32)

t0 = time.time()
M_hom_complex = forward_measurements_full_jit(c_hom)
M_hom_complex.block_until_ready()
t1 = time.time()

M_hom_complex = np.array(M_hom_complex)

print("M_hom_complex:", M_hom_complex.shape, M_hom_complex.dtype)
print("time:", t1 - t0, "sec")
# Out:
# M_hom_complex: (16, 256) complex64
# time: 8.178250789642334 sec

# %% [markdown]
# ## 4. Dataset
#
# `USCTGeoDataset` идентичен тому, что в `14_geo_unet_train_v1`.

# %%
def mask_self_receivers(M, source_ring_idx, half_width=2):
    M = M.copy()
    S_local, R_local = M.shape
    for s in range(S_local):
        ridx = int(source_ring_idx[s])
        for delta in range(-half_width, half_width + 1):
            rr = (ridx + delta) % R_local
            M[s, rr] = 0.0 + 0.0j
    return M

class USCTGeoDataset(Dataset):
    """Returns (x, c, src_norm, rcv_norm, rcv_pixel, meta).

    Same as in 14_geo_unet_train_v1: we read receiver_y/x and source_ring_idx
    that 04_generate_dataset_v2 already saved into every npz, and produce three
    geometry tensors per sample. No dataset regeneration needed.
    """
    def __init__(self, paths, c_min, c_max, M_hom_complex, H, W,
                 use_residual=True, mask_half_width=2):
        self.paths = list(paths)
        self.c_min = float(c_min)
        self.c_max = float(c_max)
        self.c_range = max(self.c_max - self.c_min, 1e-8)
        self.M_hom_complex = M_hom_complex
        self.use_residual = bool(use_residual)
        self.mask_half_width = int(mask_half_width)
        self.H = int(H)
        self.W = int(W)

    def __len__(self):
        return len(self.paths)

    def normalize_target(self, c):
        return 2.0 * (c - self.c_min) / self.c_range - 1.0

    def denormalize_target(self, c_norm):
        return ((c_norm + 1.0) * 0.5) * self.c_range + self.c_min

    def __getitem__(self, idx):
        d = np.load(self.paths[idx])

        x_raw = d["x"].astype(np.float32)
        c_map = d["c"].astype(np.float32)
        source_ring_idx = d["source_ring_idx"].astype(np.int64)
        rcv_y = d["receiver_y"].astype(np.int64)
        rcv_x = d["receiver_x"].astype(np.int64)

        # 1) measurement + residual + self-mask
        M = x_raw[0] + 1j * x_raw[1]
        if self.use_residual:
            M = M - self.M_hom_complex
        if self.mask_half_width > 0:
            M = mask_self_receivers(M, source_ring_idx, half_width=self.mask_half_width)

        x_tensor = np.stack([M.real, M.imag], axis=0).astype(np.float32)
        x_scale = float(np.percentile(np.abs(x_tensor), 99.5))
        if x_scale < 1e-8:
            x_scale = 1.0
        x_tensor = x_tensor / x_scale

        # 2) target
        c_norm = self.normalize_target(c_map).astype(np.float32)

        # 3) geometry
        src_y_pix = rcv_y[source_ring_idx]
        src_x_pix = rcv_x[source_ring_idx]

        rcv_pixel = np.stack([rcv_y, rcv_x], axis=-1).astype(np.int64)

        rcv_norm = np.stack([
            rcv_y.astype(np.float32) / max(self.H - 1, 1) * 2 - 1,
            rcv_x.astype(np.float32) / max(self.W - 1, 1) * 2 - 1,
        ], axis=-1).astype(np.float32)
        src_norm = np.stack([
            src_y_pix.astype(np.float32) / max(self.H - 1, 1) * 2 - 1,
            src_x_pix.astype(np.float32) / max(self.W - 1, 1) * 2 - 1,
        ], axis=-1).astype(np.float32)

        return (
            torch.from_numpy(x_tensor),
            torch.from_numpy(c_norm).unsqueeze(0),
            torch.from_numpy(src_norm),
            torch.from_numpy(rcv_norm),
            torch.from_numpy(rcv_pixel),
            {"path": str(self.paths[idx]), "x_scale": x_scale},
        )

# %%
ds_train = USCTGeoDataset(
    train_files, stats["c_min"], stats["c_max"],
    M_hom_complex=M_hom_complex, H=H, W=W,
    use_residual=CFG["use_residual"],
    mask_half_width=CFG["mask_half_width"],
)
ds_val = USCTGeoDataset(
    val_files, stats["c_min"], stats["c_max"],
    M_hom_complex=M_hom_complex, H=H, W=W,
    use_residual=CFG["use_residual"],
    mask_half_width=CFG["mask_half_width"],
)
ds_test = USCTGeoDataset(
    test_files, stats["c_min"], stats["c_max"],
    M_hom_complex=M_hom_complex, H=H, W=W,
    use_residual=CFG["use_residual"],
    mask_half_width=CFG["mask_half_width"],
)

x0, c0, src0, rcv0, rcvp0, meta0 = ds_train[0]
print("x:        ", x0.shape, x0.dtype)
print("c:        ", c0.shape, c0.dtype, float(c0.min()), float(c0.max()))
print("src_norm: ", src0.shape, src0.dtype, "range:", float(src0.min()), float(src0.max()))
print("rcv_norm: ", rcv0.shape, rcv0.dtype, "range:", float(rcv0.min()), float(rcv0.max()))
print("rcv_pixel:", rcvp0.shape, rcvp0.dtype, "range:", int(rcvp0.min()), int(rcvp0.max()))
print(meta0)
# Out:
# x:         torch.Size([2, 16, 256]) torch.float32
# c:         torch.Size([1, 192, 192]) torch.float32 -0.7392016053199768 0.5010437965393066
# src_norm:  torch.Size([16, 2]) torch.float32 range: -0.7591623067855835 0.7591623067855835
# rcv_norm:  torch.Size([256, 2]) torch.float32 range: -0.7591623067855835 0.7591623067855835
# rcv_pixel: torch.Size([256, 2]) torch.int64 range: 23 168
# {'path': '/workspace/usct_dataset_v2/train/sample_00000.npz', 'x_scale': 5201.529296875}

# %% [markdown]
# ## 5. Модель: GeoDeepONet
#
# ### 5.1 Branch (geometry-conditioned), Trunk и полная модель

# %%
class GeometryConditionedBranch(nn.Module):
    """Per-token MLP: (Re, Im, src_xy, rcv_xy, ray_xy) -> embed_dim.

    Identical to the one in 14_geo_unet_train_v1.
    """
    def __init__(self, token_dim=8, hidden_dim=64, embed_dim=32):
        super().__init__()
        self.embed_dim = int(embed_dim)
        self.mlp = nn.Sequential(
            nn.Linear(token_dim, hidden_dim),
            nn.GELU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.GELU(),
            nn.Linear(hidden_dim, embed_dim),
        )

    def forward(self, x_residual, src_norm, rcv_norm):
        B, _, S, R = x_residual.shape
        src = src_norm.unsqueeze(2).expand(B, S, R, 2)
        rcv = rcv_norm.unsqueeze(1).expand(B, S, R, 2)
        ray = rcv - src
        meas = x_residual.permute(0, 2, 3, 1).contiguous()
        tokens = torch.cat([meas, src, rcv, ray], dim=-1)
        return self.mlp(tokens)


class TrunkNetV2(nn.Module):
    """Identical to 12_deeponet_train_v2."""
    def __init__(self, width=192, hidden=256, num_fourier_features=24, dropout=0.0):
        super().__init__()
        self.num_fourier_features = int(num_fourier_features)

        if self.num_fourier_features > 0:
            freq = 2.0 ** torch.arange(self.num_fourier_features, dtype=torch.float32) * math.pi
            self.register_buffer("freq", freq, persistent=False)
            in_dim = 2 + 4 * self.num_fourier_features
        else:
            self.register_buffer("freq", torch.empty(0), persistent=False)
            in_dim = 2

        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden, hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden, hidden),
            nn.GELU(),
            nn.Linear(hidden, width),
        )

    def encode_coords(self, coords):
        if self.num_fourier_features == 0:
            return coords
        y = coords[:, 0:1]
        x = coords[:, 1:2]
        y_proj = y * self.freq[None, :]
        x_proj = x * self.freq[None, :]
        feats = [coords, torch.sin(y_proj), torch.cos(y_proj),
                 torch.sin(x_proj), torch.cos(x_proj)]
        return torch.cat(feats, dim=1)

    def forward(self, coords):
        return self.net(self.encode_coords(coords))


class GeoDeepONet2D(nn.Module):
    """DeepONet with permutation-invariant geometry-conditioned branch."""

    def __init__(self,
                 token_dim=8, branch_hidden=64, embed_dim=32,
                 branch_width=192, trunk_width=192, trunk_hidden=256,
                 num_fourier_features=24, dropout=0.0,
                 source_aggregation="sum", receiver_aggregation="mean",
                 H=192, W=192):
        super().__init__()
        assert source_aggregation in ("sum", "mean")
        assert receiver_aggregation in ("sum", "mean")
        assert branch_width == trunk_width, "branch_width must equal trunk_width"
        self.width = int(branch_width)
        self.H = int(H)
        self.W = int(W)
        self.source_agg = source_aggregation
        self.receiver_agg = receiver_aggregation

        self.branch_tokenizer = GeometryConditionedBranch(
            token_dim=token_dim, hidden_dim=branch_hidden, embed_dim=embed_dim,
        )
        # Project the pooled embedding (embed_dim) up to branch_width.
        self.branch_proj = nn.Sequential(
            nn.Linear(embed_dim, branch_width),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(branch_width, branch_width),
        )

        self.trunk = TrunkNetV2(
            width=trunk_width, hidden=trunk_hidden,
            num_fourier_features=num_fourier_features, dropout=dropout,
        )

        self.bias = nn.Parameter(torch.zeros(1))

    def encode_branch(self, x_residual, src_norm, rcv_norm):
        emb = self.branch_tokenizer(x_residual, src_norm, rcv_norm)   # (B, S, R, C)

        if self.source_agg == "sum":
            agg = emb.sum(dim=1)
        else:
            agg = emb.mean(dim=1)
        # agg: (B, R, C)

        if self.receiver_agg == "sum":
            agg = agg.sum(dim=1)
        else:
            agg = agg.mean(dim=1)
        # agg: (B, C)

        return self.branch_proj(agg)                                   # (B, branch_width)

    def forward(self, x_residual, src_norm, rcv_norm, coords):
        b = self.encode_branch(x_residual, src_norm, rcv_norm)         # (B, W)
        t = self.trunk(coords)                                         # (H*W, W)
        out = torch.matmul(b, t.t()) / math.sqrt(self.width) + self.bias
        return out.view(b.shape[0], 1, self.H, self.W)

# %% [markdown]
# ### 5.2 Координатная сетка для trunk
#
# То же самое, что в `12_deeponet_train_v2`: один раз заранее считаем `(H*W, 2)` тензор, потом передаём в каждый вызов модели.

# %%
# Pixel-grid coords for the trunk (same convention as 12_deeponet_train_v2).
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

yy = torch.linspace(-1.0, 1.0, H)
xx = torch.linspace(-1.0, 1.0, W)
gy, gx = torch.meshgrid(yy, xx, indexing="ij")
coords_full = torch.stack([gy.reshape(-1), gx.reshape(-1)], dim=1)
coords_device = coords_full.to(device)

print("coords_device:", coords_device.shape, coords_device.dtype, coords_device.device)
# Out:
# coords_device: torch.Size([36864, 2]) torch.float32 cuda:0

# %% [markdown]
# ### 5.3 Sanity: число параметров и форма выхода

# %%
_test_model = GeoDeepONet2D(
    token_dim=CFG["token_dim"],
    branch_hidden=CFG["branch_hidden"],
    embed_dim=CFG["embed_dim"],
    branch_width=CFG["branch_width"],
    trunk_width=CFG["trunk_width"],
    trunk_hidden=CFG["trunk_hidden"],
    num_fourier_features=CFG["num_fourier_features"],
    dropout=CFG["dropout"],
    source_aggregation=CFG["source_aggregation"],
    receiver_aggregation=CFG["receiver_aggregation"],
    H=H, W=W,
).to(device)

n_params = sum(p.numel() for p in _test_model.parameters())
n_branch_tok = sum(p.numel() for p in _test_model.branch_tokenizer.parameters())
n_branch_proj = sum(p.numel() for p in _test_model.branch_proj.parameters())
n_trunk = sum(p.numel() for p in _test_model.trunk.parameters())

print(f"Total            : {n_params:,}")
print(f"  branch_tokenizer: {n_branch_tok:,}    (v1: ~7K)")
print(f"  branch_proj     : {n_branch_proj:,}    (v1: ~43K)")
print(f"  trunk           : {n_trunk:,}    (v1: ~206K)")
print(f"\n  v2/v1 capacity ratio: ~{n_params / 256_000:.1f}x")

with torch.no_grad():
    _x  = torch.randn(2, 2, S, R, device=device)
    _sn = torch.randn(2, S, 2, device=device)
    _rn = torch.randn(2, R, 2, device=device)
    _y  = _test_model(_x, _sn, _rn, coords_device)
    print("\ninput shape: ", tuple(_x.shape))
    print("output shape:", tuple(_y.shape))
    assert _y.shape == (2, 1, H, W)

del _test_model, _x, _sn, _rn, _y
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# Total            : 988,097
#   branch_tokenizer: 25,920    (v1: ~7K)
#   branch_proj     : 172,800    (v1: ~43K)
#   trunk           : 789,376    (v1: ~206K)
#
#   v2/v1 capacity ratio: ~3.9x
#
# input shape:  (2, 2, 16, 256)
# output shape: (2, 1, 192, 192)

# %% [markdown]
# ### 5.4 Тест геометрической инвариантности
#
# Проверяем перестановку и по приёмникам, и по источникам — для DeepONet это
# особенно важно, потому что branch-вектор должен быть инвариантен к обоим.
# Ожидаем разницы порядка `0` или `1e-6..1e-7` (численный шум float32).

# %%
@torch.no_grad()
def geom_invariance_test(model, ds, device, coords_device,
                         perm_axis="receiver", perm_kind="shift", k=4, idx=0):
    """
    Permutation invariance test along source or receiver axis.

    perm_axis: "receiver" (R) or "source" (S)
    perm_kind: "shift" (circular shift by k) or "random"
    """
    x, c, src_n, rcv_n, rcv_p, _ = ds[idx]
    x      = x.unsqueeze(0).to(device)
    src_n  = src_n.unsqueeze(0).to(device)
    rcv_n  = rcv_n.unsqueeze(0).to(device)

    if perm_axis == "receiver":
        N = x.shape[-1]
    elif perm_axis == "source":
        N = x.shape[-2]
    else:
        raise ValueError(perm_axis)

    if perm_kind == "shift":
        perm = torch.tensor([(n + k) % N for n in range(N)], device=device, dtype=torch.long)
    elif perm_kind == "random":
        perm = torch.randperm(N, device=device)
    else:
        raise ValueError(perm_kind)

    if perm_axis == "receiver":
        x_p, sn_p, rn_p = x[..., perm], src_n, rcv_n[:, perm, :]
    else:
        x_p, sn_p, rn_p = x[..., perm, :], src_n[:, perm, :], rcv_n

    model.eval()
    y0 = model(x,   src_n, rcv_n, coords_device).cpu().numpy()
    y1 = model(x_p, sn_p,  rn_p,  coords_device).cpu().numpy()
    abs_diff = float(np.max(np.abs(y0 - y1)))
    rel_diff = abs_diff / (float(np.max(np.abs(y0))) + 1e-8)
    print(f"[geom inv / {perm_axis} / {perm_kind}, k={k}]  max |y0 - y1| = {abs_diff:.3e}, rel = {rel_diff:.3e}")
    return abs_diff, rel_diff


_test_model = GeoDeepONet2D(
    token_dim=CFG["token_dim"], branch_hidden=CFG["branch_hidden"],
    embed_dim=CFG["embed_dim"], branch_width=CFG["branch_width"],
    trunk_width=CFG["trunk_width"], trunk_hidden=CFG["trunk_hidden"],
    num_fourier_features=CFG["num_fourier_features"], dropout=CFG["dropout"],
    source_aggregation=CFG["source_aggregation"],
    receiver_aggregation=CFG["receiver_aggregation"],
    H=H, W=W,
).to(device)

# v2 keeps the same aggregation strategy as v1 (sum over S, then mean over R),
# applied AFTER per-token MLP. Per-token MLP is symmetric under any permutation
# of tokens. Pooling is symmetric. So permutation invariance for both sources
# and receivers is PRESERVED EXACTLY (down to float32 numerical noise ~1e-7).
print("On UNTRAINED model:")
print("  All five tests should give max |y0 - y1| ~ 1e-6..1e-7:")
geom_invariance_test(_test_model, ds_train, device, coords_device, perm_axis="receiver", perm_kind="shift", k=4)
geom_invariance_test(_test_model, ds_train, device, coords_device, perm_axis="receiver", perm_kind="shift", k=37)
geom_invariance_test(_test_model, ds_train, device, coords_device, perm_axis="receiver", perm_kind="random")
geom_invariance_test(_test_model, ds_train, device, coords_device, perm_axis="source",   perm_kind="shift", k=3)
geom_invariance_test(_test_model, ds_train, device, coords_device, perm_axis="source",   perm_kind="random")

del _test_model
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# On UNTRAINED model:
#   All five tests should give max |y0 - y1| ~ 1e-6..1e-7:
# [geom inv / receiver / shift, k=4]  max |y0 - y1| = 4.657e-09, rel = 3.298e-07
# [geom inv / receiver / shift, k=37]  max |y0 - y1| = 4.657e-09, rel = 3.298e-07
# [geom inv / receiver / random, k=4]  max |y0 - y1| = 5.588e-09, rel = 3.958e-07
# [geom inv / source / shift, k=3]  max |y0 - y1| = 4.657e-09, rel = 3.298e-07
# [geom inv / source / random, k=4]  max |y0 - y1| = 5.588e-09, rel = 3.958e-07

# %% [markdown]
# ## 6. Метрики и тренировочные хелперы

# %%
def denorm_c_from_minus1_1(c_norm, c_min, c_max):
    return ((c_norm + 1.0) * 0.5) * (c_max - c_min) + c_min

def mse(a, b):  return float(np.mean((a - b) ** 2))
def rmse(a, b): return float(np.sqrt(np.mean((a - b) ** 2)))
def relative_l2(a, b):
    return float(np.linalg.norm(a - b) / (np.linalg.norm(b) + 1e-8))
def psnr_from_mse(mse_value, data_range):
    if mse_value <= 1e-12:
        return float("inf")
    return float(20 * np.log10(data_range) - 10 * np.log10(mse_value))

try:
    from skimage.metrics import structural_similarity as ssim_fn
    HAS_SKIMAGE = True
except Exception:
    HAS_SKIMAGE = False
    ssim_fn = None

def compute_metrics(pred, target, data_range):
    out = {
        "mse": mse(pred, target),
        "rmse": rmse(pred, target),
        "relative_l2": relative_l2(pred, target),
        "psnr": psnr_from_mse(mse(pred, target), data_range),
    }
    if HAS_SKIMAGE:
        out["ssim"] = float(ssim_fn(pred, target, data_range=data_range))
    return out

def _move_batch(batch, device):
    x, c, src_n, rcv_n, rcv_p, _ = batch
    return (
        x.to(device, non_blocking=True),
        c.to(device, non_blocking=True),
        src_n.to(device, non_blocking=True),
        rcv_n.to(device, non_blocking=True),
        rcv_p.to(device, non_blocking=True),
    )

def train_one_epoch(model, loader, optimizer, criterion, device, scaler=None):
    model.train()
    total_loss = 0.0
    for batch in loader:
        x, c, src_n, rcv_n, rcv_p = _move_batch(batch, device)
        optimizer.zero_grad(set_to_none=True)
        if scaler is None:
            pred = model(x, src_n, rcv_n, coords_device)
            loss = criterion(pred, c)
            loss.backward()
            optimizer.step()
        else:
            with torch.autocast(device_type="cuda", dtype=torch.float16):
                pred = model(x, src_n, rcv_n, coords_device)
                loss = criterion(pred, c)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
        total_loss += float(loss.item()) * x.shape[0]
    return total_loss / len(loader.dataset)

@torch.no_grad()
def eval_loss(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    for batch in loader:
        x, c, src_n, rcv_n, rcv_p = _move_batch(batch, device)
        pred = model(x, src_n, rcv_n, coords_device)
        loss = criterion(pred, c)
        total_loss += float(loss.item()) * x.shape[0]
    return total_loss / len(loader.dataset)

@torch.no_grad()
def evaluate_dataset(model, dataset, device, c_min, c_max):
    model.eval()
    metrics_list = []
    data_range = float(c_max - c_min)
    for idx in range(len(dataset)):
        x, c, src_n, rcv_n, rcv_p, meta = dataset[idx]
        x      = x.unsqueeze(0).to(device)
        src_n  = src_n.unsqueeze(0).to(device)
        rcv_n  = rcv_n.unsqueeze(0).to(device)
        rcv_p  = rcv_p.unsqueeze(0).to(device)
        pred = model(x, src_n, rcv_n, coords_device)[0, 0].cpu().numpy()
        pred = np.clip(pred, -1.0, 1.0)
        target = c[0].numpy()
        pred_phys = denorm_c_from_minus1_1(pred, c_min, c_max)
        target_phys = denorm_c_from_minus1_1(target, c_min, c_max)
        m = compute_metrics(pred_phys, target_phys, data_range=data_range)
        m["index"] = idx
        m["path"] = meta["path"]
        metrics_list.append(m)
    return metrics_list

def summarize_metrics(metrics_list):
    summary = {}
    for key in metrics_list[0].keys():
        if key in ("index", "path"):
            continue
        vals = [m[key] for m in metrics_list]
        summary[f"{key}_mean"] = float(np.mean(vals))
        summary[f"{key}_std"] = float(np.std(vals))
    return summary

# %% [markdown]
# ## 7. DataLoaders

# %%
train_loader = DataLoader(
    ds_train, batch_size=CFG["batch_size"], shuffle=True,
    num_workers=CFG["num_workers"], pin_memory=torch.cuda.is_available(),
)
val_loader = DataLoader(
    ds_val, batch_size=CFG["batch_size"], shuffle=False,
    num_workers=CFG["num_workers"], pin_memory=torch.cuda.is_available(),
)
print("num train batches:", len(train_loader))
print("num val batches:  ", len(val_loader))
# Out:
# num train batches: 775
# num val batches:   125

# %% [markdown]
# ## 8. Overfit sanity check

# %%
if CFG["overfit_debug_enabled"]:
    overfit_subset = Subset(ds_train, list(range(CFG["overfit_subset_size"])))
    overfit_loader = DataLoader(
        overfit_subset,
        batch_size=min(CFG["batch_size"], CFG["overfit_subset_size"]),
        shuffle=True, num_workers=0,
        pin_memory=torch.cuda.is_available(),
    )

    overfit_model = GeoDeepONet2D(token_dim=CFG['token_dim'], branch_hidden=CFG['branch_hidden'], embed_dim=CFG['embed_dim'], branch_width=CFG['branch_width'], trunk_width=CFG['trunk_width'], trunk_hidden=CFG['trunk_hidden'], num_fourier_features=CFG['num_fourier_features'], dropout=CFG['dropout'], source_aggregation=CFG['source_aggregation'], receiver_aggregation=CFG['receiver_aggregation'], H=H, W=W).to(device)
    overfit_optimizer = torch.optim.AdamW(
        overfit_model.parameters(), lr=CFG["overfit_lr"], weight_decay=0.0,
    )
    overfit_criterion = nn.MSELoss()
    overfit_scaler = torch.amp.GradScaler("cuda") if torch.cuda.is_available() else None

    overfit_history = []
    for epoch in range(1, CFG["overfit_epochs"] + 1):
        loss = train_one_epoch(
            overfit_model, overfit_loader, overfit_optimizer,
            overfit_criterion, device, scaler=overfit_scaler,
        )
        overfit_history.append(loss)
        if epoch == 1 or epoch % 20 == 0 or epoch == CFG["overfit_epochs"]:
            print(f"[overfit] epoch {epoch:03d} | loss={loss:.6f}")

    plt.figure(figsize=(7, 4))
    plt.plot(overfit_history)
    plt.xlabel("epoch"); plt.ylabel("loss"); plt.yscale("log")
    plt.title("Overfit sanity check")
    plt.show()

    del overfit_model, overfit_optimizer, overfit_scaler
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
else:
    print("overfit debug block is disabled")
# Out:
# [overfit] epoch 001 | loss=0.110371
# [overfit] epoch 020 | loss=0.059048
# [overfit] epoch 040 | loss=0.050741
# [overfit] epoch 060 | loss=0.048060
# [overfit] epoch 080 | loss=0.045990
# [overfit] epoch 100 | loss=0.045222
# [overfit] epoch 120 | loss=0.046033
# [overfit] epoch 140 | loss=0.044855
# [overfit] epoch 160 | loss=0.044429
# [overfit] epoch 180 | loss=0.044144
# [overfit] epoch 200 | loss=0.043792
# [overfit] epoch 220 | loss=0.043454
# [overfit] epoch 240 | loss=0.044320
# [overfit] epoch 260 | loss=0.043269
# [overfit] epoch 280 | loss=0.043009
# [overfit] epoch 300 | loss=0.042829

# %% [markdown]
# ## 9. Полное обучение

# %%
model = GeoDeepONet2D(token_dim=CFG['token_dim'], branch_hidden=CFG['branch_hidden'], embed_dim=CFG['embed_dim'], branch_width=CFG['branch_width'], trunk_width=CFG['trunk_width'], trunk_hidden=CFG['trunk_hidden'], num_fourier_features=CFG['num_fourier_features'], dropout=CFG['dropout'], source_aggregation=CFG['source_aggregation'], receiver_aggregation=CFG['receiver_aggregation'], H=H, W=W).to(device)

print(f"GeoDeepONet params: {sum(p.numel() for p in model.parameters()):,}")

optimizer = torch.optim.AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"])
criterion = nn.MSELoss()
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="min",
    factor=CFG["scheduler_factor"], patience=CFG["scheduler_patience"],
    min_lr=CFG["min_lr"],
)

use_amp = torch.cuda.is_available()
scaler = torch.amp.GradScaler("cuda") if use_amp else None

RUN_DIR = Path("/workspace/reference_points") / CFG["run_name"]
RUN_DIR.mkdir(parents=True, exist_ok=True)

best_val = float("inf")
best_epoch = -1
best_ckpt_path = RUN_DIR / "geo_deeponet_v2_best.pt"

train_history = []
val_history = []
lr_history = []
epochs_no_improve = 0

t0 = time.time()
for epoch in range(1, CFG["epochs"] + 1):
    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device, scaler=scaler)
    val_loss = eval_loss(model, val_loader, criterion, device)
    scheduler.step(val_loss)

    current_lr = optimizer.param_groups[0]["lr"]
    train_history.append(train_loss)
    val_history.append(val_loss)
    lr_history.append(current_lr)

    print(f"epoch {epoch:03d} | train_loss={train_loss:.6f} | val_loss={val_loss:.6f} | lr={current_lr:.6e}")

    if val_loss < best_val:
        best_val = val_loss
        best_epoch = epoch
        epochs_no_improve = 0
        torch.save(
            {
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "stats": stats,
                "config": CFG,
                "best_epoch": best_epoch,
                "best_val": best_val,
            },
            best_ckpt_path,
        )
    else:
        epochs_no_improve += 1

    if epochs_no_improve >= CFG["patience"]:
        print("early stopping")
        break
t1 = time.time()
print("training time sec:", t1 - t0)
print("best_epoch:", best_epoch)
print("best_val:", best_val)
# Out:
# GeoDeepONet params: 988,097
# epoch 001 | train_loss=0.043330 | val_loss=0.041995 | lr=1.000000e-03
# epoch 002 | train_loss=0.041264 | val_loss=0.042756 | lr=1.000000e-03
# epoch 003 | train_loss=0.040197 | val_loss=0.041792 | lr=1.000000e-03
# epoch 004 | train_loss=0.039174 | val_loss=0.037336 | lr=1.000000e-03
# epoch 005 | train_loss=0.036657 | val_loss=0.036787 | lr=1.000000e-03
# epoch 006 | train_loss=0.035464 | val_loss=0.033493 | lr=1.000000e-03
# epoch 007 | train_loss=0.034092 | val_loss=0.033969 | lr=1.000000e-03
# epoch 008 | train_loss=0.033213 | val_loss=0.032000 | lr=1.000000e-03
# epoch 009 | train_loss=0.032794 | val_loss=0.032966 | lr=1.000000e-03
# epoch 010 | train_loss=0.032268 | val_loss=0.031926 | lr=1.000000e-03
# epoch 011 | train_loss=0.032688 | val_loss=0.030723 | lr=1.000000e-03
# epoch 012 | train_loss=0.031493 | val_loss=0.032973 | lr=1.000000e-03
# epoch 013 | train_loss=0.030882 | val_loss=0.032176 | lr=1.000000e-03
# epoch 014 | train_loss=0.030690 | val_loss=0.030763 | lr=1.000000e-03
# epoch 015 | train_loss=0.029491 | val_loss=0.028851 | lr=1.000000e-03
# epoch 016 | train_loss=0.028837 | val_loss=0.028617 | lr=1.000000e-03
# epoch 017 | train_loss=0.028694 | val_loss=0.027105 | lr=1.000000e-03
# epoch 018 | train_loss=0.028916 | val_loss=0.027585 | lr=1.000000e-03
# epoch 019 | train_loss=0.027247 | val_loss=0.028366 | lr=1.000000e-03
# epoch 020 | train_loss=0.027112 | val_loss=0.026561 | lr=1.000000e-03
# epoch 021 | train_loss=0.026751 | val_loss=0.026014 | lr=1.000000e-03
# epoch 022 | train_loss=0.026680 | val_loss=0.026648 | lr=1.000000e-03
# epoch 023 | train_loss=0.026090 | val_loss=0.026327 | lr=1.000000e-03
# epoch 024 | train_loss=0.025864 | val_loss=0.026031 | lr=1.000000e-03
# epoch 025 | train_loss=0.025787 | val_loss=0.026682 | lr=1.000000e-03
# epoch 026 | train_loss=0.025357 | val_loss=0.024893 | lr=1.000000e-03
# epoch 027 | train_loss=0.025079 | val_loss=0.024691 | lr=1.000000e-03
# epoch 028 | train_loss=0.024790 | val_loss=0.024987 | lr=1.000000e-03
# epoch 029 | train_loss=0.024548 | val_loss=0.024663 | lr=1.000000e-03
# epoch 030 | train_loss=0.024462 | val_loss=0.024437 | lr=1.000000e-03
# epoch 031 | train_loss=0.025187 | val_loss=0.024288 | lr=1.000000e-03
# epoch 032 | train_loss=0.023815 | val_loss=0.023848 | lr=1.000000e-03
# epoch 033 | train_loss=0.023862 | val_loss=0.023841 | lr=1.000000e-03
# epoch 034 | train_loss=0.023709 | val_loss=0.024846 | lr=1.000000e-03
# epoch 035 | train_loss=0.023590 | val_loss=0.023340 | lr=1.000000e-03
# epoch 036 | train_loss=0.023439 | val_loss=0.023471 | lr=1.000000e-03
# epoch 037 | train_loss=0.023140 | val_loss=0.023060 | lr=1.000000e-03
# epoch 038 | train_loss=0.023173 | val_loss=0.023217 | lr=1.000000e-03
# epoch 039 | train_loss=0.023099 | val_loss=0.023447 | lr=1.000000e-03
# epoch 040 | train_loss=0.022967 | val_loss=0.023011 | lr=1.000000e-03
# epoch 041 | train_loss=0.022675 | val_loss=0.022499 | lr=1.000000e-03
# epoch 042 | train_loss=0.022619 | val_loss=0.023215 | lr=1.000000e-03
# epoch 043 | train_loss=0.022782 | val_loss=0.022628 | lr=1.000000e-03
# epoch 044 | train_loss=0.022352 | val_loss=0.022443 | lr=1.000000e-03
# epoch 045 | train_loss=0.022511 | val_loss=0.022748 | lr=1.000000e-03
# epoch 046 | train_loss=0.022297 | val_loss=0.022543 | lr=1.000000e-03
# epoch 047 | train_loss=0.022331 | val_loss=0.022711 | lr=1.000000e-03
# epoch 048 | train_loss=0.022065 | val_loss=0.022798 | lr=1.000000e-03
# epoch 049 | train_loss=0.021924 | val_loss=0.022267 | lr=1.000000e-03
# epoch 050 | train_loss=0.022142 | val_loss=0.022219 | lr=1.000000e-03
# epoch 051 | train_loss=0.022090 | val_loss=0.022121 | lr=1.000000e-03
# epoch 052 | train_loss=0.021762 | val_loss=0.022596 | lr=1.000000e-03
# epoch 053 | train_loss=0.021672 | val_loss=0.022036 | lr=1.000000e-03
# epoch 054 | train_loss=0.022124 | val_loss=0.022796 | lr=1.000000e-03
# epoch 055 | train_loss=0.021493 | val_loss=0.022276 | lr=1.000000e-03
# epoch 056 | train_loss=0.021567 | val_loss=0.022164 | lr=1.000000e-03
# epoch 057 | train_loss=0.021547 | val_loss=0.021943 | lr=1.000000e-03
# epoch 058 | train_loss=0.021420 | val_loss=0.021662 | lr=1.000000e-03
# epoch 059 | train_loss=0.021356 | val_loss=0.021697 | lr=1.000000e-03
# epoch 060 | train_loss=0.021326 | val_loss=0.021947 | lr=1.000000e-03
# epoch 061 | train_loss=0.021283 | val_loss=0.021659 | lr=1.000000e-03
# epoch 062 | train_loss=0.021702 | val_loss=0.021491 | lr=1.000000e-03
# epoch 063 | train_loss=0.021156 | val_loss=0.021894 | lr=1.000000e-03
# epoch 064 | train_loss=0.021024 | val_loss=0.021540 | lr=1.000000e-03
# epoch 065 | train_loss=0.021162 | val_loss=0.021350 | lr=1.000000e-03
# epoch 066 | train_loss=0.020953 | val_loss=0.021369 | lr=1.000000e-03
# epoch 067 | train_loss=0.021007 | val_loss=0.021642 | lr=1.000000e-03
# epoch 068 | train_loss=0.020841 | val_loss=0.021119 | lr=1.000000e-03
# epoch 069 | train_loss=0.021100 | val_loss=0.021588 | lr=1.000000e-03
# epoch 070 | train_loss=0.020791 | val_loss=0.021187 | lr=1.000000e-03
# epoch 071 | train_loss=0.020803 | val_loss=0.021146 | lr=1.000000e-03
# epoch 072 | train_loss=0.020745 | val_loss=0.021222 | lr=1.000000e-03
# epoch 073 | train_loss=0.020770 | val_loss=0.021589 | lr=1.000000e-03
# epoch 074 | train_loss=0.020645 | val_loss=0.021249 | lr=1.000000e-03
# epoch 075 | train_loss=0.020703 | val_loss=0.021187 | lr=1.000000e-03
# epoch 076 | train_loss=0.020518 | val_loss=0.021038 | lr=1.000000e-03
# epoch 077 | train_loss=0.020624 | val_loss=0.020910 | lr=1.000000e-03
# epoch 078 | train_loss=0.020501 | val_loss=0.020879 | lr=1.000000e-03
# epoch 079 | train_loss=0.020513 | val_loss=0.021064 | lr=1.000000e-03
# epoch 080 | train_loss=0.020354 | val_loss=0.021084 | lr=1.000000e-03
# epoch 081 | train_loss=0.020447 | val_loss=0.021048 | lr=1.000000e-03
# epoch 082 | train_loss=0.020392 | val_loss=0.021124 | lr=1.000000e-03
# epoch 083 | train_loss=0.020298 | val_loss=0.020795 | lr=1.000000e-03
# epoch 084 | train_loss=0.020235 | val_loss=0.020676 | lr=1.000000e-03
# epoch 085 | train_loss=0.020336 | val_loss=0.021337 | lr=1.000000e-03
# epoch 086 | train_loss=0.020182 | val_loss=0.020783 | lr=1.000000e-03
# epoch 087 | train_loss=0.020165 | val_loss=0.021019 | lr=1.000000e-03
# epoch 088 | train_loss=0.020073 | val_loss=0.020559 | lr=1.000000e-03
# epoch 089 | train_loss=0.020195 | val_loss=0.021103 | lr=1.000000e-03
# epoch 090 | train_loss=0.020022 | val_loss=0.020443 | lr=1.000000e-03
# epoch 091 | train_loss=0.020092 | val_loss=0.020589 | lr=1.000000e-03
# epoch 092 | train_loss=0.019927 | val_loss=0.020684 | lr=1.000000e-03
# epoch 093 | train_loss=0.019908 | val_loss=0.020673 | lr=1.000000e-03
# epoch 094 | train_loss=0.019951 | val_loss=0.020805 | lr=1.000000e-03
# epoch 095 | train_loss=0.019895 | val_loss=0.020958 | lr=1.000000e-03
# epoch 096 | train_loss=0.019860 | val_loss=0.020487 | lr=1.000000e-03
# epoch 097 | train_loss=0.019761 | val_loss=0.020567 | lr=1.000000e-03
# epoch 098 | train_loss=0.019852 | val_loss=0.020493 | lr=1.000000e-03
# epoch 099 | train_loss=0.019697 | val_loss=0.020487 | lr=5.000000e-04
# epoch 100 | train_loss=0.018877 | val_loss=0.019700 | lr=5.000000e-04
# epoch 101 | train_loss=0.018812 | val_loss=0.019629 | lr=5.000000e-04
# epoch 102 | train_loss=0.018763 | val_loss=0.019639 | lr=5.000000e-04
# epoch 103 | train_loss=0.018737 | val_loss=0.019672 | lr=5.000000e-04
# epoch 104 | train_loss=0.018699 | val_loss=0.019509 | lr=5.000000e-04
# epoch 105 | train_loss=0.018673 | val_loss=0.019603 | lr=5.000000e-04
# epoch 106 | train_loss=0.018639 | val_loss=0.019454 | lr=5.000000e-04
# epoch 107 | train_loss=0.018629 | val_loss=0.019583 | lr=5.000000e-04
# epoch 108 | train_loss=0.018596 | val_loss=0.019428 | lr=5.000000e-04
# epoch 109 | train_loss=0.018577 | val_loss=0.019543 | lr=5.000000e-04
# epoch 110 | train_loss=0.018550 | val_loss=0.019423 | lr=5.000000e-04
# epoch 111 | train_loss=0.018510 | val_loss=0.019435 | lr=5.000000e-04
# epoch 112 | train_loss=0.018490 | val_loss=0.019365 | lr=5.000000e-04
# epoch 113 | train_loss=0.018485 | val_loss=0.019306 | lr=5.000000e-04
# epoch 114 | train_loss=0.018461 | val_loss=0.019326 | lr=5.000000e-04
# epoch 115 | train_loss=0.018441 | val_loss=0.019520 | lr=5.000000e-04
# epoch 116 | train_loss=0.018401 | val_loss=0.019278 | lr=5.000000e-04
# epoch 117 | train_loss=0.018389 | val_loss=0.019174 | lr=5.000000e-04
# epoch 118 | train_loss=0.018353 | val_loss=0.019357 | lr=5.000000e-04
# epoch 119 | train_loss=0.018336 | val_loss=0.019461 | lr=5.000000e-04
# epoch 120 | train_loss=0.018325 | val_loss=0.019160 | lr=5.000000e-04
# epoch 121 | train_loss=0.018281 | val_loss=0.019203 | lr=5.000000e-04
# epoch 122 | train_loss=0.018274 | val_loss=0.019269 | lr=5.000000e-04
# epoch 123 | train_loss=0.018254 | val_loss=0.019193 | lr=5.000000e-04
# epoch 124 | train_loss=0.018241 | val_loss=0.019186 | lr=5.000000e-04
# epoch 125 | train_loss=0.018211 | val_loss=0.019166 | lr=5.000000e-04
# epoch 126 | train_loss=0.018199 | val_loss=0.019260 | lr=5.000000e-04
# epoch 127 | train_loss=0.018154 | val_loss=0.019135 | lr=5.000000e-04
# epoch 128 | train_loss=0.018142 | val_loss=0.019148 | lr=5.000000e-04
# epoch 129 | train_loss=0.018115 | val_loss=0.019244 | lr=5.000000e-04
# epoch 130 | train_loss=0.018102 | val_loss=0.019306 | lr=5.000000e-04
# epoch 131 | train_loss=0.018102 | val_loss=0.019135 | lr=5.000000e-04
# epoch 132 | train_loss=0.018071 | val_loss=0.019004 | lr=5.000000e-04
# epoch 133 | train_loss=0.018044 | val_loss=0.019023 | lr=5.000000e-04
# epoch 134 | train_loss=0.018030 | val_loss=0.019059 | lr=5.000000e-04
# epoch 135 | train_loss=0.018023 | val_loss=0.019031 | lr=5.000000e-04
# epoch 136 | train_loss=0.017979 | val_loss=0.019224 | lr=5.000000e-04
# epoch 137 | train_loss=0.017977 | val_loss=0.018990 | lr=5.000000e-04
# epoch 138 | train_loss=0.017930 | val_loss=0.018982 | lr=5.000000e-04
# epoch 139 | train_loss=0.017938 | val_loss=0.018967 | lr=5.000000e-04
# epoch 140 | train_loss=0.017897 | val_loss=0.018860 | lr=5.000000e-04
# epoch 141 | train_loss=0.017901 | val_loss=0.019011 | lr=5.000000e-04
# epoch 142 | train_loss=0.017856 | val_loss=0.019202 | lr=5.000000e-04
# epoch 143 | train_loss=0.017839 | val_loss=0.018942 | lr=5.000000e-04
# epoch 144 | train_loss=0.017830 | val_loss=0.018852 | lr=5.000000e-04
# epoch 145 | train_loss=0.017811 | val_loss=0.018931 | lr=5.000000e-04
# epoch 146 | train_loss=0.017788 | val_loss=0.018853 | lr=5.000000e-04
# epoch 147 | train_loss=0.017757 | val_loss=0.018976 | lr=5.000000e-04
# epoch 148 | train_loss=0.017736 | val_loss=0.018930 | lr=5.000000e-04
# epoch 149 | train_loss=0.017718 | val_loss=0.018778 | lr=5.000000e-04
# epoch 150 | train_loss=0.017701 | val_loss=0.018972 | lr=5.000000e-04
# epoch 151 | train_loss=0.017683 | val_loss=0.018797 | lr=5.000000e-04
# epoch 152 | train_loss=0.017659 | val_loss=0.018736 | lr=5.000000e-04
# epoch 153 | train_loss=0.017645 | val_loss=0.018903 | lr=5.000000e-04
# epoch 154 | train_loss=0.017634 | val_loss=0.018742 | lr=5.000000e-04
# epoch 155 | train_loss=0.017605 | val_loss=0.018820 | lr=5.000000e-04
# epoch 156 | train_loss=0.017577 | val_loss=0.018825 | lr=5.000000e-04
# epoch 157 | train_loss=0.017567 | val_loss=0.019052 | lr=5.000000e-04
# epoch 158 | train_loss=0.017559 | val_loss=0.018732 | lr=5.000000e-04
# epoch 159 | train_loss=0.017549 | val_loss=0.018766 | lr=5.000000e-04
# epoch 160 | train_loss=0.017526 | val_loss=0.018688 | lr=5.000000e-04
# epoch 161 | train_loss=0.017496 | val_loss=0.018700 | lr=5.000000e-04
# epoch 162 | train_loss=0.017467 | val_loss=0.018654 | lr=5.000000e-04
# epoch 163 | train_loss=0.017449 | val_loss=0.018720 | lr=5.000000e-04
# epoch 164 | train_loss=0.017441 | val_loss=0.018714 | lr=5.000000e-04
# epoch 165 | train_loss=0.017395 | val_loss=0.018651 | lr=5.000000e-04
# epoch 166 | train_loss=0.017392 | val_loss=0.018697 | lr=5.000000e-04
# epoch 167 | train_loss=0.017367 | val_loss=0.018559 | lr=5.000000e-04
# epoch 168 | train_loss=0.017351 | val_loss=0.018830 | lr=5.000000e-04
# epoch 169 | train_loss=0.017342 | val_loss=0.018613 | lr=5.000000e-04
# epoch 170 | train_loss=0.017332 | val_loss=0.018725 | lr=5.000000e-04
# epoch 171 | train_loss=0.017326 | val_loss=0.018765 | lr=5.000000e-04
# epoch 172 | train_loss=0.017300 | val_loss=0.018696 | lr=5.000000e-04
# epoch 173 | train_loss=0.017274 | val_loss=0.018664 | lr=5.000000e-04
# epoch 174 | train_loss=0.017261 | val_loss=0.018544 | lr=5.000000e-04
# epoch 175 | train_loss=0.017225 | val_loss=0.018553 | lr=5.000000e-04
# epoch 176 | train_loss=0.017208 | val_loss=0.018637 | lr=5.000000e-04
# epoch 177 | train_loss=0.017199 | val_loss=0.018465 | lr=5.000000e-04
# epoch 178 | train_loss=0.017186 | val_loss=0.018673 | lr=5.000000e-04
# epoch 179 | train_loss=0.017154 | val_loss=0.018649 | lr=5.000000e-04
# epoch 180 | train_loss=0.017158 | val_loss=0.018464 | lr=5.000000e-04
# epoch 181 | train_loss=0.017119 | val_loss=0.018558 | lr=5.000000e-04
# epoch 182 | train_loss=0.017112 | val_loss=0.018504 | lr=5.000000e-04
# epoch 183 | train_loss=0.017107 | val_loss=0.018664 | lr=5.000000e-04
# epoch 184 | train_loss=0.017072 | val_loss=0.018638 | lr=5.000000e-04
# epoch 185 | train_loss=0.017079 | val_loss=0.018459 | lr=5.000000e-04
# epoch 186 | train_loss=0.017048 | val_loss=0.018383 | lr=5.000000e-04
# epoch 187 | train_loss=0.017038 | val_loss=0.018427 | lr=5.000000e-04
# epoch 188 | train_loss=0.017021 | val_loss=0.018520 | lr=5.000000e-04
# epoch 189 | train_loss=0.016991 | val_loss=0.018436 | lr=5.000000e-04
# epoch 190 | train_loss=0.016990 | val_loss=0.018445 | lr=5.000000e-04
# epoch 191 | train_loss=0.016984 | val_loss=0.018423 | lr=5.000000e-04
# epoch 192 | train_loss=0.016949 | val_loss=0.018368 | lr=5.000000e-04
# epoch 193 | train_loss=0.016949 | val_loss=0.018330 | lr=5.000000e-04
# epoch 194 | train_loss=0.016952 | val_loss=0.018513 | lr=5.000000e-04
# epoch 195 | train_loss=0.016899 | val_loss=0.018336 | lr=5.000000e-04
# epoch 196 | train_loss=0.016896 | val_loss=0.018356 | lr=5.000000e-04
# epoch 197 | train_loss=0.016889 | val_loss=0.018392 | lr=5.000000e-04
# epoch 198 | train_loss=0.016865 | val_loss=0.018342 | lr=5.000000e-04
# epoch 199 | train_loss=0.016854 | val_loss=0.018263 | lr=5.000000e-04
# epoch 200 | train_loss=0.016833 | val_loss=0.018536 | lr=5.000000e-04
# epoch 201 | train_loss=0.016826 | val_loss=0.018378 | lr=5.000000e-04
# epoch 202 | train_loss=0.016806 | val_loss=0.018371 | lr=5.000000e-04
# epoch 203 | train_loss=0.016786 | val_loss=0.018277 | lr=5.000000e-04
# epoch 204 | train_loss=0.016769 | val_loss=0.018413 | lr=5.000000e-04
# epoch 205 | train_loss=0.016776 | val_loss=0.018406 | lr=5.000000e-04
# epoch 206 | train_loss=0.016760 | val_loss=0.018311 | lr=5.000000e-04
# epoch 207 | train_loss=0.016738 | val_loss=0.018280 | lr=5.000000e-04
# epoch 208 | train_loss=0.016713 | val_loss=0.018306 | lr=2.500000e-04
# epoch 209 | train_loss=0.016200 | val_loss=0.017896 | lr=2.500000e-04
# epoch 210 | train_loss=0.016146 | val_loss=0.017938 | lr=2.500000e-04
# epoch 211 | train_loss=0.016152 | val_loss=0.017883 | lr=2.500000e-04
# epoch 212 | train_loss=0.016126 | val_loss=0.017879 | lr=2.500000e-04
# epoch 213 | train_loss=0.016121 | val_loss=0.017893 | lr=2.500000e-04
# epoch 214 | train_loss=0.016113 | val_loss=0.017903 | lr=2.500000e-04
# epoch 215 | train_loss=0.016098 | val_loss=0.017887 | lr=2.500000e-04
# epoch 216 | train_loss=0.016082 | val_loss=0.017911 | lr=2.500000e-04
# epoch 217 | train_loss=0.016075 | val_loss=0.017884 | lr=2.500000e-04
# epoch 218 | train_loss=0.016067 | val_loss=0.017827 | lr=2.500000e-04
# epoch 219 | train_loss=0.016048 | val_loss=0.017843 | lr=2.500000e-04
# epoch 220 | train_loss=0.016048 | val_loss=0.017921 | lr=2.500000e-04
# epoch 221 | train_loss=0.016038 | val_loss=0.017859 | lr=2.500000e-04
# epoch 222 | train_loss=0.016033 | val_loss=0.017826 | lr=2.500000e-04
# epoch 223 | train_loss=0.016014 | val_loss=0.017852 | lr=2.500000e-04
# epoch 224 | train_loss=0.016005 | val_loss=0.017784 | lr=2.500000e-04
# epoch 225 | train_loss=0.016001 | val_loss=0.017829 | lr=2.500000e-04
# epoch 226 | train_loss=0.015992 | val_loss=0.017830 | lr=2.500000e-04
# epoch 227 | train_loss=0.015981 | val_loss=0.017921 | lr=2.500000e-04
# epoch 228 | train_loss=0.015978 | val_loss=0.017850 | lr=2.500000e-04
# epoch 229 | train_loss=0.015974 | val_loss=0.017778 | lr=2.500000e-04
# epoch 230 | train_loss=0.015960 | val_loss=0.017852 | lr=2.500000e-04
# epoch 231 | train_loss=0.015946 | val_loss=0.017785 | lr=2.500000e-04
# epoch 232 | train_loss=0.015947 | val_loss=0.017809 | lr=2.500000e-04
# epoch 233 | train_loss=0.015928 | val_loss=0.017789 | lr=2.500000e-04
# epoch 234 | train_loss=0.015930 | val_loss=0.017842 | lr=2.500000e-04
# epoch 235 | train_loss=0.015932 | val_loss=0.017822 | lr=2.500000e-04
# epoch 236 | train_loss=0.015908 | val_loss=0.017821 | lr=2.500000e-04
# epoch 237 | train_loss=0.015904 | val_loss=0.017783 | lr=2.500000e-04
# epoch 238 | train_loss=0.015893 | val_loss=0.017809 | lr=1.250000e-04
# epoch 239 | train_loss=0.015630 | val_loss=0.017635 | lr=1.250000e-04
# epoch 240 | train_loss=0.015603 | val_loss=0.017629 | lr=1.250000e-04
# epoch 241 | train_loss=0.015599 | val_loss=0.017619 | lr=1.250000e-04
# epoch 242 | train_loss=0.015598 | val_loss=0.017678 | lr=1.250000e-04
# epoch 243 | train_loss=0.015594 | val_loss=0.017608 | lr=1.250000e-04
# epoch 244 | train_loss=0.015585 | val_loss=0.017637 | lr=1.250000e-04
# epoch 245 | train_loss=0.015579 | val_loss=0.017730 | lr=1.250000e-04
# epoch 246 | train_loss=0.015578 | val_loss=0.017617 | lr=1.250000e-04
# epoch 247 | train_loss=0.015564 | val_loss=0.017602 | lr=1.250000e-04
# epoch 248 | train_loss=0.015565 | val_loss=0.017612 | lr=1.250000e-04
# epoch 249 | train_loss=0.015562 | val_loss=0.017607 | lr=1.250000e-04
# epoch 250 | train_loss=0.015552 | val_loss=0.017655 | lr=1.250000e-04
# epoch 251 | train_loss=0.015552 | val_loss=0.017611 | lr=1.250000e-04
# epoch 252 | train_loss=0.015549 | val_loss=0.017629 | lr=1.250000e-04
# epoch 253 | train_loss=0.015540 | val_loss=0.017598 | lr=1.250000e-04
# epoch 254 | train_loss=0.015540 | val_loss=0.017604 | lr=1.250000e-04
# epoch 255 | train_loss=0.015537 | val_loss=0.017610 | lr=1.250000e-04
# epoch 256 | train_loss=0.015526 | val_loss=0.017618 | lr=1.250000e-04
# epoch 257 | train_loss=0.015526 | val_loss=0.017579 | lr=1.250000e-04
# epoch 258 | train_loss=0.015521 | val_loss=0.017605 | lr=1.250000e-04
# epoch 259 | train_loss=0.015513 | val_loss=0.017584 | lr=1.250000e-04
# epoch 260 | train_loss=0.015510 | val_loss=0.017597 | lr=1.250000e-04
# epoch 261 | train_loss=0.015509 | val_loss=0.017611 | lr=1.250000e-04
# epoch 262 | train_loss=0.015506 | val_loss=0.017581 | lr=1.250000e-04
# epoch 263 | train_loss=0.015504 | val_loss=0.017586 | lr=1.250000e-04
# epoch 264 | train_loss=0.015497 | val_loss=0.017564 | lr=1.250000e-04
# epoch 265 | train_loss=0.015491 | val_loss=0.017595 | lr=1.250000e-04
# epoch 266 | train_loss=0.015484 | val_loss=0.017563 | lr=1.250000e-04
# epoch 267 | train_loss=0.015485 | val_loss=0.017583 | lr=1.250000e-04
# epoch 268 | train_loss=0.015482 | val_loss=0.017610 | lr=1.250000e-04
# epoch 269 | train_loss=0.015479 | val_loss=0.017568 | lr=1.250000e-04
# epoch 270 | train_loss=0.015476 | val_loss=0.017567 | lr=1.250000e-04
# epoch 271 | train_loss=0.015469 | val_loss=0.017572 | lr=1.250000e-04
# epoch 272 | train_loss=0.015465 | val_loss=0.017592 | lr=1.250000e-04
# epoch 273 | train_loss=0.015462 | val_loss=0.017601 | lr=6.250000e-05
# epoch 274 | train_loss=0.015316 | val_loss=0.017530 | lr=6.250000e-05
# epoch 275 | train_loss=0.015308 | val_loss=0.017518 | lr=6.250000e-05
# epoch 276 | train_loss=0.015305 | val_loss=0.017526 | lr=6.250000e-05
# epoch 277 | train_loss=0.015304 | val_loss=0.017527 | lr=6.250000e-05
# epoch 278 | train_loss=0.015299 | val_loss=0.017532 | lr=6.250000e-05
# epoch 279 | train_loss=0.015297 | val_loss=0.017510 | lr=6.250000e-05
# epoch 280 | train_loss=0.015295 | val_loss=0.017519 | lr=6.250000e-05
# epoch 281 | train_loss=0.015292 | val_loss=0.017527 | lr=6.250000e-05
# epoch 282 | train_loss=0.015291 | val_loss=0.017514 | lr=6.250000e-05
# epoch 283 | train_loss=0.015289 | val_loss=0.017515 | lr=6.250000e-05
# epoch 284 | train_loss=0.015288 | val_loss=0.017517 | lr=6.250000e-05
# epoch 285 | train_loss=0.015286 | val_loss=0.017537 | lr=6.250000e-05
# epoch 286 | train_loss=0.015281 | val_loss=0.017518 | lr=6.250000e-05
# epoch 287 | train_loss=0.015281 | val_loss=0.017515 | lr=6.250000e-05
# epoch 288 | train_loss=0.015278 | val_loss=0.017531 | lr=3.125000e-05
# epoch 289 | train_loss=0.015199 | val_loss=0.017492 | lr=3.125000e-05
# epoch 290 | train_loss=0.015195 | val_loss=0.017497 | lr=3.125000e-05
# epoch 291 | train_loss=0.015193 | val_loss=0.017483 | lr=3.125000e-05
# epoch 292 | train_loss=0.015191 | val_loss=0.017494 | lr=3.125000e-05
# epoch 293 | train_loss=0.015191 | val_loss=0.017489 | lr=3.125000e-05
# epoch 294 | train_loss=0.015190 | val_loss=0.017509 | lr=3.125000e-05
# epoch 295 | train_loss=0.015189 | val_loss=0.017504 | lr=3.125000e-05
# epoch 296 | train_loss=0.015189 | val_loss=0.017498 | lr=3.125000e-05
# epoch 297 | train_loss=0.015186 | val_loss=0.017502 | lr=3.125000e-05
# epoch 298 | train_loss=0.015183 | val_loss=0.017501 | lr=3.125000e-05
# epoch 299 | train_loss=0.015184 | val_loss=0.017496 | lr=3.125000e-05
# epoch 300 | train_loss=0.015184 | val_loss=0.017507 | lr=1.562500e-05
# epoch 301 | train_loss=0.015140 | val_loss=0.017488 | lr=1.562500e-05
# epoch 302 | train_loss=0.015138 | val_loss=0.017495 | lr=1.562500e-05
# epoch 303 | train_loss=0.015137 | val_loss=0.017490 | lr=1.562500e-05
# epoch 304 | train_loss=0.015136 | val_loss=0.017490 | lr=1.562500e-05
# epoch 305 | train_loss=0.015136 | val_loss=0.017487 | lr=1.562500e-05
# epoch 306 | train_loss=0.015135 | val_loss=0.017496 | lr=1.562500e-05
# epoch 307 | train_loss=0.015135 | val_loss=0.017491 | lr=1.562500e-05
# epoch 308 | train_loss=0.015133 | val_loss=0.017499 | lr=1.562500e-05
# epoch 309 | train_loss=0.015133 | val_loss=0.017488 | lr=1.000000e-05
# epoch 310 | train_loss=0.015117 | val_loss=0.017483 | lr=1.000000e-05
# epoch 311 | train_loss=0.015116 | val_loss=0.017486 | lr=1.000000e-05
# epoch 312 | train_loss=0.015116 | val_loss=0.017487 | lr=1.000000e-05
# epoch 313 | train_loss=0.015116 | val_loss=0.017486 | lr=1.000000e-05
# epoch 314 | train_loss=0.015115 | val_loss=0.017482 | lr=1.000000e-05
# epoch 315 | train_loss=0.015115 | val_loss=0.017484 | lr=1.000000e-05
# epoch 316 | train_loss=0.015114 | val_loss=0.017481 | lr=1.000000e-05
# epoch 317 | train_loss=0.015114 | val_loss=0.017487 | lr=1.000000e-05
# epoch 318 | train_loss=0.015113 | val_loss=0.017487 | lr=1.000000e-05
# epoch 319 | train_loss=0.015113 | val_loss=0.017485 | lr=1.000000e-05
# epoch 320 | train_loss=0.015113 | val_loss=0.017491 | lr=1.000000e-05
# epoch 321 | train_loss=0.015113 | val_loss=0.017489 | lr=1.000000e-05
# epoch 322 | train_loss=0.015111 | val_loss=0.017490 | lr=1.000000e-05
# epoch 323 | train_loss=0.015111 | val_loss=0.017487 | lr=1.000000e-05
# epoch 324 | train_loss=0.015111 | val_loss=0.017486 | lr=1.000000e-05
# epoch 325 | train_loss=0.015111 | val_loss=0.017492 | lr=1.000000e-05
# epoch 326 | train_loss=0.015111 | val_loss=0.017486 | lr=1.000000e-05
# epoch 327 | train_loss=0.015110 | val_loss=0.017481 | lr=1.000000e-05
# epoch 328 | train_loss=0.015110 | val_loss=0.017484 | lr=1.000000e-05
# epoch 329 | train_loss=0.015110 | val_loss=0.017485 | lr=1.000000e-05
# epoch 330 | train_loss=0.015109 | val_loss=0.017486 | lr=1.000000e-05
# epoch 331 | train_loss=0.015108 | val_loss=0.017484 | lr=1.000000e-05
# epoch 332 | train_loss=0.015108 | val_loss=0.017481 | lr=1.000000e-05
# epoch 333 | train_loss=0.015108 | val_loss=0.017486 | lr=1.000000e-05
# epoch 334 | train_loss=0.015107 | val_loss=0.017487 | lr=1.000000e-05
# epoch 335 | train_loss=0.015107 | val_loss=0.017483 | lr=1.000000e-05
# epoch 336 | train_loss=0.015107 | val_loss=0.017483 | lr=1.000000e-05
# epoch 337 | train_loss=0.015106 | val_loss=0.017488 | lr=1.000000e-05
# epoch 338 | train_loss=0.015106 | val_loss=0.017482 | lr=1.000000e-05
# epoch 339 | train_loss=0.015105 | val_loss=0.017488 | lr=1.000000e-05
# epoch 340 | train_loss=0.015105 | val_loss=0.017479 | lr=1.000000e-05
# epoch 341 | train_loss=0.015104 | val_loss=0.017494 | lr=1.000000e-05
# epoch 342 | train_loss=0.015103 | val_loss=0.017488 | lr=1.000000e-05
# epoch 343 | train_loss=0.015104 | val_loss=0.017488 | lr=1.000000e-05
# epoch 344 | train_loss=0.015103 | val_loss=0.017491 | lr=1.000000e-05
# epoch 345 | train_loss=0.015104 | val_loss=0.017488 | lr=1.000000e-05
# epoch 346 | train_loss=0.015103 | val_loss=0.017482 | lr=1.000000e-05
# epoch 347 | train_loss=0.015102 | val_loss=0.017485 | lr=1.000000e-05
# epoch 348 | train_loss=0.015101 | val_loss=0.017478 | lr=1.000000e-05
# epoch 349 | train_loss=0.015101 | val_loss=0.017484 | lr=1.000000e-05
# epoch 350 | train_loss=0.015101 | val_loss=0.017484 | lr=1.000000e-05
# epoch 351 | train_loss=0.015101 | val_loss=0.017489 | lr=1.000000e-05
# epoch 352 | train_loss=0.015101 | val_loss=0.017480 | lr=1.000000e-05
# epoch 353 | train_loss=0.015100 | val_loss=0.017486 | lr=1.000000e-05
# epoch 354 | train_loss=0.015100 | val_loss=0.017485 | lr=1.000000e-05
# epoch 355 | train_loss=0.015099 | val_loss=0.017480 | lr=1.000000e-05
# epoch 356 | train_loss=0.015099 | val_loss=0.017482 | lr=1.000000e-05
# epoch 357 | train_loss=0.015099 | val_loss=0.017483 | lr=1.000000e-05
# epoch 358 | train_loss=0.015099 | val_loss=0.017482 | lr=1.000000e-05
# epoch 359 | train_loss=0.015098 | val_loss=0.017484 | lr=1.000000e-05
# epoch 360 | train_loss=0.015098 | val_loss=0.017484 | lr=1.000000e-05
# epoch 361 | train_loss=0.015097 | val_loss=0.017485 | lr=1.000000e-05
# epoch 362 | train_loss=0.015097 | val_loss=0.017485 | lr=1.000000e-05
# epoch 363 | train_loss=0.015097 | val_loss=0.017480 | lr=1.000000e-05
# epoch 364 | train_loss=0.015096 | val_loss=0.017477 | lr=1.000000e-05
# epoch 365 | train_loss=0.015095 | val_loss=0.017485 | lr=1.000000e-05
# epoch 366 | train_loss=0.015096 | val_loss=0.017477 | lr=1.000000e-05
# epoch 367 | train_loss=0.015095 | val_loss=0.017478 | lr=1.000000e-05
# epoch 368 | train_loss=0.015095 | val_loss=0.017486 | lr=1.000000e-05
# epoch 369 | train_loss=0.015094 | val_loss=0.017487 | lr=1.000000e-05
# epoch 370 | train_loss=0.015094 | val_loss=0.017480 | lr=1.000000e-05
# epoch 371 | train_loss=0.015093 | val_loss=0.017478 | lr=1.000000e-05
# epoch 372 | train_loss=0.015093 | val_loss=0.017482 | lr=1.000000e-05
# epoch 373 | train_loss=0.015093 | val_loss=0.017489 | lr=1.000000e-05
# epoch 374 | train_loss=0.015093 | val_loss=0.017480 | lr=1.000000e-05
# epoch 375 | train_loss=0.015092 | val_loss=0.017480 | lr=1.000000e-05
# epoch 376 | train_loss=0.015092 | val_loss=0.017485 | lr=1.000000e-05
# epoch 377 | train_loss=0.015092 | val_loss=0.017480 | lr=1.000000e-05
# epoch 378 | train_loss=0.015091 | val_loss=0.017481 | lr=1.000000e-05
# epoch 379 | train_loss=0.015091 | val_loss=0.017478 | lr=1.000000e-05
# epoch 380 | train_loss=0.015090 | val_loss=0.017481 | lr=1.000000e-05
# epoch 381 | train_loss=0.015090 | val_loss=0.017480 | lr=1.000000e-05
# epoch 382 | train_loss=0.015089 | val_loss=0.017478 | lr=1.000000e-05
# epoch 383 | train_loss=0.015089 | val_loss=0.017478 | lr=1.000000e-05
# epoch 384 | train_loss=0.015089 | val_loss=0.017486 | lr=1.000000e-05
# epoch 385 | train_loss=0.015088 | val_loss=0.017483 | lr=1.000000e-05
# epoch 386 | train_loss=0.015088 | val_loss=0.017485 | lr=1.000000e-05
# epoch 387 | train_loss=0.015088 | val_loss=0.017475 | lr=1.000000e-05
# epoch 388 | train_loss=0.015088 | val_loss=0.017479 | lr=1.000000e-05
# epoch 389 | train_loss=0.015087 | val_loss=0.017479 | lr=1.000000e-05
# epoch 390 | train_loss=0.015087 | val_loss=0.017478 | lr=1.000000e-05
# epoch 391 | train_loss=0.015086 | val_loss=0.017480 | lr=1.000000e-05
# epoch 392 | train_loss=0.015086 | val_loss=0.017481 | lr=1.000000e-05
# epoch 393 | train_loss=0.015086 | val_loss=0.017476 | lr=1.000000e-05
# epoch 394 | train_loss=0.015085 | val_loss=0.017482 | lr=1.000000e-05
# epoch 395 | train_loss=0.015085 | val_loss=0.017479 | lr=1.000000e-05
# epoch 396 | train_loss=0.015085 | val_loss=0.017476 | lr=1.000000e-05
# epoch 397 | train_loss=0.015084 | val_loss=0.017473 | lr=1.000000e-05
# epoch 398 | train_loss=0.015084 | val_loss=0.017477 | lr=1.000000e-05
# epoch 399 | train_loss=0.015084 | val_loss=0.017476 | lr=1.000000e-05
# epoch 400 | train_loss=0.015083 | val_loss=0.017482 | lr=1.000000e-05
# epoch 401 | train_loss=0.015083 | val_loss=0.017476 | lr=1.000000e-05
# epoch 402 | train_loss=0.015083 | val_loss=0.017475 | lr=1.000000e-05
# epoch 403 | train_loss=0.015082 | val_loss=0.017476 | lr=1.000000e-05
# epoch 404 | train_loss=0.015082 | val_loss=0.017475 | lr=1.000000e-05
# epoch 405 | train_loss=0.015082 | val_loss=0.017481 | lr=1.000000e-05
# epoch 406 | train_loss=0.015081 | val_loss=0.017474 | lr=1.000000e-05
# epoch 407 | train_loss=0.015081 | val_loss=0.017474 | lr=1.000000e-05
# epoch 408 | train_loss=0.015081 | val_loss=0.017479 | lr=1.000000e-05
# epoch 409 | train_loss=0.015080 | val_loss=0.017477 | lr=1.000000e-05
# epoch 410 | train_loss=0.015080 | val_loss=0.017475 | lr=1.000000e-05
# epoch 411 | train_loss=0.015079 | val_loss=0.017476 | lr=1.000000e-05
# epoch 412 | train_loss=0.015079 | val_loss=0.017478 | lr=1.000000e-05
# epoch 413 | train_loss=0.015079 | val_loss=0.017475 | lr=1.000000e-05
# epoch 414 | train_loss=0.015079 | val_loss=0.017480 | lr=1.000000e-05
# epoch 415 | train_loss=0.015079 | val_loss=0.017477 | lr=1.000000e-05
# epoch 416 | train_loss=0.015078 | val_loss=0.017477 | lr=1.000000e-05
# epoch 417 | train_loss=0.015077 | val_loss=0.017479 | lr=1.000000e-05
# epoch 418 | train_loss=0.015077 | val_loss=0.017476 | lr=1.000000e-05
# epoch 419 | train_loss=0.015077 | val_loss=0.017478 | lr=1.000000e-05
# epoch 420 | train_loss=0.015077 | val_loss=0.017474 | lr=1.000000e-05
# epoch 421 | train_loss=0.015076 | val_loss=0.017484 | lr=1.000000e-05
# epoch 422 | train_loss=0.015076 | val_loss=0.017479 | lr=1.000000e-05
# epoch 423 | train_loss=0.015075 | val_loss=0.017475 | lr=1.000000e-05
# epoch 424 | train_loss=0.015075 | val_loss=0.017477 | lr=1.000000e-05
# epoch 425 | train_loss=0.015075 | val_loss=0.017477 | lr=1.000000e-05
# epoch 426 | train_loss=0.015075 | val_loss=0.017471 | lr=1.000000e-05
# epoch 427 | train_loss=0.015074 | val_loss=0.017477 | lr=1.000000e-05
# epoch 428 | train_loss=0.015073 | val_loss=0.017473 | lr=1.000000e-05
# epoch 429 | train_loss=0.015074 | val_loss=0.017475 | lr=1.000000e-05
# epoch 430 | train_loss=0.015073 | val_loss=0.017477 | lr=1.000000e-05
# epoch 431 | train_loss=0.015073 | val_loss=0.017478 | lr=1.000000e-05
# epoch 432 | train_loss=0.015072 | val_loss=0.017480 | lr=1.000000e-05
# epoch 433 | train_loss=0.015072 | val_loss=0.017476 | lr=1.000000e-05
# epoch 434 | train_loss=0.015071 | val_loss=0.017481 | lr=1.000000e-05
# epoch 435 | train_loss=0.015072 | val_loss=0.017475 | lr=1.000000e-05
# epoch 436 | train_loss=0.015071 | val_loss=0.017479 | lr=1.000000e-05
# epoch 437 | train_loss=0.015071 | val_loss=0.017476 | lr=1.000000e-05
# epoch 438 | train_loss=0.015070 | val_loss=0.017474 | lr=1.000000e-05
# epoch 439 | train_loss=0.015070 | val_loss=0.017472 | lr=1.000000e-05
# epoch 440 | train_loss=0.015069 | val_loss=0.017478 | lr=1.000000e-05
# epoch 441 | train_loss=0.015069 | val_loss=0.017479 | lr=1.000000e-05
# epoch 442 | train_loss=0.015069 | val_loss=0.017469 | lr=1.000000e-05
# epoch 443 | train_loss=0.015069 | val_loss=0.017468 | lr=1.000000e-05
# epoch 444 | train_loss=0.015068 | val_loss=0.017477 | lr=1.000000e-05
# epoch 445 | train_loss=0.015067 | val_loss=0.017474 | lr=1.000000e-05
# epoch 446 | train_loss=0.015068 | val_loss=0.017469 | lr=1.000000e-05
# epoch 447 | train_loss=0.015067 | val_loss=0.017474 | lr=1.000000e-05
# epoch 448 | train_loss=0.015067 | val_loss=0.017475 | lr=1.000000e-05
# epoch 449 | train_loss=0.015067 | val_loss=0.017472 | lr=1.000000e-05
# epoch 450 | train_loss=0.015066 | val_loss=0.017477 | lr=1.000000e-05
# epoch 451 | train_loss=0.015066 | val_loss=0.017472 | lr=1.000000e-05
# epoch 452 | train_loss=0.015066 | val_loss=0.017469 | lr=1.000000e-05
# epoch 453 | train_loss=0.015065 | val_loss=0.017472 | lr=1.000000e-05
# epoch 454 | train_loss=0.015065 | val_loss=0.017472 | lr=1.000000e-05
# epoch 455 | train_loss=0.015065 | val_loss=0.017469 | lr=1.000000e-05
# epoch 456 | train_loss=0.015064 | val_loss=0.017469 | lr=1.000000e-05
# epoch 457 | train_loss=0.015064 | val_loss=0.017477 | lr=1.000000e-05
# epoch 458 | train_loss=0.015064 | val_loss=0.017473 | lr=1.000000e-05
# epoch 459 | train_loss=0.015064 | val_loss=0.017474 | lr=1.000000e-05
# epoch 460 | train_loss=0.015063 | val_loss=0.017467 | lr=1.000000e-05
# epoch 461 | train_loss=0.015063 | val_loss=0.017469 | lr=1.000000e-05
# epoch 462 | train_loss=0.015063 | val_loss=0.017472 | lr=1.000000e-05
# epoch 463 | train_loss=0.015062 | val_loss=0.017469 | lr=1.000000e-05
# epoch 464 | train_loss=0.015062 | val_loss=0.017473 | lr=1.000000e-05
# epoch 465 | train_loss=0.015062 | val_loss=0.017466 | lr=1.000000e-05
# epoch 466 | train_loss=0.015061 | val_loss=0.017473 | lr=1.000000e-05
# epoch 467 | train_loss=0.015061 | val_loss=0.017471 | lr=1.000000e-05
# epoch 468 | train_loss=0.015060 | val_loss=0.017471 | lr=1.000000e-05
# epoch 469 | train_loss=0.015059 | val_loss=0.017467 | lr=1.000000e-05
# epoch 470 | train_loss=0.015060 | val_loss=0.017467 | lr=1.000000e-05
# epoch 471 | train_loss=0.015060 | val_loss=0.017468 | lr=1.000000e-05
# epoch 472 | train_loss=0.015059 | val_loss=0.017472 | lr=1.000000e-05
# epoch 473 | train_loss=0.015059 | val_loss=0.017468 | lr=1.000000e-05
# epoch 474 | train_loss=0.015058 | val_loss=0.017476 | lr=1.000000e-05
# epoch 475 | train_loss=0.015058 | val_loss=0.017474 | lr=1.000000e-05
# epoch 476 | train_loss=0.015058 | val_loss=0.017470 | lr=1.000000e-05
# epoch 477 | train_loss=0.015058 | val_loss=0.017478 | lr=1.000000e-05
# epoch 478 | train_loss=0.015057 | val_loss=0.017475 | lr=1.000000e-05
# epoch 479 | train_loss=0.015057 | val_loss=0.017468 | lr=1.000000e-05
# epoch 480 | train_loss=0.015056 | val_loss=0.017468 | lr=1.000000e-05
# epoch 481 | train_loss=0.015056 | val_loss=0.017467 | lr=1.000000e-05
# epoch 482 | train_loss=0.015056 | val_loss=0.017471 | lr=1.000000e-05
# epoch 483 | train_loss=0.015055 | val_loss=0.017469 | lr=1.000000e-05
# epoch 484 | train_loss=0.015055 | val_loss=0.017470 | lr=1.000000e-05
# epoch 485 | train_loss=0.015055 | val_loss=0.017470 | lr=1.000000e-05
# epoch 486 | train_loss=0.015054 | val_loss=0.017466 | lr=1.000000e-05
# epoch 487 | train_loss=0.015054 | val_loss=0.017472 | lr=1.000000e-05
# epoch 488 | train_loss=0.015053 | val_loss=0.017470 | lr=1.000000e-05
# epoch 489 | train_loss=0.015054 | val_loss=0.017475 | lr=1.000000e-05
# epoch 490 | train_loss=0.015053 | val_loss=0.017468 | lr=1.000000e-05
# epoch 491 | train_loss=0.015052 | val_loss=0.017468 | lr=1.000000e-05
# epoch 492 | train_loss=0.015053 | val_loss=0.017467 | lr=1.000000e-05
# epoch 493 | train_loss=0.015052 | val_loss=0.017463 | lr=1.000000e-05
# epoch 494 | train_loss=0.015052 | val_loss=0.017471 | lr=1.000000e-05
# epoch 495 | train_loss=0.015052 | val_loss=0.017463 | lr=1.000000e-05
# epoch 496 | train_loss=0.015051 | val_loss=0.017471 | lr=1.000000e-05
# epoch 497 | train_loss=0.015052 | val_loss=0.017469 | lr=1.000000e-05
# epoch 498 | train_loss=0.015051 | val_loss=0.017475 | lr=1.000000e-05
# epoch 499 | train_loss=0.015051 | val_loss=0.017471 | lr=1.000000e-05
# epoch 500 | train_loss=0.015050 | val_loss=0.017470 | lr=1.000000e-05
# epoch 501 | train_loss=0.015050 | val_loss=0.017469 | lr=1.000000e-05
# epoch 502 | train_loss=0.015050 | val_loss=0.017469 | lr=1.000000e-05
# epoch 503 | train_loss=0.015049 | val_loss=0.017467 | lr=1.000000e-05
# epoch 504 | train_loss=0.015049 | val_loss=0.017464 | lr=1.000000e-05
# epoch 505 | train_loss=0.015049 | val_loss=0.017466 | lr=1.000000e-05
# epoch 506 | train_loss=0.015048 | val_loss=0.017470 | lr=1.000000e-05
# epoch 507 | train_loss=0.015048 | val_loss=0.017465 | lr=1.000000e-05
# epoch 508 | train_loss=0.015048 | val_loss=0.017464 | lr=1.000000e-05
# epoch 509 | train_loss=0.015047 | val_loss=0.017469 | lr=1.000000e-05
# epoch 510 | train_loss=0.015047 | val_loss=0.017467 | lr=1.000000e-05
# epoch 511 | train_loss=0.015046 | val_loss=0.017466 | lr=1.000000e-05
# epoch 512 | train_loss=0.015046 | val_loss=0.017473 | lr=1.000000e-05
# epoch 513 | train_loss=0.015045 | val_loss=0.017461 | lr=1.000000e-05
# epoch 514 | train_loss=0.015046 | val_loss=0.017468 | lr=1.000000e-05
# epoch 515 | train_loss=0.015045 | val_loss=0.017463 | lr=1.000000e-05
# epoch 516 | train_loss=0.015045 | val_loss=0.017473 | lr=1.000000e-05
# epoch 517 | train_loss=0.015044 | val_loss=0.017463 | lr=1.000000e-05
# epoch 518 | train_loss=0.015044 | val_loss=0.017466 | lr=1.000000e-05
# epoch 519 | train_loss=0.015044 | val_loss=0.017463 | lr=1.000000e-05
# epoch 520 | train_loss=0.015044 | val_loss=0.017464 | lr=1.000000e-05
# epoch 521 | train_loss=0.015044 | val_loss=0.017468 | lr=1.000000e-05
# epoch 522 | train_loss=0.015043 | val_loss=0.017464 | lr=1.000000e-05
# epoch 523 | train_loss=0.015043 | val_loss=0.017471 | lr=1.000000e-05
# epoch 524 | train_loss=0.015043 | val_loss=0.017464 | lr=1.000000e-05
# epoch 525 | train_loss=0.015042 | val_loss=0.017467 | lr=1.000000e-05
# epoch 526 | train_loss=0.015042 | val_loss=0.017464 | lr=1.000000e-05
# epoch 527 | train_loss=0.015041 | val_loss=0.017461 | lr=1.000000e-05
# epoch 528 | train_loss=0.015042 | val_loss=0.017462 | lr=1.000000e-05
# epoch 529 | train_loss=0.015041 | val_loss=0.017469 | lr=1.000000e-05
# epoch 530 | train_loss=0.015041 | val_loss=0.017463 | lr=1.000000e-05
# epoch 531 | train_loss=0.015040 | val_loss=0.017466 | lr=1.000000e-05
# epoch 532 | train_loss=0.015040 | val_loss=0.017464 | lr=1.000000e-05
# epoch 533 | train_loss=0.015040 | val_loss=0.017465 | lr=1.000000e-05
# epoch 534 | train_loss=0.015039 | val_loss=0.017467 | lr=1.000000e-05
# epoch 535 | train_loss=0.015039 | val_loss=0.017466 | lr=1.000000e-05
# epoch 536 | train_loss=0.015039 | val_loss=0.017467 | lr=1.000000e-05
# epoch 537 | train_loss=0.015039 | val_loss=0.017463 | lr=1.000000e-05
# epoch 538 | train_loss=0.015038 | val_loss=0.017465 | lr=1.000000e-05
# epoch 539 | train_loss=0.015038 | val_loss=0.017467 | lr=1.000000e-05
# epoch 540 | train_loss=0.015038 | val_loss=0.017459 | lr=1.000000e-05
# epoch 541 | train_loss=0.015037 | val_loss=0.017461 | lr=1.000000e-05
# epoch 542 | train_loss=0.015037 | val_loss=0.017465 | lr=1.000000e-05
# epoch 543 | train_loss=0.015037 | val_loss=0.017459 | lr=1.000000e-05
# epoch 544 | train_loss=0.015036 | val_loss=0.017461 | lr=1.000000e-05
# epoch 545 | train_loss=0.015036 | val_loss=0.017462 | lr=1.000000e-05
# epoch 546 | train_loss=0.015036 | val_loss=0.017460 | lr=1.000000e-05
# epoch 547 | train_loss=0.015035 | val_loss=0.017463 | lr=1.000000e-05
# epoch 548 | train_loss=0.015035 | val_loss=0.017459 | lr=1.000000e-05
# epoch 549 | train_loss=0.015034 | val_loss=0.017458 | lr=1.000000e-05
# epoch 550 | train_loss=0.015034 | val_loss=0.017459 | lr=1.000000e-05
# epoch 551 | train_loss=0.015034 | val_loss=0.017465 | lr=1.000000e-05
# epoch 552 | train_loss=0.015034 | val_loss=0.017464 | lr=1.000000e-05
# epoch 553 | train_loss=0.015033 | val_loss=0.017460 | lr=1.000000e-05
# epoch 554 | train_loss=0.015033 | val_loss=0.017455 | lr=1.000000e-05
# epoch 555 | train_loss=0.015033 | val_loss=0.017459 | lr=1.000000e-05
# epoch 556 | train_loss=0.015033 | val_loss=0.017461 | lr=1.000000e-05
# epoch 557 | train_loss=0.015032 | val_loss=0.017461 | lr=1.000000e-05
# epoch 558 | train_loss=0.015032 | val_loss=0.017460 | lr=1.000000e-05
# epoch 559 | train_loss=0.015032 | val_loss=0.017466 | lr=1.000000e-05
# epoch 560 | train_loss=0.015031 | val_loss=0.017463 | lr=1.000000e-05
# epoch 561 | train_loss=0.015031 | val_loss=0.017469 | lr=1.000000e-05
# epoch 562 | train_loss=0.015031 | val_loss=0.017468 | lr=1.000000e-05
# epoch 563 | train_loss=0.015031 | val_loss=0.017457 | lr=1.000000e-05
# epoch 564 | train_loss=0.015030 | val_loss=0.017461 | lr=1.000000e-05
# epoch 565 | train_loss=0.015030 | val_loss=0.017460 | lr=1.000000e-05
# epoch 566 | train_loss=0.015029 | val_loss=0.017457 | lr=1.000000e-05
# epoch 567 | train_loss=0.015029 | val_loss=0.017460 | lr=1.000000e-05
# epoch 568 | train_loss=0.015029 | val_loss=0.017462 | lr=1.000000e-05
# epoch 569 | train_loss=0.015029 | val_loss=0.017453 | lr=1.000000e-05
# epoch 570 | train_loss=0.015029 | val_loss=0.017458 | lr=1.000000e-05
# epoch 571 | train_loss=0.015028 | val_loss=0.017452 | lr=1.000000e-05
# epoch 572 | train_loss=0.015028 | val_loss=0.017461 | lr=1.000000e-05
# epoch 573 | train_loss=0.015028 | val_loss=0.017460 | lr=1.000000e-05
# epoch 574 | train_loss=0.015027 | val_loss=0.017460 | lr=1.000000e-05
# epoch 575 | train_loss=0.015027 | val_loss=0.017459 | lr=1.000000e-05
# epoch 576 | train_loss=0.015026 | val_loss=0.017457 | lr=1.000000e-05
# epoch 577 | train_loss=0.015026 | val_loss=0.017455 | lr=1.000000e-05
# epoch 578 | train_loss=0.015025 | val_loss=0.017459 | lr=1.000000e-05
# epoch 579 | train_loss=0.015026 | val_loss=0.017461 | lr=1.000000e-05
# epoch 580 | train_loss=0.015026 | val_loss=0.017453 | lr=1.000000e-05
# epoch 581 | train_loss=0.015025 | val_loss=0.017464 | lr=1.000000e-05
# epoch 582 | train_loss=0.015025 | val_loss=0.017457 | lr=1.000000e-05
# epoch 583 | train_loss=0.015025 | val_loss=0.017462 | lr=1.000000e-05
# epoch 584 | train_loss=0.015024 | val_loss=0.017457 | lr=1.000000e-05
# epoch 585 | train_loss=0.015024 | val_loss=0.017458 | lr=1.000000e-05
# epoch 586 | train_loss=0.015024 | val_loss=0.017456 | lr=1.000000e-05
# epoch 587 | train_loss=0.015023 | val_loss=0.017460 | lr=1.000000e-05
# epoch 588 | train_loss=0.015023 | val_loss=0.017459 | lr=1.000000e-05
# epoch 589 | train_loss=0.015023 | val_loss=0.017462 | lr=1.000000e-05
# epoch 590 | train_loss=0.015022 | val_loss=0.017457 | lr=1.000000e-05
# epoch 591 | train_loss=0.015022 | val_loss=0.017454 | lr=1.000000e-05
# epoch 592 | train_loss=0.015021 | val_loss=0.017454 | lr=1.000000e-05
# epoch 593 | train_loss=0.015022 | val_loss=0.017462 | lr=1.000000e-05
# epoch 594 | train_loss=0.015021 | val_loss=0.017456 | lr=1.000000e-05
# epoch 595 | train_loss=0.015021 | val_loss=0.017453 | lr=1.000000e-05
# epoch 596 | train_loss=0.015020 | val_loss=0.017460 | lr=1.000000e-05
# epoch 597 | train_loss=0.015020 | val_loss=0.017456 | lr=1.000000e-05
# epoch 598 | train_loss=0.015019 | val_loss=0.017465 | lr=1.000000e-05
# epoch 599 | train_loss=0.015020 | val_loss=0.017451 | lr=1.000000e-05
# epoch 600 | train_loss=0.015019 | val_loss=0.017452 | lr=1.000000e-05
# epoch 601 | train_loss=0.015020 | val_loss=0.017456 | lr=1.000000e-05
# epoch 602 | train_loss=0.015019 | val_loss=0.017452 | lr=1.000000e-05
# epoch 603 | train_loss=0.015019 | val_loss=0.017454 | lr=1.000000e-05
# epoch 604 | train_loss=0.015018 | val_loss=0.017455 | lr=1.000000e-05
# epoch 605 | train_loss=0.015018 | val_loss=0.017452 | lr=1.000000e-05
# epoch 606 | train_loss=0.015018 | val_loss=0.017453 | lr=1.000000e-05
# epoch 607 | train_loss=0.015017 | val_loss=0.017454 | lr=1.000000e-05
# epoch 608 | train_loss=0.015017 | val_loss=0.017455 | lr=1.000000e-05
# epoch 609 | train_loss=0.015017 | val_loss=0.017458 | lr=1.000000e-05
# epoch 610 | train_loss=0.015016 | val_loss=0.017452 | lr=1.000000e-05
# epoch 611 | train_loss=0.015016 | val_loss=0.017458 | lr=1.000000e-05
# epoch 612 | train_loss=0.015016 | val_loss=0.017452 | lr=1.000000e-05
# epoch 613 | train_loss=0.015016 | val_loss=0.017456 | lr=1.000000e-05
# epoch 614 | train_loss=0.015015 | val_loss=0.017454 | lr=1.000000e-05
# epoch 615 | train_loss=0.015014 | val_loss=0.017448 | lr=1.000000e-05
# epoch 616 | train_loss=0.015014 | val_loss=0.017449 | lr=1.000000e-05
# epoch 617 | train_loss=0.015014 | val_loss=0.017448 | lr=1.000000e-05
# epoch 618 | train_loss=0.015014 | val_loss=0.017451 | lr=1.000000e-05
# epoch 619 | train_loss=0.015014 | val_loss=0.017458 | lr=1.000000e-05
# epoch 620 | train_loss=0.015013 | val_loss=0.017454 | lr=1.000000e-05
# epoch 621 | train_loss=0.015013 | val_loss=0.017455 | lr=1.000000e-05
# epoch 622 | train_loss=0.015013 | val_loss=0.017456 | lr=1.000000e-05
# epoch 623 | train_loss=0.015012 | val_loss=0.017448 | lr=1.000000e-05
# epoch 624 | train_loss=0.015012 | val_loss=0.017453 | lr=1.000000e-05
# epoch 625 | train_loss=0.015011 | val_loss=0.017453 | lr=1.000000e-05
# epoch 626 | train_loss=0.015012 | val_loss=0.017455 | lr=1.000000e-05
# epoch 627 | train_loss=0.015011 | val_loss=0.017455 | lr=1.000000e-05
# epoch 628 | train_loss=0.015011 | val_loss=0.017451 | lr=1.000000e-05
# epoch 629 | train_loss=0.015011 | val_loss=0.017454 | lr=1.000000e-05
# epoch 630 | train_loss=0.015010 | val_loss=0.017453 | lr=1.000000e-05
# epoch 631 | train_loss=0.015010 | val_loss=0.017450 | lr=1.000000e-05
# epoch 632 | train_loss=0.015010 | val_loss=0.017451 | lr=1.000000e-05
# epoch 633 | train_loss=0.015009 | val_loss=0.017451 | lr=1.000000e-05
# epoch 634 | train_loss=0.015009 | val_loss=0.017452 | lr=1.000000e-05
# epoch 635 | train_loss=0.015009 | val_loss=0.017451 | lr=1.000000e-05
# epoch 636 | train_loss=0.015009 | val_loss=0.017447 | lr=1.000000e-05
# epoch 637 | train_loss=0.015009 | val_loss=0.017452 | lr=1.000000e-05
# epoch 638 | train_loss=0.015008 | val_loss=0.017447 | lr=1.000000e-05
# epoch 639 | train_loss=0.015008 | val_loss=0.017452 | lr=1.000000e-05
# epoch 640 | train_loss=0.015007 | val_loss=0.017448 | lr=1.000000e-05
# epoch 641 | train_loss=0.015007 | val_loss=0.017452 | lr=1.000000e-05
# epoch 642 | train_loss=0.015007 | val_loss=0.017449 | lr=1.000000e-05
# epoch 643 | train_loss=0.015007 | val_loss=0.017449 | lr=1.000000e-05
# epoch 644 | train_loss=0.015006 | val_loss=0.017448 | lr=1.000000e-05
# epoch 645 | train_loss=0.015006 | val_loss=0.017445 | lr=1.000000e-05
# epoch 646 | train_loss=0.015005 | val_loss=0.017449 | lr=1.000000e-05
# epoch 647 | train_loss=0.015006 | val_loss=0.017450 | lr=1.000000e-05
# epoch 648 | train_loss=0.015005 | val_loss=0.017449 | lr=1.000000e-05
# epoch 649 | train_loss=0.015005 | val_loss=0.017451 | lr=1.000000e-05
# epoch 650 | train_loss=0.015004 | val_loss=0.017451 | lr=1.000000e-05
# epoch 651 | train_loss=0.015004 | val_loss=0.017456 | lr=1.000000e-05
# epoch 652 | train_loss=0.015004 | val_loss=0.017452 | lr=1.000000e-05
# epoch 653 | train_loss=0.015004 | val_loss=0.017454 | lr=1.000000e-05
# epoch 654 | train_loss=0.015003 | val_loss=0.017451 | lr=1.000000e-05
# epoch 655 | train_loss=0.015003 | val_loss=0.017449 | lr=1.000000e-05
# epoch 656 | train_loss=0.015003 | val_loss=0.017448 | lr=1.000000e-05
# epoch 657 | train_loss=0.015003 | val_loss=0.017448 | lr=1.000000e-05
# epoch 658 | train_loss=0.015002 | val_loss=0.017457 | lr=1.000000e-05
# epoch 659 | train_loss=0.015003 | val_loss=0.017446 | lr=1.000000e-05
# epoch 660 | train_loss=0.015002 | val_loss=0.017447 | lr=1.000000e-05
# epoch 661 | train_loss=0.015001 | val_loss=0.017448 | lr=1.000000e-05
# epoch 662 | train_loss=0.015001 | val_loss=0.017459 | lr=1.000000e-05
# epoch 663 | train_loss=0.015001 | val_loss=0.017458 | lr=1.000000e-05
# epoch 664 | train_loss=0.015001 | val_loss=0.017449 | lr=1.000000e-05
# epoch 665 | train_loss=0.015000 | val_loss=0.017454 | lr=1.000000e-05
# epoch 666 | train_loss=0.015000 | val_loss=0.017445 | lr=1.000000e-05
# epoch 667 | train_loss=0.015000 | val_loss=0.017450 | lr=1.000000e-05
# epoch 668 | train_loss=0.015000 | val_loss=0.017450 | lr=1.000000e-05
# epoch 669 | train_loss=0.014999 | val_loss=0.017448 | lr=1.000000e-05
# epoch 670 | train_loss=0.014999 | val_loss=0.017453 | lr=1.000000e-05
# epoch 671 | train_loss=0.014999 | val_loss=0.017441 | lr=1.000000e-05
# epoch 672 | train_loss=0.014998 | val_loss=0.017444 | lr=1.000000e-05
# epoch 673 | train_loss=0.014998 | val_loss=0.017441 | lr=1.000000e-05
# epoch 674 | train_loss=0.014998 | val_loss=0.017443 | lr=1.000000e-05
# epoch 675 | train_loss=0.014997 | val_loss=0.017448 | lr=1.000000e-05
# epoch 676 | train_loss=0.014997 | val_loss=0.017440 | lr=1.000000e-05
# epoch 677 | train_loss=0.014997 | val_loss=0.017442 | lr=1.000000e-05
# epoch 678 | train_loss=0.014997 | val_loss=0.017451 | lr=1.000000e-05
# epoch 679 | train_loss=0.014996 | val_loss=0.017446 | lr=1.000000e-05
# epoch 680 | train_loss=0.014996 | val_loss=0.017448 | lr=1.000000e-05
# epoch 681 | train_loss=0.014996 | val_loss=0.017449 | lr=1.000000e-05
# epoch 682 | train_loss=0.014995 | val_loss=0.017444 | lr=1.000000e-05
# epoch 683 | train_loss=0.014996 | val_loss=0.017454 | lr=1.000000e-05
# epoch 684 | train_loss=0.014995 | val_loss=0.017448 | lr=1.000000e-05
# epoch 685 | train_loss=0.014995 | val_loss=0.017447 | lr=1.000000e-05
# ...
# epoch 774 | train_loss=0.014970 | val_loss=0.017436 | lr=1.000000e-05
# epoch 775 | train_loss=0.014970 | val_loss=0.017438 | lr=1.000000e-05
# epoch 776 | train_loss=0.014970 | val_loss=0.017432 | lr=1.000000e-05
# epoch 777 | train_loss=0.014969 | val_loss=0.017437 | lr=1.000000e-05
# epoch 778 | train_loss=0.014969 | val_loss=0.017438 | lr=1.000000e-05
# epoch 779 | train_loss=0.014969 | val_loss=0.017436 | lr=1.000000e-05
# epoch 780 | train_loss=0.014969 | val_loss=0.017429 | lr=1.000000e-05
# epoch 781 | train_loss=0.014968 | val_loss=0.017437 | lr=1.000000e-05
# epoch 782 | train_loss=0.014968 | val_loss=0.017435 | lr=1.000000e-05
# epoch 783 | train_loss=0.014968 | val_loss=0.017430 | lr=1.000000e-05
# epoch 784 | train_loss=0.014968 | val_loss=0.017434 | lr=1.000000e-05
# epoch 785 | train_loss=0.014967 | val_loss=0.017437 | lr=1.000000e-05
# epoch 786 | train_loss=0.014967 | val_loss=0.017432 | lr=1.000000e-05
# epoch 787 | train_loss=0.014966 | val_loss=0.017432 | lr=1.000000e-05
# epoch 788 | train_loss=0.014966 | val_loss=0.017432 | lr=1.000000e-05
# epoch 789 | train_loss=0.014966 | val_loss=0.017431 | lr=1.000000e-05
# epoch 790 | train_loss=0.014966 | val_loss=0.017438 | lr=1.000000e-05
# epoch 791 | train_loss=0.014966 | val_loss=0.017436 | lr=1.000000e-05
# epoch 792 | train_loss=0.014965 | val_loss=0.017435 | lr=1.000000e-05
# epoch 793 | train_loss=0.014965 | val_loss=0.017432 | lr=1.000000e-05
# epoch 794 | train_loss=0.014965 | val_loss=0.017436 | lr=1.000000e-05
# epoch 795 | train_loss=0.014965 | val_loss=0.017434 | lr=1.000000e-05
# epoch 796 | train_loss=0.014964 | val_loss=0.017432 | lr=1.000000e-05
# epoch 797 | train_loss=0.014964 | val_loss=0.017433 | lr=1.000000e-05
# epoch 798 | train_loss=0.014964 | val_loss=0.017431 | lr=1.000000e-05
# epoch 799 | train_loss=0.014964 | val_loss=0.017434 | lr=1.000000e-05
# epoch 800 | train_loss=0.014963 | val_loss=0.017436 | lr=1.000000e-05
# epoch 801 | train_loss=0.014963 | val_loss=0.017435 | lr=1.000000e-05
# epoch 802 | train_loss=0.014963 | val_loss=0.017431 | lr=1.000000e-05
# epoch 803 | train_loss=0.014963 | val_loss=0.017436 | lr=1.000000e-05
# epoch 804 | train_loss=0.014962 | val_loss=0.017443 | lr=1.000000e-05
# epoch 805 | train_loss=0.014962 | val_loss=0.017429 | lr=1.000000e-05
# epoch 806 | train_loss=0.014961 | val_loss=0.017436 | lr=1.000000e-05
# epoch 807 | train_loss=0.014962 | val_loss=0.017436 | lr=1.000000e-05
# epoch 808 | train_loss=0.014961 | val_loss=0.017428 | lr=1.000000e-05
# epoch 809 | train_loss=0.014960 | val_loss=0.017434 | lr=1.000000e-05
# epoch 810 | train_loss=0.014961 | val_loss=0.017433 | lr=1.000000e-05
# epoch 811 | train_loss=0.014961 | val_loss=0.017435 | lr=1.000000e-05
# epoch 812 | train_loss=0.014960 | val_loss=0.017430 | lr=1.000000e-05
# epoch 813 | train_loss=0.014960 | val_loss=0.017430 | lr=1.000000e-05
# epoch 814 | train_loss=0.014959 | val_loss=0.017430 | lr=1.000000e-05
# epoch 815 | train_loss=0.014959 | val_loss=0.017429 | lr=1.000000e-05
# epoch 816 | train_loss=0.014958 | val_loss=0.017436 | lr=1.000000e-05
# epoch 817 | train_loss=0.014959 | val_loss=0.017433 | lr=1.000000e-05
# epoch 818 | train_loss=0.014959 | val_loss=0.017442 | lr=1.000000e-05
# epoch 819 | train_loss=0.014958 | val_loss=0.017433 | lr=1.000000e-05
# epoch 820 | train_loss=0.014958 | val_loss=0.017438 | lr=1.000000e-05
# epoch 821 | train_loss=0.014958 | val_loss=0.017428 | lr=1.000000e-05
# epoch 822 | train_loss=0.014957 | val_loss=0.017425 | lr=1.000000e-05
# epoch 823 | train_loss=0.014957 | val_loss=0.017429 | lr=1.000000e-05
# epoch 824 | train_loss=0.014956 | val_loss=0.017433 | lr=1.000000e-05
# epoch 825 | train_loss=0.014957 | val_loss=0.017430 | lr=1.000000e-05
# epoch 826 | train_loss=0.014956 | val_loss=0.017423 | lr=1.000000e-05
# epoch 827 | train_loss=0.014956 | val_loss=0.017431 | lr=1.000000e-05
# epoch 828 | train_loss=0.014956 | val_loss=0.017437 | lr=1.000000e-05
# epoch 829 | train_loss=0.014955 | val_loss=0.017433 | lr=1.000000e-05
# epoch 830 | train_loss=0.014955 | val_loss=0.017429 | lr=1.000000e-05
# epoch 831 | train_loss=0.014955 | val_loss=0.017428 | lr=1.000000e-05
# epoch 832 | train_loss=0.014955 | val_loss=0.017428 | lr=1.000000e-05
# epoch 833 | train_loss=0.014955 | val_loss=0.017430 | lr=1.000000e-05
# epoch 834 | train_loss=0.014954 | val_loss=0.017431 | lr=1.000000e-05
# epoch 835 | train_loss=0.014954 | val_loss=0.017430 | lr=1.000000e-05
# epoch 836 | train_loss=0.014954 | val_loss=0.017430 | lr=1.000000e-05
# epoch 837 | train_loss=0.014953 | val_loss=0.017426 | lr=1.000000e-05
# epoch 838 | train_loss=0.014953 | val_loss=0.017421 | lr=1.000000e-05
# epoch 839 | train_loss=0.014954 | val_loss=0.017429 | lr=1.000000e-05
# epoch 840 | train_loss=0.014953 | val_loss=0.017432 | lr=1.000000e-05
# epoch 841 | train_loss=0.014953 | val_loss=0.017426 | lr=1.000000e-05
# epoch 842 | train_loss=0.014953 | val_loss=0.017429 | lr=1.000000e-05
# epoch 843 | train_loss=0.014951 | val_loss=0.017426 | lr=1.000000e-05
# epoch 844 | train_loss=0.014952 | val_loss=0.017429 | lr=1.000000e-05
# epoch 845 | train_loss=0.014952 | val_loss=0.017433 | lr=1.000000e-05
# epoch 846 | train_loss=0.014951 | val_loss=0.017427 | lr=1.000000e-05
# epoch 847 | train_loss=0.014951 | val_loss=0.017429 | lr=1.000000e-05
# epoch 848 | train_loss=0.014951 | val_loss=0.017430 | lr=1.000000e-05
# epoch 849 | train_loss=0.014951 | val_loss=0.017429 | lr=1.000000e-05
# epoch 850 | train_loss=0.014950 | val_loss=0.017425 | lr=1.000000e-05
# epoch 851 | train_loss=0.014950 | val_loss=0.017430 | lr=1.000000e-05
# epoch 852 | train_loss=0.014950 | val_loss=0.017431 | lr=1.000000e-05
# epoch 853 | train_loss=0.014949 | val_loss=0.017426 | lr=1.000000e-05
# epoch 854 | train_loss=0.014949 | val_loss=0.017429 | lr=1.000000e-05
# epoch 855 | train_loss=0.014949 | val_loss=0.017429 | lr=1.000000e-05
# epoch 856 | train_loss=0.014948 | val_loss=0.017431 | lr=1.000000e-05
# epoch 857 | train_loss=0.014948 | val_loss=0.017421 | lr=1.000000e-05
# epoch 858 | train_loss=0.014948 | val_loss=0.017427 | lr=1.000000e-05
# epoch 859 | train_loss=0.014948 | val_loss=0.017422 | lr=1.000000e-05
# epoch 860 | train_loss=0.014948 | val_loss=0.017431 | lr=1.000000e-05
# epoch 861 | train_loss=0.014947 | val_loss=0.017428 | lr=1.000000e-05
# epoch 862 | train_loss=0.014946 | val_loss=0.017433 | lr=1.000000e-05
# epoch 863 | train_loss=0.014947 | val_loss=0.017425 | lr=1.000000e-05
# epoch 864 | train_loss=0.014947 | val_loss=0.017427 | lr=1.000000e-05
# epoch 865 | train_loss=0.014946 | val_loss=0.017426 | lr=1.000000e-05
# epoch 866 | train_loss=0.014946 | val_loss=0.017426 | lr=1.000000e-05
# epoch 867 | train_loss=0.014946 | val_loss=0.017424 | lr=1.000000e-05
# epoch 868 | train_loss=0.014945 | val_loss=0.017422 | lr=1.000000e-05
# epoch 869 | train_loss=0.014945 | val_loss=0.017419 | lr=1.000000e-05
# epoch 870 | train_loss=0.014945 | val_loss=0.017427 | lr=1.000000e-05
# epoch 871 | train_loss=0.014945 | val_loss=0.017430 | lr=1.000000e-05
# epoch 872 | train_loss=0.014944 | val_loss=0.017427 | lr=1.000000e-05
# epoch 873 | train_loss=0.014944 | val_loss=0.017421 | lr=1.000000e-05
# epoch 874 | train_loss=0.014944 | val_loss=0.017430 | lr=1.000000e-05
# epoch 875 | train_loss=0.014944 | val_loss=0.017424 | lr=1.000000e-05
# epoch 876 | train_loss=0.014944 | val_loss=0.017424 | lr=1.000000e-05
# epoch 877 | train_loss=0.014943 | val_loss=0.017423 | lr=1.000000e-05
# epoch 878 | train_loss=0.014943 | val_loss=0.017425 | lr=1.000000e-05
# epoch 879 | train_loss=0.014943 | val_loss=0.017427 | lr=1.000000e-05
# epoch 880 | train_loss=0.014942 | val_loss=0.017421 | lr=1.000000e-05
# epoch 881 | train_loss=0.014942 | val_loss=0.017427 | lr=1.000000e-05
# epoch 882 | train_loss=0.014942 | val_loss=0.017427 | lr=1.000000e-05
# epoch 883 | train_loss=0.014942 | val_loss=0.017425 | lr=1.000000e-05
# epoch 884 | train_loss=0.014942 | val_loss=0.017423 | lr=1.000000e-05
# epoch 885 | train_loss=0.014941 | val_loss=0.017424 | lr=1.000000e-05
# epoch 886 | train_loss=0.014941 | val_loss=0.017430 | lr=1.000000e-05
# epoch 887 | train_loss=0.014940 | val_loss=0.017422 | lr=1.000000e-05
# epoch 888 | train_loss=0.014941 | val_loss=0.017430 | lr=1.000000e-05
# epoch 889 | train_loss=0.014941 | val_loss=0.017429 | lr=1.000000e-05
# epoch 890 | train_loss=0.014940 | val_loss=0.017422 | lr=1.000000e-05
# epoch 891 | train_loss=0.014939 | val_loss=0.017423 | lr=1.000000e-05
# epoch 892 | train_loss=0.014940 | val_loss=0.017423 | lr=1.000000e-05
# epoch 893 | train_loss=0.014939 | val_loss=0.017428 | lr=1.000000e-05
# epoch 894 | train_loss=0.014939 | val_loss=0.017420 | lr=1.000000e-05
# epoch 895 | train_loss=0.014939 | val_loss=0.017419 | lr=1.000000e-05
# epoch 896 | train_loss=0.014939 | val_loss=0.017422 | lr=1.000000e-05
# epoch 897 | train_loss=0.014938 | val_loss=0.017420 | lr=1.000000e-05
# epoch 898 | train_loss=0.014938 | val_loss=0.017417 | lr=1.000000e-05
# epoch 899 | train_loss=0.014937 | val_loss=0.017423 | lr=1.000000e-05
# epoch 900 | train_loss=0.014937 | val_loss=0.017422 | lr=1.000000e-05
# epoch 901 | train_loss=0.014937 | val_loss=0.017421 | lr=1.000000e-05
# epoch 902 | train_loss=0.014937 | val_loss=0.017427 | lr=1.000000e-05
# epoch 903 | train_loss=0.014937 | val_loss=0.017415 | lr=1.000000e-05
# epoch 904 | train_loss=0.014936 | val_loss=0.017417 | lr=1.000000e-05
# epoch 905 | train_loss=0.014936 | val_loss=0.017419 | lr=1.000000e-05
# epoch 906 | train_loss=0.014936 | val_loss=0.017421 | lr=1.000000e-05
# epoch 907 | train_loss=0.014935 | val_loss=0.017433 | lr=1.000000e-05
# epoch 908 | train_loss=0.014936 | val_loss=0.017418 | lr=1.000000e-05
# epoch 909 | train_loss=0.014935 | val_loss=0.017422 | lr=1.000000e-05
# epoch 910 | train_loss=0.014935 | val_loss=0.017422 | lr=1.000000e-05
# epoch 911 | train_loss=0.014935 | val_loss=0.017417 | lr=1.000000e-05
# epoch 912 | train_loss=0.014934 | val_loss=0.017423 | lr=1.000000e-05
# epoch 913 | train_loss=0.014934 | val_loss=0.017421 | lr=1.000000e-05
# epoch 914 | train_loss=0.014934 | val_loss=0.017417 | lr=1.000000e-05
# epoch 915 | train_loss=0.014933 | val_loss=0.017421 | lr=1.000000e-05
# epoch 916 | train_loss=0.014933 | val_loss=0.017422 | lr=1.000000e-05
# epoch 917 | train_loss=0.014933 | val_loss=0.017417 | lr=1.000000e-05
# epoch 918 | train_loss=0.014933 | val_loss=0.017423 | lr=1.000000e-05
# epoch 919 | train_loss=0.014933 | val_loss=0.017416 | lr=1.000000e-05
# epoch 920 | train_loss=0.014932 | val_loss=0.017414 | lr=1.000000e-05
# epoch 921 | train_loss=0.014932 | val_loss=0.017417 | lr=1.000000e-05
# epoch 922 | train_loss=0.014932 | val_loss=0.017417 | lr=1.000000e-05
# epoch 923 | train_loss=0.014931 | val_loss=0.017419 | lr=1.000000e-05
# epoch 924 | train_loss=0.014932 | val_loss=0.017424 | lr=1.000000e-05
# epoch 925 | train_loss=0.014931 | val_loss=0.017422 | lr=1.000000e-05
# epoch 926 | train_loss=0.014930 | val_loss=0.017416 | lr=1.000000e-05
# epoch 927 | train_loss=0.014931 | val_loss=0.017422 | lr=1.000000e-05
# epoch 928 | train_loss=0.014930 | val_loss=0.017419 | lr=1.000000e-05
# epoch 929 | train_loss=0.014930 | val_loss=0.017417 | lr=1.000000e-05
# epoch 930 | train_loss=0.014930 | val_loss=0.017419 | lr=1.000000e-05
# epoch 931 | train_loss=0.014930 | val_loss=0.017423 | lr=1.000000e-05
# epoch 932 | train_loss=0.014929 | val_loss=0.017414 | lr=1.000000e-05
# epoch 933 | train_loss=0.014929 | val_loss=0.017423 | lr=1.000000e-05
# epoch 934 | train_loss=0.014928 | val_loss=0.017420 | lr=1.000000e-05
# epoch 935 | train_loss=0.014928 | val_loss=0.017419 | lr=1.000000e-05
# epoch 936 | train_loss=0.014928 | val_loss=0.017417 | lr=1.000000e-05
# epoch 937 | train_loss=0.014928 | val_loss=0.017426 | lr=1.000000e-05
# epoch 938 | train_loss=0.014928 | val_loss=0.017416 | lr=1.000000e-05
# epoch 939 | train_loss=0.014927 | val_loss=0.017418 | lr=1.000000e-05
# epoch 940 | train_loss=0.014928 | val_loss=0.017413 | lr=1.000000e-05
# epoch 941 | train_loss=0.014927 | val_loss=0.017420 | lr=1.000000e-05
# epoch 942 | train_loss=0.014927 | val_loss=0.017422 | lr=1.000000e-05
# epoch 943 | train_loss=0.014926 | val_loss=0.017416 | lr=1.000000e-05
# epoch 944 | train_loss=0.014926 | val_loss=0.017424 | lr=1.000000e-05
# epoch 945 | train_loss=0.014926 | val_loss=0.017417 | lr=1.000000e-05
# epoch 946 | train_loss=0.014926 | val_loss=0.017414 | lr=1.000000e-05
# epoch 947 | train_loss=0.014926 | val_loss=0.017415 | lr=1.000000e-05
# epoch 948 | train_loss=0.014926 | val_loss=0.017422 | lr=1.000000e-05
# epoch 949 | train_loss=0.014925 | val_loss=0.017418 | lr=1.000000e-05
# epoch 950 | train_loss=0.014925 | val_loss=0.017417 | lr=1.000000e-05
# epoch 951 | train_loss=0.014925 | val_loss=0.017424 | lr=1.000000e-05
# epoch 952 | train_loss=0.014924 | val_loss=0.017419 | lr=1.000000e-05
# epoch 953 | train_loss=0.014924 | val_loss=0.017410 | lr=1.000000e-05
# epoch 954 | train_loss=0.014924 | val_loss=0.017416 | lr=1.000000e-05
# epoch 955 | train_loss=0.014924 | val_loss=0.017422 | lr=1.000000e-05
# epoch 956 | train_loss=0.014924 | val_loss=0.017412 | lr=1.000000e-05
# epoch 957 | train_loss=0.014923 | val_loss=0.017416 | lr=1.000000e-05
# epoch 958 | train_loss=0.014923 | val_loss=0.017415 | lr=1.000000e-05
# epoch 959 | train_loss=0.014923 | val_loss=0.017418 | lr=1.000000e-05
# epoch 960 | train_loss=0.014922 | val_loss=0.017419 | lr=1.000000e-05
# epoch 961 | train_loss=0.014923 | val_loss=0.017412 | lr=1.000000e-05
# epoch 962 | train_loss=0.014922 | val_loss=0.017421 | lr=1.000000e-05
# epoch 963 | train_loss=0.014922 | val_loss=0.017421 | lr=1.000000e-05
# epoch 964 | train_loss=0.014922 | val_loss=0.017418 | lr=1.000000e-05
# epoch 965 | train_loss=0.014921 | val_loss=0.017414 | lr=1.000000e-05
# epoch 966 | train_loss=0.014921 | val_loss=0.017419 | lr=1.000000e-05
# epoch 967 | train_loss=0.014921 | val_loss=0.017417 | lr=1.000000e-05
# epoch 968 | train_loss=0.014921 | val_loss=0.017418 | lr=1.000000e-05
# epoch 969 | train_loss=0.014920 | val_loss=0.017415 | lr=1.000000e-05
# epoch 970 | train_loss=0.014920 | val_loss=0.017420 | lr=1.000000e-05
# epoch 971 | train_loss=0.014920 | val_loss=0.017415 | lr=1.000000e-05
# epoch 972 | train_loss=0.014919 | val_loss=0.017413 | lr=1.000000e-05
# epoch 973 | train_loss=0.014919 | val_loss=0.017413 | lr=1.000000e-05
# epoch 974 | train_loss=0.014919 | val_loss=0.017415 | lr=1.000000e-05
# epoch 975 | train_loss=0.014919 | val_loss=0.017413 | lr=1.000000e-05
# epoch 976 | train_loss=0.014919 | val_loss=0.017416 | lr=1.000000e-05
# epoch 977 | train_loss=0.014918 | val_loss=0.017414 | lr=1.000000e-05
# epoch 978 | train_loss=0.014918 | val_loss=0.017415 | lr=1.000000e-05
# epoch 979 | train_loss=0.014918 | val_loss=0.017409 | lr=1.000000e-05
# epoch 980 | train_loss=0.014918 | val_loss=0.017414 | lr=1.000000e-05
# epoch 981 | train_loss=0.014917 | val_loss=0.017422 | lr=1.000000e-05
# epoch 982 | train_loss=0.014917 | val_loss=0.017415 | lr=1.000000e-05
# epoch 983 | train_loss=0.014917 | val_loss=0.017412 | lr=1.000000e-05
# epoch 984 | train_loss=0.014916 | val_loss=0.017413 | lr=1.000000e-05
# epoch 985 | train_loss=0.014917 | val_loss=0.017413 | lr=1.000000e-05
# epoch 986 | train_loss=0.014916 | val_loss=0.017415 | lr=1.000000e-05
# epoch 987 | train_loss=0.014916 | val_loss=0.017411 | lr=1.000000e-05
# epoch 988 | train_loss=0.014915 | val_loss=0.017414 | lr=1.000000e-05
# epoch 989 | train_loss=0.014915 | val_loss=0.017413 | lr=1.000000e-05
# epoch 990 | train_loss=0.014916 | val_loss=0.017416 | lr=1.000000e-05
# epoch 991 | train_loss=0.014915 | val_loss=0.017414 | lr=1.000000e-05
# epoch 992 | train_loss=0.014914 | val_loss=0.017425 | lr=1.000000e-05
# epoch 993 | train_loss=0.014915 | val_loss=0.017412 | lr=1.000000e-05
# epoch 994 | train_loss=0.014915 | val_loss=0.017411 | lr=1.000000e-05
# epoch 995 | train_loss=0.014914 | val_loss=0.017413 | lr=1.000000e-05
# epoch 996 | train_loss=0.014914 | val_loss=0.017410 | lr=1.000000e-05
# epoch 997 | train_loss=0.014913 | val_loss=0.017409 | lr=1.000000e-05
# epoch 998 | train_loss=0.014913 | val_loss=0.017406 | lr=1.000000e-05
# epoch 999 | train_loss=0.014913 | val_loss=0.017408 | lr=1.000000e-05
# epoch 1000 | train_loss=0.014913 | val_loss=0.017410 | lr=1.000000e-05
# training time sec: 10844.246210575104
# best_epoch: 998
# best_val: 0.017405509304255246

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(train_history, label="train")
ax[0].plot(val_history, label="val")
ax[0].set_xlabel("epoch"); ax[0].set_ylabel("loss")
ax[0].set_title("Training curves"); ax[0].legend()

ax[1].plot(lr_history)
ax[1].set_xlabel("epoch"); ax[1].set_ylabel("lr")
ax[1].set_title("LR schedule")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Best checkpoint evaluation

# %%
best_ckpt = torch.load(best_ckpt_path, map_location=device)
model.load_state_dict(best_ckpt["model_state_dict"])
model.eval()

train_metrics = evaluate_dataset(model, ds_train, device, stats["c_min"], stats["c_max"])
val_metrics = evaluate_dataset(model, ds_val, device, stats["c_min"], stats["c_max"])
test_metrics = evaluate_dataset(model, ds_test, device, stats["c_min"], stats["c_max"])

train_summary = summarize_metrics(train_metrics)
val_summary = summarize_metrics(val_metrics)
test_summary = summarize_metrics(test_metrics)

print("TRAIN SUMMARY")
print(json.dumps(train_summary, ensure_ascii=False, indent=2))
print("\nVAL SUMMARY")
print(json.dumps(val_summary, ensure_ascii=False, indent=2))
print("\nTEST SUMMARY")
print(json.dumps(test_summary, ensure_ascii=False, indent=2))
# Out:
# TRAIN SUMMARY
# {
#   "mse_mean": 140.31125635823895,
#   "mse_std": 64.61195574399552,
#   "rmse_mean": 11.524049625473637,
#   "rmse_std": 2.7399884180954444,
#   "relative_l2_mean": 0.00772368629079973,
#   "relative_l2_std": 0.0018320046320658868,
#   "psnr_mean": 24.78904473403239,
#   "psnr_std": 2.1393345911014343
# }
#
# VAL SUMMARY
# {
#   "mse_mean": 164.05225971603394,
#   "mse_std": 86.06900114246156,
#   "rmse_mean": 12.367526539802551,
#   "rmse_std": 3.331148015275549,
#   "relative_l2_mean": 0.00828641961608082,
#   "relative_l2_std": 0.0022235164466509697,
#   "psnr_mean": 24.24633213306337,
#   "psnr_std": 2.41640374223882
# }
#
# TEST SUMMARY
# {
#   "mse_mean": 334.16507583618164,
#   "mse_std": 178.09905302851558,
#   "rmse_mean": 17.60240495622158,
#   "rmse_std": 4.931573312503147,
#   "relative_l2_mean": 0.011797254216508008,
#   "relative_l2_std": 0.0033001892492528573,
#   "psnr_mean": 21.219881041443706,
#   "psnr_std": 2.5814681370879002
# }

# %% [markdown]
# ### 10.1 Geometry invariance на обученной модели

# %%
print("On TRAINED model:")
geom_invariance_test(model, ds_test, device, coords_device, perm_axis="receiver", perm_kind="shift", k=4)
geom_invariance_test(model, ds_test, device, coords_device, perm_axis="receiver", perm_kind="shift", k=37)
geom_invariance_test(model, ds_test, device, coords_device, perm_axis="receiver", perm_kind="random")
geom_invariance_test(model, ds_test, device, coords_device, perm_axis="source",   perm_kind="shift", k=3)
geom_invariance_test(model, ds_test, device, coords_device, perm_axis="source",   perm_kind="random")
# Out:
# On TRAINED model:
# [geom inv / receiver / shift, k=4]  max |y0 - y1| = 4.284e-07, rel = 3.638e-07
# [geom inv / receiver / shift, k=37]  max |y0 - y1| = 4.768e-07, rel = 4.049e-07
# [geom inv / receiver / random, k=4]  max |y0 - y1| = 5.066e-07, rel = 4.302e-07
# [geom inv / source / shift, k=3]  max |y0 - y1| = 6.147e-07, rel = 5.219e-07
# [geom inv / source / random, k=4]  max |y0 - y1| = 4.768e-07, rel = 4.049e-07
# (4.76837158203125e-07, 4.048792367739129e-07)

# %% [markdown]
# ## 11. Визуализация на test

# %%
@torch.no_grad()
def show_prediction(model, dataset, idx, device, c_min, c_max):
    x, c, src_n, rcv_n, rcv_p, meta = dataset[idx]
    x      = x.unsqueeze(0).to(device)
    src_n  = src_n.unsqueeze(0).to(device)
    rcv_n  = rcv_n.unsqueeze(0).to(device)
    rcv_p  = rcv_p.unsqueeze(0).to(device)
    pred = model(x, src_n, rcv_n, coords_device)[0, 0].cpu().numpy()
    pred = np.clip(pred, -1.0, 1.0)
    target = c[0].numpy()
    pred_phys = denorm_c_from_minus1_1(pred, c_min, c_max)
    target_phys = denorm_c_from_minus1_1(target, c_min, c_max)
    err = np.abs(pred_phys - target_phys)

    fig, ax = plt.subplots(1, 3, figsize=(15, 4))
    im0 = ax[0].imshow(target_phys, origin="lower")
    ax[0].set_title(f"target | idx={idx}"); plt.colorbar(im0, ax=ax[0])
    im1 = ax[1].imshow(pred_phys, origin="lower")
    ax[1].set_title("GeoDeepONet prediction"); plt.colorbar(im1, ax=ax[1])
    im2 = ax[2].imshow(err, origin="lower")
    ax[2].set_title("|pred - target|"); plt.colorbar(im2, ax=ax[2])
    plt.tight_layout()
    plt.show()
    print(meta["path"])

for idx in [0, 1, 2]:
    show_prediction(model, ds_test, idx, device, stats["c_min"], stats["c_max"])
# Out:
# /workspace/usct_dataset_v2/test/sample_00000.npz
# /workspace/usct_dataset_v2/test/sample_00001.npz
# /workspace/usct_dataset_v2/test/sample_00002.npz

# %% [markdown]
# ## 12. Save artifacts

# %%
with open(RUN_DIR / "config.json", "w", encoding="utf-8") as f:
    json.dump(
        {
            "config": CFG,
            "stats": stats,
            "S": int(S), "R": int(R),
            "H": int(H), "W": int(W),
            "dx": [float(v) for v in dx],
            "freq_hz": float(freq_hz),
            "best_epoch": int(best_epoch),
            "best_val": float(best_val),
            "num_params": int(sum(p.numel() for p in model.parameters())),
        },
        f, ensure_ascii=False, indent=2,
    )

for name, payload in [
    ("train_summary.json", train_summary),
    ("val_summary.json",   val_summary),
    ("test_summary.json",  test_summary),
    ("train_metrics.json", train_metrics),
    ("val_metrics.json",   val_metrics),
    ("test_metrics.json",  test_metrics),
]:
    with open(RUN_DIR / name, "w", encoding="utf-8") as f:
        json.dump(payload, f, ensure_ascii=False, indent=2)

np.savez_compressed(
    RUN_DIR / "loss_history.npz",
    train_loss=np.array(train_history, dtype=np.float32),
    val_loss=np.array(val_history, dtype=np.float32),
    lr=np.array(lr_history, dtype=np.float32),
)
print("saved GeoDeepONet artifacts to:", RUN_DIR)
# Out:
# saved GeoDeepONet artifacts to: /workspace/reference_points/geo_deeponet_v2
