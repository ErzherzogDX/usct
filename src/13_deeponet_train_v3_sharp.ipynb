# %% [markdown]
# # 13_deeponet_train_v3_sharp.ipynb
#
# DeepONet v3 с акцентом на уменьшение **blur / мутности** в реконструкции.
#
# ## Что добавлено
# Относительно `DeepONet v2`:
# - **linear output** и **scaled dot-product** сохранены;
# - target нормируется в `[-1, 1]`;
# - используется **composite loss**:
#   - pixel loss,
#   - gradient loss,
#   - multiscale loss;
# - есть LR scheduler;
# - сохраняются отдельные кривые для разных компонент loss.
#
# ## Идея
# Обычный pixel-wise loss часто приводит к сглаженным reconstruction maps.
# Чтобы сделать предсказания более резкими, добавляем:
# - штраф на несовпадение **градиентов**,
# - loss на нескольких масштабах.

# %% [markdown]
# ## 0. Важно
# `M_hom` считается через `j-Wave`, поэтому JAX запускается на **CPU**.
#
# Сама DeepONet-модель обучается в **PyTorch** и использует GPU, если он доступен.

# %%
import os

os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"
os.environ.pop("LD_LIBRARY_PATH", None)
# Out:
# '/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/cuda/lib64'

# %%
from pathlib import Path
import json
import math
import random
import time

import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, Subset
import torch.nn.functional as F

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = False
torch.backends.cudnn.benchmark = True

print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("device name:", torch.cuda.get_device_name(0))
# Out:
# torch: 2.10.0+cu130
# cuda available: True
# device name: NVIDIA GeForce RTX 5090

# %%
CFG = {
    "dataset_root": "/workspace/usct_dataset_v2",
    "run_name": "deeponet_v3_sharp",
    "batch_size": 8,
    "epochs": 200,
    "patience": 35,
    "lr": 1e-3,
    "min_lr": 1e-5,
    "weight_decay": 1e-6,
    "num_workers": 0,
    "mask_half_width": 2,
    "use_residual": True,
    "branch_width": 192,
    "trunk_width": 192,
    "trunk_hidden": 256,
    "num_fourier_features": 24,
    "dropout": 0.0,
    "scheduler_factor": 0.5,
    "scheduler_patience": 8,
    "overfit_debug_enabled": True,
    "overfit_subset_size": 8,
    "overfit_epochs": 300,
    "overfit_lr": 1e-3,
    "loss_pixel_weight": 1.0,
    "loss_grad_weight": 0.15,
    "loss_multiscale_weight": 0.20,
    "multiscale_levels": 3,
    "pixel_loss_type": "l1",
    "grad_loss_type": "l1",
    "multiscale_loss_type": "l1",
}
CFG
# Out:
# {'dataset_root': '/workspace/usct_dataset_v2',
#  'run_name': 'deeponet_v3_sharp',
#  'batch_size': 8,
#  'epochs': 200,
#  'patience': 35,
#  'lr': 0.001,
#  'min_lr': 1e-05,
#  'weight_decay': 1e-06,
#  'num_workers': 0,
#  'mask_half_width': 2,
#  'use_residual': True,
#  'branch_width': 192,
#  'trunk_width': 192,
#  'trunk_hidden': 256,
#  'num_fourier_features': 24,
#  'dropout': 0.0,
#  'scheduler_factor': 0.5,
#  'scheduler_patience': 8,
#  'overfit_debug_enabled': True,
#  'overfit_subset_size': 8,
#  'overfit_epochs': 300,
#  'overfit_lr': 0.001,
#  'loss_pixel_weight': 1.0,
#  'loss_grad_weight': 0.15,
#  'loss_multiscale_weight': 0.2,
#  'multiscale_levels': 3,
#  'pixel_loss_type': 'l1',
#  'grad_loss_type': 'l1',
#  'multiscale_loss_type': 'l1'}

# %%
OUT_ROOT = Path(CFG["dataset_root"])
TRAIN_DIR = OUT_ROOT / "train"
VAL_DIR = OUT_ROOT / "val"
TEST_DIR = OUT_ROOT / "test"

assert TRAIN_DIR.exists(), TRAIN_DIR
assert VAL_DIR.exists(), VAL_DIR
assert TEST_DIR.exists(), TEST_DIR

train_files = sorted(TRAIN_DIR.glob("*.npz"))
val_files = sorted(VAL_DIR.glob("*.npz"))
test_files = sorted(TEST_DIR.glob("*.npz"))

print("train:", len(train_files))
print("val:", len(val_files))
print("test:", len(test_files))
assert len(train_files) > 0 and len(val_files) > 0 and len(test_files) > 0
# Out:
# train: 6200
# val: 1000
# test: 800

# %%
sample0 = np.load(train_files[0])

S, R = sample0["x"].shape[1], sample0["x"].shape[2]
H, W = sample0["c"].shape
dx = tuple(sample0["dx"].astype(np.float32))
freq_hz = float(sample0["freq_hz"][0])

receiver_y = np.array(sample0["receiver_y"].astype(np.int32))
receiver_x = np.array(sample0["receiver_x"].astype(np.int32))
source_ring_idx_full = np.array(sample0["source_ring_idx"].astype(np.int32))

all_c_values = []
for p in train_files:
    c = np.load(p)["c"].astype(np.float32)
    all_c_values.append(c)
all_c_values = np.stack(all_c_values, axis=0)

stats = {
    "c_min": float(all_c_values.min()),
    "c_max": float(all_c_values.max()),
}
print("S, R:", S, R)
print("H, W:", H, W)
print("dx:", dx)
print("freq_hz:", freq_hz)
print("stats:", stats)
# Out:
# S, R: 16 256
# H, W: 192 192
# dx: (np.float32(0.00075), np.float32(0.00075))
# freq_hz: 500000.0
# stats: {'c_min': 1404.1473388671875, 'c_max': 1598.34423828125}

# %% [markdown]
# ## 1. `M_hom` через j-Wave

# %%
import jax
import jax.numpy as jnp
from jax import jit

from jwave import FourierSeries
from jwave.geometry import Domain, Medium
from jwave.acoustics.time_harmonic import helmholtz_solver

print("jax version:", jax.__version__)
print("jax devices:", jax.devices())
# Out:
# jax version: 0.4.38
# jax devices: [CudaDevice(id=0)]

# %%
domain = Domain((H, W), dx)
omega = 2 * np.pi * freq_hz

def gaussian_source(H, W, y0, x0, sigma=1.8):
    yy, xx = np.mgrid[0:H, 0:W]
    g = np.exp(-((yy - y0) ** 2 + (xx - x0) ** 2) / (2 * sigma**2))
    g = g / g.sum()
    return g.astype(np.float32)

full_source_fields = []
for ridx in source_ring_idx_full:
    y0 = int(receiver_y[ridx])
    x0 = int(receiver_x[ridx])
    src_np = gaussian_source(H, W, y0, x0, sigma=1.8)
    full_source_fields.append(jnp.array(src_np, dtype=jnp.complex64))
full_source_fields = tuple(full_source_fields)

def make_medium(c_map):
    sound_speed = FourierSeries(jnp.expand_dims(jnp.array(c_map), -1), domain)
    medium = Medium(
        domain=domain,
        sound_speed=sound_speed,
        density=1000.0,
        pml_size=16,
    )
    return medium

def forward_measurements_full(c_map):
    medium = make_medium(c_map)
    ms = []
    for i in range(len(full_source_fields)):
        src = FourierSeries(jnp.expand_dims(full_source_fields[i], -1), domain)
        field = helmholtz_solver(medium, omega, src * omega)
        u = field.params[..., 0]
        ms.append(u[receiver_y, receiver_x])
    return jnp.stack(ms, axis=0)

forward_measurements_full_jit = jit(forward_measurements_full)
# Out:
# /tmp/ipykernel_181807/2997561755.py:1: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   domain = Domain((H, W), dx)

# %%
c_hom = jnp.full((H, W), 1500.0, dtype=jnp.float32)

t0 = time.time()
M_hom_complex = forward_measurements_full_jit(c_hom)
M_hom_complex.block_until_ready()
t1 = time.time()

M_hom_complex = np.array(M_hom_complex)

print("M_hom_complex:", M_hom_complex.shape, M_hom_complex.dtype)
print("time:", t1 - t0, "sec")

plt.figure(figsize=(8, 4))
plt.imshow(np.abs(M_hom_complex), aspect="auto", origin="lower")
plt.title("|M_hom|")
plt.colorbar()
plt.show()
# Out:
# M_hom_complex: (16, 256) complex64
# time: 7.189568758010864 sec

# %% [markdown]
# ## 2. Dataset with target normalization to `[-1, 1]`

# %%
def mask_self_receivers(M, source_ring_idx, half_width=2):
    M = M.copy()
    S_local, R_local = M.shape
    for s in range(S_local):
        ridx = int(source_ring_idx[s])
        for delta in range(-half_width, half_width + 1):
            rr = (ridx + delta) % R_local
            M[s, rr] = 0.0 + 0.0j
    return M

class USCTDeepONetDatasetV3(Dataset):
    def __init__(self, paths, c_min, c_max, M_hom_complex, use_residual=True, mask_half_width=2):
        self.paths = list(paths)
        self.c_min = float(c_min)
        self.c_max = float(c_max)
        self.c_range = max(self.c_max - self.c_min, 1e-8)
        self.M_hom_complex = M_hom_complex
        self.use_residual = bool(use_residual)
        self.mask_half_width = int(mask_half_width)

    def __len__(self):
        return len(self.paths)

    def normalize_target(self, c):
        return 2.0 * (c - self.c_min) / self.c_range - 1.0

    def denormalize_target(self, c_norm):
        return ((c_norm + 1.0) * 0.5) * self.c_range + self.c_min

    def __getitem__(self, idx):
        d = np.load(self.paths[idx])

        x_raw = d["x"].astype(np.float32)
        c = d["c"].astype(np.float32)
        source_ring_idx = d["source_ring_idx"].astype(np.int64)

        M = x_raw[0] + 1j * x_raw[1]

        if self.use_residual:
            M = M - self.M_hom_complex

        if self.mask_half_width > 0:
            M = mask_self_receivers(M, source_ring_idx, half_width=self.mask_half_width)

        x_tensor = np.stack([M.real, M.imag], axis=0).astype(np.float32)

        x_scale = float(np.percentile(np.abs(x_tensor), 99.5))
        if x_scale < 1e-8:
            x_scale = 1.0
        x_tensor = x_tensor / x_scale

        c_norm = self.normalize_target(c).astype(np.float32)

        return (
            torch.from_numpy(x_tensor),
            torch.from_numpy(c_norm).unsqueeze(0),
            {
                "path": str(self.paths[idx]),
                "x_scale": x_scale,
            },
        )

# %%
ds_train = USCTDeepONetDatasetV3(
    train_files,
    stats["c_min"],
    stats["c_max"],
    M_hom_complex=M_hom_complex,
    use_residual=CFG["use_residual"],
    mask_half_width=CFG["mask_half_width"],
)

ds_val = USCTDeepONetDatasetV3(
    val_files,
    stats["c_min"],
    stats["c_max"],
    M_hom_complex=M_hom_complex,
    use_residual=CFG["use_residual"],
    mask_half_width=CFG["mask_half_width"],
)

ds_test = USCTDeepONetDatasetV3(
    test_files,
    stats["c_min"],
    stats["c_max"],
    M_hom_complex=M_hom_complex,
    use_residual=CFG["use_residual"],
    mask_half_width=CFG["mask_half_width"],
)

x0, c0, meta0 = ds_train[0]
print("x0:", x0.shape, x0.dtype)
print("c0:", c0.shape, c0.dtype, float(c0.min()), float(c0.max()))
print(meta0)
# Out:
# x0: torch.Size([2, 16, 256]) torch.float32
# c0: torch.Size([1, 192, 192]) torch.float32 -0.7392016053199768 0.5010437965393066
# {'path': '/workspace/usct_dataset_v2/train/sample_00000.npz', 'x_scale': 5201.529296875}

# %% [markdown]
# ## 3. Trunk coordinate grid

# %%
yy = np.linspace(-1.0, 1.0, H, dtype=np.float32)
xx = np.linspace(-1.0, 1.0, W, dtype=np.float32)
grid_y, grid_x = np.meshgrid(yy, xx, indexing="ij")
coords = np.stack([grid_y, grid_x], axis=-1).reshape(-1, 2)
coords_t = torch.from_numpy(coords)

print("coords_t:", coords_t.shape)
# Out:
# coords_t: torch.Size([36864, 2])

# %% [markdown]
# ## 4. DeepONet v3

# %%
class BranchEncoderV3(nn.Module):
    def __init__(self, out_dim=192, dropout=0.0):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(2, 32, kernel_size=3, stride=1, padding=1),
            nn.GroupNorm(1, 32),
            nn.GELU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.GroupNorm(1, 64),
            nn.GELU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.GroupNorm(1, 128),
            nn.GELU(),
            nn.Conv2d(128, 192, kernel_size=3, stride=2, padding=1),
            nn.GroupNorm(1, 192),
            nn.GELU(),
            nn.Flatten(),
            nn.Linear(192 * 2 * 32, 384),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(384, out_dim),
        )

    def forward(self, x):
        return self.net(x)

class TrunkNetV3(nn.Module):
    def __init__(self, width=192, hidden=256, num_fourier_features=24, dropout=0.0):
        super().__init__()
        self.num_fourier_features = int(num_fourier_features)

        if self.num_fourier_features > 0:
            freq = 2.0 ** torch.arange(self.num_fourier_features, dtype=torch.float32) * math.pi
            self.register_buffer("freq", freq, persistent=False)
            in_dim = 2 + 4 * self.num_fourier_features
        else:
            self.register_buffer("freq", torch.empty(0), persistent=False)
            in_dim = 2

        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden, hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden, hidden),
            nn.GELU(),
            nn.Linear(hidden, width),
        )

    def encode_coords(self, coords):
        if self.num_fourier_features == 0:
            return coords

        y = coords[:, 0:1]
        x = coords[:, 1:2]

        y_proj = y * self.freq[None, :]
        x_proj = x * self.freq[None, :]

        feats = [
            coords,
            torch.sin(y_proj),
            torch.cos(y_proj),
            torch.sin(x_proj),
            torch.cos(x_proj),
        ]
        return torch.cat(feats, dim=1)

    def forward(self, coords):
        return self.net(self.encode_coords(coords))

class DeepONet2DV3(nn.Module):
    def __init__(self, branch_width=192, trunk_width=192, trunk_hidden=256, num_fourier_features=24, dropout=0.0):
        super().__init__()
        self.width = int(branch_width)
        self.branch = BranchEncoderV3(out_dim=branch_width, dropout=dropout)
        self.trunk = TrunkNetV3(
            width=trunk_width,
            hidden=trunk_hidden,
            num_fourier_features=num_fourier_features,
            dropout=dropout,
        )
        self.bias = nn.Parameter(torch.zeros(1))

    def forward(self, x, coords):
        b = self.branch(x)
        t = self.trunk(coords)
        out = torch.matmul(b, t.t()) / math.sqrt(self.width) + self.bias
        out = out.view(x.shape[0], 1, H, W)
        return out

# %% [markdown]
# ## 5. Composite loss to reduce blur

# %%
def image_gradients(x):
    dx = x[:, :, :, 1:] - x[:, :, :, :-1]
    dy = x[:, :, 1:, :] - x[:, :, :-1, :]
    return dx, dy

def gradient_loss(pred, target, loss_type="l1"):
    pred_dx, pred_dy = image_gradients(pred)
    tgt_dx, tgt_dy = image_gradients(target)

    if loss_type == "l2":
        loss_x = F.mse_loss(pred_dx, tgt_dx)
        loss_y = F.mse_loss(pred_dy, tgt_dy)
    else:
        loss_x = F.l1_loss(pred_dx, tgt_dx)
        loss_y = F.l1_loss(pred_dy, tgt_dy)

    return loss_x + loss_y

def multiscale_loss(pred, target, levels=3, loss_type="l1"):
    loss = 0.0
    cur_pred = pred
    cur_tgt = target

    for level in range(levels):
        if loss_type == "l2":
            loss = loss + F.mse_loss(cur_pred, cur_tgt)
        else:
            loss = loss + F.l1_loss(cur_pred, cur_tgt)

        if level != levels - 1:
            cur_pred = F.avg_pool2d(cur_pred, kernel_size=2, stride=2, ceil_mode=False)
            cur_tgt = F.avg_pool2d(cur_tgt, kernel_size=2, stride=2, ceil_mode=False)

    return loss / levels

class CompositeReconstructionLoss(nn.Module):
    def __init__(
        self,
        pixel_weight=1.0,
        grad_weight=0.15,
        multiscale_weight=0.20,
        multiscale_levels=3,
        pixel_type="l1",
        grad_type="l1",
        multiscale_type="l1",
    ):
        super().__init__()
        self.pixel_weight = float(pixel_weight)
        self.grad_weight = float(grad_weight)
        self.multiscale_weight = float(multiscale_weight)
        self.multiscale_levels = int(multiscale_levels)
        self.pixel_type = pixel_type
        self.grad_type = grad_type
        self.multiscale_type = multiscale_type

    def pixel_loss(self, pred, target):
        if self.pixel_type == "l2":
            return F.mse_loss(pred, target)
        return F.l1_loss(pred, target)

    def forward(self, pred, target):
        lp = self.pixel_loss(pred, target)
        lg = gradient_loss(pred, target, loss_type=self.grad_type)
        lm = multiscale_loss(
            pred,
            target,
            levels=self.multiscale_levels,
            loss_type=self.multiscale_type,
        )

        total = (
            self.pixel_weight * lp
            + self.grad_weight * lg
            + self.multiscale_weight * lm
        )

        parts = {
            "pixel": float(lp.detach().item()),
            "grad": float(lg.detach().item()),
            "multiscale": float(lm.detach().item()),
            "total": float(total.detach().item()),
        }
        return total, parts

# %% [markdown]
# ## 6. Metrics and helpers

# %%
def denorm_c_from_minus1_1(c_norm, c_min, c_max):
    return ((c_norm + 1.0) * 0.5) * (c_max - c_min) + c_min

def mse(a, b):
    return float(np.mean((a - b) ** 2))

def rmse(a, b):
    return float(np.sqrt(np.mean((a - b) ** 2)))

def relative_l2(a, b):
    num = np.linalg.norm(a - b)
    den = np.linalg.norm(b) + 1e-8
    return float(num / den)

def psnr_from_mse(mse_value, data_range):
    if mse_value <= 1e-12:
        return float("inf")
    return float(20 * np.log10(data_range) - 10 * np.log10(mse_value))

try:
    from skimage.metrics import structural_similarity as ssim_fn
    HAS_SKIMAGE = True
except Exception:
    HAS_SKIMAGE = False
    ssim_fn = None

def compute_metrics(pred, target, data_range):
    out = {
        "mse": mse(pred, target),
        "rmse": rmse(pred, target),
        "relative_l2": relative_l2(pred, target),
        "psnr": psnr_from_mse(mse(pred, target), data_range),
    }
    if HAS_SKIMAGE:
        out["ssim"] = float(ssim_fn(pred, target, data_range=data_range))
    return out

def train_one_epoch(model, loader, optimizer, criterion, device, coords_device, scaler=None):
    model.train()
    total_loss = 0.0
    total_pixel = 0.0
    total_grad = 0.0
    total_ms = 0.0

    for x, c, _ in loader:
        x = x.to(device, non_blocking=True)
        c = c.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        if scaler is None:
            pred = model(x, coords_device)
            loss, parts = criterion(pred, c)
            loss.backward()
            optimizer.step()
        else:
            with torch.autocast(device_type="cuda", dtype=torch.float16):
                pred = model(x, coords_device)
                loss, parts = criterion(pred, c)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        bs = x.shape[0]
        total_loss += float(loss.item()) * bs
        total_pixel += parts["pixel"] * bs
        total_grad += parts["grad"] * bs
        total_ms += parts["multiscale"] * bs

    n = len(loader.dataset)
    return {
        "total": total_loss / n,
        "pixel": total_pixel / n,
        "grad": total_grad / n,
        "multiscale": total_ms / n,
    }

@torch.no_grad()
def eval_loss(model, loader, criterion, device, coords_device):
    model.eval()
    total_loss = 0.0
    total_pixel = 0.0
    total_grad = 0.0
    total_ms = 0.0

    for x, c, _ in loader:
        x = x.to(device, non_blocking=True)
        c = c.to(device, non_blocking=True)

        pred = model(x, coords_device)
        loss, parts = criterion(pred, c)

        bs = x.shape[0]
        total_loss += float(loss.item()) * bs
        total_pixel += parts["pixel"] * bs
        total_grad += parts["grad"] * bs
        total_ms += parts["multiscale"] * bs

    n = len(loader.dataset)
    return {
        "total": total_loss / n,
        "pixel": total_pixel / n,
        "grad": total_grad / n,
        "multiscale": total_ms / n,
    }

@torch.no_grad()
def evaluate_dataset(model, dataset, device, coords_device, c_min, c_max):
    model.eval()
    metrics_list = []
    data_range = float(c_max - c_min)

    for idx in range(len(dataset)):
        x, c, meta = dataset[idx]
        pred = model(x.unsqueeze(0).to(device), coords_device)[0, 0].cpu().numpy()
        pred = np.clip(pred, -1.0, 1.0)
        target = c[0].numpy()

        pred_phys = denorm_c_from_minus1_1(pred, c_min, c_max)
        target_phys = denorm_c_from_minus1_1(target, c_min, c_max)

        m = compute_metrics(pred_phys, target_phys, data_range=data_range)
        m["index"] = idx
        m["path"] = meta["path"]
        metrics_list.append(m)

    return metrics_list

def summarize_metrics(metrics_list):
    summary = {}
    for key in metrics_list[0].keys():
        if key in ("index", "path"):
            continue
        vals = [m[key] for m in metrics_list]
        summary[f"{key}_mean"] = float(np.mean(vals))
        summary[f"{key}_std"] = float(np.std(vals))
    return summary

# %% [markdown]
# ## 7. DataLoaders

# %%
train_loader = DataLoader(
    ds_train,
    batch_size=CFG["batch_size"],
    shuffle=True,
    num_workers=CFG["num_workers"],
    pin_memory=torch.cuda.is_available(),
)

val_loader = DataLoader(
    ds_val,
    batch_size=CFG["batch_size"],
    shuffle=False,
    num_workers=CFG["num_workers"],
    pin_memory=torch.cuda.is_available(),
)

print("num train batches:", len(train_loader))
print("num val batches:", len(val_loader))
# Out:
# num train batches: 775
# num val batches: 125

# %% [markdown]
# ## 8. Optional overfit sanity check

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
coords_device = coords_t.to(device)

if CFG["overfit_debug_enabled"]:
    overfit_subset = Subset(ds_train, list(range(CFG["overfit_subset_size"])))
    overfit_loader = DataLoader(
        overfit_subset,
        batch_size=min(CFG["batch_size"], CFG["overfit_subset_size"]),
        shuffle=True,
        num_workers=0,
        pin_memory=torch.cuda.is_available(),
    )

    overfit_model = DeepONet2DV3(
        branch_width=CFG["branch_width"],
        trunk_width=CFG["trunk_width"],
        trunk_hidden=CFG["trunk_hidden"],
        num_fourier_features=CFG["num_fourier_features"],
        dropout=CFG["dropout"],
    ).to(device)

    overfit_optimizer = torch.optim.AdamW(
        overfit_model.parameters(),
        lr=CFG["overfit_lr"],
        weight_decay=0.0,
    )

    overfit_criterion = CompositeReconstructionLoss(
        pixel_weight=CFG["loss_pixel_weight"],
        grad_weight=CFG["loss_grad_weight"],
        multiscale_weight=CFG["loss_multiscale_weight"],
        multiscale_levels=CFG["multiscale_levels"],
        pixel_type=CFG["pixel_loss_type"],
        grad_type=CFG["grad_loss_type"],
        multiscale_type=CFG["multiscale_loss_type"],
    )

    overfit_scaler = torch.amp.GradScaler("cuda") if torch.cuda.is_available() else None

    overfit_history = []
    for epoch in range(1, CFG["overfit_epochs"] + 1):
        stats_overfit = train_one_epoch(
            overfit_model,
            overfit_loader,
            overfit_optimizer,
            overfit_criterion,
            device,
            coords_device,
            scaler=overfit_scaler,
        )
        overfit_history.append(stats_overfit["total"])
        if epoch == 1 or epoch % 20 == 0 or epoch == CFG["overfit_epochs"]:
            print(f"[overfit] epoch {epoch:03d} | total={stats_overfit['total']:.6f}")

    plt.figure(figsize=(7, 4))
    plt.plot(overfit_history)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.title("Overfit sanity check")
    plt.show()
else:
    print("overfit debug block is disabled")
# Out:
# [overfit] epoch 001 | total=0.224175
# [overfit] epoch 020 | total=0.206895
# [overfit] epoch 040 | total=0.205420
# [overfit] epoch 060 | total=0.205194
# [overfit] epoch 080 | total=0.205174
# [overfit] epoch 100 | total=0.205115
# [overfit] epoch 120 | total=0.205101
# [overfit] epoch 140 | total=0.205075
# [overfit] epoch 160 | total=0.205069
# [overfit] epoch 180 | total=0.205062
# [overfit] epoch 200 | total=0.205071
# [overfit] epoch 220 | total=0.205048
# [overfit] epoch 240 | total=0.205026
# [overfit] epoch 260 | total=0.204975
# [overfit] epoch 280 | total=0.204687
# [overfit] epoch 300 | total=0.195590

# %% [markdown]
# ## 9. Full training

# %%
model = DeepONet2DV3(
    branch_width=CFG["branch_width"],
    trunk_width=CFG["trunk_width"],
    trunk_hidden=CFG["trunk_hidden"],
    num_fourier_features=CFG["num_fourier_features"],
    dropout=CFG["dropout"],
).to(device)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=CFG["lr"],
    weight_decay=CFG["weight_decay"],
)

criterion = CompositeReconstructionLoss(
    pixel_weight=CFG["loss_pixel_weight"],
    grad_weight=CFG["loss_grad_weight"],
    multiscale_weight=CFG["loss_multiscale_weight"],
    multiscale_levels=CFG["multiscale_levels"],
    pixel_type=CFG["pixel_loss_type"],
    grad_type=CFG["grad_loss_type"],
    multiscale_type=CFG["multiscale_loss_type"],
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=CFG["scheduler_factor"],
    patience=CFG["scheduler_patience"],
    min_lr=CFG["min_lr"],
)

use_amp = torch.cuda.is_available()
scaler = torch.amp.GradScaler("cuda") if use_amp else None

RUN_DIR = Path("/workspace/reference_points") / CFG["run_name"]
RUN_DIR.mkdir(parents=True, exist_ok=True)

best_val = float("inf")
best_epoch = -1
best_ckpt_path = RUN_DIR / "deeponet_best.pt"

train_history = []
val_history = []
lr_history = []
epochs_no_improve = 0

t0 = time.time()

for epoch in range(1, CFG["epochs"] + 1):
    train_stats = train_one_epoch(model, train_loader, optimizer, criterion, device, coords_device, scaler=scaler)
    val_stats = eval_loss(model, val_loader, criterion, device, coords_device)

    scheduler.step(val_stats["total"])

    current_lr = optimizer.param_groups[0]["lr"]
    train_history.append(train_stats)
    val_history.append(val_stats)
    lr_history.append(current_lr)

    print(
        f"epoch {epoch:03d} | "
        f"train_total={train_stats['total']:.6f} | "
        f"val_total={val_stats['total']:.6f} | "
        f"train_pix={train_stats['pixel']:.6f} | "
        f"val_pix={val_stats['pixel']:.6f} | "
        f"train_grad={train_stats['grad']:.6f} | "
        f"val_grad={val_stats['grad']:.6f} | "
        f"train_ms={train_stats['multiscale']:.6f} | "
        f"val_ms={val_stats['multiscale']:.6f} | "
        f"lr={current_lr:.6e}"
    )

    if val_stats["total"] < best_val:
        best_val = val_stats["total"]
        best_epoch = epoch
        epochs_no_improve = 0
        torch.save(
            {
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "stats": stats,
                "config": CFG,
                "best_epoch": best_epoch,
                "best_val": best_val,
            },
            best_ckpt_path,
        )
    else:
        epochs_no_improve += 1

    if epochs_no_improve >= CFG["patience"]:
        print("early stopping")
        break

t1 = time.time()
print("training time sec:", t1 - t0)
print("best_epoch:", best_epoch)
print("best_val:", best_val)
# Out:
# epoch 001 | train_total=0.134131 | val_total=0.105354 | train_pix=0.105798 | val_pix=0.081898 | train_grad=0.055650 | val_grad=0.055026 | train_ms=0.099926 | val_ms=0.076009 | lr=1.000000e-03
# epoch 002 | train_total=0.102538 | val_total=0.098092 | train_pix=0.079249 | val_pix=0.075645 | train_grad=0.056273 | val_grad=0.055377 | train_ms=0.074241 | val_ms=0.070704 | lr=1.000000e-03
# epoch 003 | train_total=0.099580 | val_total=0.100163 | train_pix=0.076712 | val_pix=0.077449 | train_grad=0.056377 | val_grad=0.055262 | train_ms=0.072059 | val_ms=0.072124 | lr=1.000000e-03
# epoch 004 | train_total=0.098352 | val_total=0.095893 | train_pix=0.075656 | val_pix=0.073744 | train_grad=0.056410 | val_grad=0.055482 | train_ms=0.071170 | val_ms=0.069132 | lr=1.000000e-03
# epoch 005 | train_total=0.096952 | val_total=0.091594 | train_pix=0.074491 | val_pix=0.070085 | train_grad=0.056447 | val_grad=0.055572 | train_ms=0.069969 | val_ms=0.065866 | lr=1.000000e-03
# epoch 006 | train_total=0.094643 | val_total=0.091893 | train_pix=0.072541 | val_pix=0.070262 | train_grad=0.056545 | val_grad=0.055854 | train_ms=0.068099 | val_ms=0.066267 | lr=1.000000e-03
# epoch 007 | train_total=0.094436 | val_total=0.090469 | train_pix=0.072356 | val_pix=0.069140 | train_grad=0.056605 | val_grad=0.055671 | train_ms=0.067948 | val_ms=0.064889 | lr=1.000000e-03
# epoch 008 | train_total=0.093895 | val_total=0.091385 | train_pix=0.071899 | val_pix=0.069942 | train_grad=0.056560 | val_grad=0.055694 | train_ms=0.067561 | val_ms=0.065445 | lr=1.000000e-03
# epoch 009 | train_total=0.093387 | val_total=0.089798 | train_pix=0.071461 | val_pix=0.068535 | train_grad=0.056555 | val_grad=0.055852 | train_ms=0.067211 | val_ms=0.064427 | lr=1.000000e-03
# epoch 010 | train_total=0.093215 | val_total=0.090383 | train_pix=0.071315 | val_pix=0.069067 | train_grad=0.056546 | val_grad=0.055559 | train_ms=0.067089 | val_ms=0.064913 | lr=1.000000e-03
# epoch 011 | train_total=0.093095 | val_total=0.091823 | train_pix=0.071215 | val_pix=0.070179 | train_grad=0.056532 | val_grad=0.055859 | train_ms=0.067003 | val_ms=0.066325 | lr=1.000000e-03
# epoch 012 | train_total=0.092883 | val_total=0.090062 | train_pix=0.071032 | val_pix=0.068767 | train_grad=0.056536 | val_grad=0.055738 | train_ms=0.066853 | val_ms=0.064674 | lr=1.000000e-03
# epoch 013 | train_total=0.092773 | val_total=0.089976 | train_pix=0.070934 | val_pix=0.068708 | train_grad=0.056540 | val_grad=0.055698 | train_ms=0.066790 | val_ms=0.064566 | lr=1.000000e-03
# epoch 014 | train_total=0.092720 | val_total=0.089496 | train_pix=0.070888 | val_pix=0.068290 | train_grad=0.056536 | val_grad=0.055671 | train_ms=0.066754 | val_ms=0.064278 | lr=1.000000e-03
# epoch 015 | train_total=0.092605 | val_total=0.089689 | train_pix=0.070788 | val_pix=0.068440 | train_grad=0.056548 | val_grad=0.055724 | train_ms=0.066677 | val_ms=0.064450 | lr=1.000000e-03
# epoch 016 | train_total=0.092474 | val_total=0.090718 | train_pix=0.070676 | val_pix=0.069279 | train_grad=0.056549 | val_grad=0.055854 | train_ms=0.066578 | val_ms=0.065309 | lr=1.000000e-03
# epoch 017 | train_total=0.092996 | val_total=0.089309 | train_pix=0.071112 | val_pix=0.068133 | train_grad=0.056579 | val_grad=0.055677 | train_ms=0.066985 | val_ms=0.064119 | lr=1.000000e-03
# epoch 018 | train_total=0.092291 | val_total=0.089299 | train_pix=0.070522 | val_pix=0.068116 | train_grad=0.056529 | val_grad=0.055699 | train_ms=0.066451 | val_ms=0.064142 | lr=1.000000e-03
# epoch 019 | train_total=0.092296 | val_total=0.089769 | train_pix=0.070524 | val_pix=0.068541 | train_grad=0.056538 | val_grad=0.055563 | train_ms=0.066453 | val_ms=0.064467 | lr=1.000000e-03
# epoch 020 | train_total=0.092204 | val_total=0.089425 | train_pix=0.070442 | val_pix=0.068230 | train_grad=0.056557 | val_grad=0.055677 | train_ms=0.066390 | val_ms=0.064216 | lr=1.000000e-03
# epoch 021 | train_total=0.092401 | val_total=0.089961 | train_pix=0.070611 | val_pix=0.068671 | train_grad=0.056557 | val_grad=0.055815 | train_ms=0.066533 | val_ms=0.064589 | lr=1.000000e-03
# epoch 022 | train_total=0.092298 | val_total=0.089326 | train_pix=0.070525 | val_pix=0.068133 | train_grad=0.056545 | val_grad=0.055763 | train_ms=0.066459 | val_ms=0.064146 | lr=1.000000e-03
# epoch 023 | train_total=0.092206 | val_total=0.089284 | train_pix=0.070445 | val_pix=0.068113 | train_grad=0.056555 | val_grad=0.055694 | train_ms=0.066393 | val_ms=0.064085 | lr=1.000000e-03
# epoch 024 | train_total=0.091999 | val_total=0.089087 | train_pix=0.070268 | val_pix=0.067958 | train_grad=0.056553 | val_grad=0.055673 | train_ms=0.066241 | val_ms=0.063889 | lr=1.000000e-03
# epoch 025 | train_total=0.092104 | val_total=0.089386 | train_pix=0.070356 | val_pix=0.068215 | train_grad=0.056561 | val_grad=0.055701 | train_ms=0.066320 | val_ms=0.064081 | lr=1.000000e-03
# epoch 026 | train_total=0.092044 | val_total=0.088983 | train_pix=0.070305 | val_pix=0.067846 | train_grad=0.056554 | val_grad=0.055728 | train_ms=0.066276 | val_ms=0.063890 | lr=1.000000e-03
# epoch 027 | train_total=0.092063 | val_total=0.089920 | train_pix=0.070321 | val_pix=0.068588 | train_grad=0.056560 | val_grad=0.055848 | train_ms=0.066292 | val_ms=0.064774 | lr=1.000000e-03
# epoch 028 | train_total=0.092124 | val_total=0.089440 | train_pix=0.070372 | val_pix=0.068199 | train_grad=0.056560 | val_grad=0.055772 | train_ms=0.066338 | val_ms=0.064376 | lr=1.000000e-03
# epoch 029 | train_total=0.091963 | val_total=0.089570 | train_pix=0.070234 | val_pix=0.068323 | train_grad=0.056556 | val_grad=0.055700 | train_ms=0.066226 | val_ms=0.064461 | lr=1.000000e-03
# epoch 030 | train_total=0.091906 | val_total=0.089661 | train_pix=0.070187 | val_pix=0.068351 | train_grad=0.056558 | val_grad=0.055806 | train_ms=0.066175 | val_ms=0.064694 | lr=1.000000e-03
# epoch 031 | train_total=0.091956 | val_total=0.089617 | train_pix=0.070226 | val_pix=0.068400 | train_grad=0.056566 | val_grad=0.055748 | train_ms=0.066224 | val_ms=0.064274 | lr=1.000000e-03
# epoch 032 | train_total=0.091913 | val_total=0.088925 | train_pix=0.070191 | val_pix=0.067794 | train_grad=0.056559 | val_grad=0.055726 | train_ms=0.066190 | val_ms=0.063862 | lr=1.000000e-03
# epoch 033 | train_total=0.091968 | val_total=0.089361 | train_pix=0.070237 | val_pix=0.068156 | train_grad=0.056567 | val_grad=0.055730 | train_ms=0.066228 | val_ms=0.064229 | lr=1.000000e-03
# epoch 034 | train_total=0.091920 | val_total=0.089019 | train_pix=0.070197 | val_pix=0.067870 | train_grad=0.056562 | val_grad=0.055694 | train_ms=0.066192 | val_ms=0.063974 | lr=1.000000e-03
# epoch 035 | train_total=0.091909 | val_total=0.088926 | train_pix=0.070187 | val_pix=0.067791 | train_grad=0.056557 | val_grad=0.055723 | train_ms=0.066191 | val_ms=0.063888 | lr=1.000000e-03
# epoch 036 | train_total=0.091909 | val_total=0.089350 | train_pix=0.070187 | val_pix=0.068166 | train_grad=0.056561 | val_grad=0.055763 | train_ms=0.066190 | val_ms=0.064099 | lr=1.000000e-03
# epoch 037 | train_total=0.091917 | val_total=0.088997 | train_pix=0.070194 | val_pix=0.067846 | train_grad=0.056566 | val_grad=0.055782 | train_ms=0.066190 | val_ms=0.063917 | lr=1.000000e-03
# epoch 038 | train_total=0.091768 | val_total=0.089419 | train_pix=0.070066 | val_pix=0.068242 | train_grad=0.056566 | val_grad=0.055646 | train_ms=0.066084 | val_ms=0.064151 | lr=1.000000e-03
# epoch 039 | train_total=0.091965 | val_total=0.089702 | train_pix=0.070233 | val_pix=0.068424 | train_grad=0.056572 | val_grad=0.055838 | train_ms=0.066228 | val_ms=0.064514 | lr=1.000000e-03
# epoch 040 | train_total=0.091802 | val_total=0.088883 | train_pix=0.070096 | val_pix=0.067764 | train_grad=0.056553 | val_grad=0.055692 | train_ms=0.066111 | val_ms=0.063822 | lr=1.000000e-03
# epoch 041 | train_total=0.091820 | val_total=0.089285 | train_pix=0.070113 | val_pix=0.068114 | train_grad=0.056550 | val_grad=0.055784 | train_ms=0.066125 | val_ms=0.064016 | lr=1.000000e-03
# epoch 042 | train_total=0.091798 | val_total=0.088957 | train_pix=0.070092 | val_pix=0.067844 | train_grad=0.056570 | val_grad=0.055621 | train_ms=0.066104 | val_ms=0.063845 | lr=1.000000e-03
# epoch 043 | train_total=0.091677 | val_total=0.088837 | train_pix=0.069989 | val_pix=0.067719 | train_grad=0.056562 | val_grad=0.055717 | train_ms=0.066016 | val_ms=0.063800 | lr=1.000000e-03
# epoch 044 | train_total=0.091806 | val_total=0.088832 | train_pix=0.070098 | val_pix=0.067726 | train_grad=0.056569 | val_grad=0.055665 | train_ms=0.066111 | val_ms=0.063784 | lr=1.000000e-03
# epoch 045 | train_total=0.091780 | val_total=0.088890 | train_pix=0.070078 | val_pix=0.067762 | train_grad=0.056554 | val_grad=0.055736 | train_ms=0.066092 | val_ms=0.063840 | lr=1.000000e-03
# epoch 046 | train_total=0.091760 | val_total=0.088894 | train_pix=0.070061 | val_pix=0.067763 | train_grad=0.056558 | val_grad=0.055725 | train_ms=0.066077 | val_ms=0.063862 | lr=1.000000e-03
# epoch 047 | train_total=0.091800 | val_total=0.089172 | train_pix=0.070093 | val_pix=0.068003 | train_grad=0.056567 | val_grad=0.055784 | train_ms=0.066112 | val_ms=0.064006 | lr=1.000000e-03
# epoch 048 | train_total=0.091709 | val_total=0.088961 | train_pix=0.070016 | val_pix=0.067838 | train_grad=0.056563 | val_grad=0.055746 | train_ms=0.066044 | val_ms=0.063805 | lr=1.000000e-03
# epoch 049 | train_total=0.091750 | val_total=0.088899 | train_pix=0.070052 | val_pix=0.067771 | train_grad=0.056560 | val_grad=0.055771 | train_ms=0.066069 | val_ms=0.063814 | lr=1.000000e-03
# epoch 050 | train_total=0.091671 | val_total=0.089145 | train_pix=0.069984 | val_pix=0.067959 | train_grad=0.056570 | val_grad=0.055783 | train_ms=0.066012 | val_ms=0.064095 | lr=1.000000e-03
# epoch 051 | train_total=0.091634 | val_total=0.089298 | train_pix=0.069951 | val_pix=0.068125 | train_grad=0.056573 | val_grad=0.055765 | train_ms=0.065985 | val_ms=0.064042 | lr=1.000000e-03
# epoch 052 | train_total=0.091576 | val_total=0.089223 | train_pix=0.069906 | val_pix=0.068028 | train_grad=0.056558 | val_grad=0.055778 | train_ms=0.065928 | val_ms=0.064142 | lr=5.000000e-04
# epoch 053 | train_total=0.091106 | val_total=0.088355 | train_pix=0.069516 | val_pix=0.067327 | train_grad=0.056541 | val_grad=0.055686 | train_ms=0.065544 | val_ms=0.063379 | lr=5.000000e-04
# epoch 054 | train_total=0.091077 | val_total=0.088234 | train_pix=0.069496 | val_pix=0.067218 | train_grad=0.056511 | val_grad=0.055686 | train_ms=0.065519 | val_ms=0.063315 | lr=5.000000e-04
# epoch 055 | train_total=0.090950 | val_total=0.088111 | train_pix=0.069397 | val_pix=0.067120 | train_grad=0.056499 | val_grad=0.055719 | train_ms=0.065393 | val_ms=0.063165 | lr=5.000000e-04
# epoch 056 | train_total=0.090336 | val_total=0.087174 | train_pix=0.068854 | val_pix=0.066290 | train_grad=0.056668 | val_grad=0.055894 | train_ms=0.064912 | val_ms=0.062500 | lr=5.000000e-04
# epoch 057 | train_total=0.089958 | val_total=0.087198 | train_pix=0.068523 | val_pix=0.066318 | train_grad=0.056739 | val_grad=0.055947 | train_ms=0.064624 | val_ms=0.062441 | lr=5.000000e-04
# epoch 058 | train_total=0.089889 | val_total=0.087058 | train_pix=0.068461 | val_pix=0.066200 | train_grad=0.056760 | val_grad=0.055890 | train_ms=0.064573 | val_ms=0.062372 | lr=5.000000e-04
# epoch 059 | train_total=0.089775 | val_total=0.086954 | train_pix=0.068368 | val_pix=0.066140 | train_grad=0.056752 | val_grad=0.055842 | train_ms=0.064472 | val_ms=0.062190 | lr=5.000000e-04
# epoch 060 | train_total=0.089374 | val_total=0.086222 | train_pix=0.068044 | val_pix=0.065569 | train_grad=0.056741 | val_grad=0.055784 | train_ms=0.064094 | val_ms=0.061429 | lr=5.000000e-04
# epoch 061 | train_total=0.088232 | val_total=0.084974 | train_pix=0.067100 | val_pix=0.064491 | train_grad=0.056777 | val_grad=0.055911 | train_ms=0.063077 | val_ms=0.060480 | lr=5.000000e-04
# epoch 062 | train_total=0.087662 | val_total=0.084729 | train_pix=0.066624 | val_pix=0.064279 | train_grad=0.056763 | val_grad=0.055949 | train_ms=0.062616 | val_ms=0.060287 | lr=5.000000e-04
# epoch 063 | train_total=0.087369 | val_total=0.084190 | train_pix=0.066379 | val_pix=0.063840 | train_grad=0.056764 | val_grad=0.055855 | train_ms=0.062376 | val_ms=0.059856 | lr=5.000000e-04
# epoch 064 | train_total=0.086973 | val_total=0.083849 | train_pix=0.066049 | val_pix=0.063579 | train_grad=0.056771 | val_grad=0.055843 | train_ms=0.062041 | val_ms=0.059464 | lr=5.000000e-04
# epoch 065 | train_total=0.086334 | val_total=0.083684 | train_pix=0.065523 | val_pix=0.063389 | train_grad=0.056779 | val_grad=0.056000 | train_ms=0.061471 | val_ms=0.059472 | lr=5.000000e-04
# epoch 066 | train_total=0.085935 | val_total=0.083143 | train_pix=0.065194 | val_pix=0.062992 | train_grad=0.056785 | val_grad=0.055837 | train_ms=0.061115 | val_ms=0.058873 | lr=5.000000e-04
# epoch 067 | train_total=0.085484 | val_total=0.082647 | train_pix=0.064821 | val_pix=0.062549 | train_grad=0.056782 | val_grad=0.055921 | train_ms=0.060732 | val_ms=0.058548 | lr=5.000000e-04
# epoch 068 | train_total=0.085113 | val_total=0.082215 | train_pix=0.064513 | val_pix=0.062216 | train_grad=0.056785 | val_grad=0.055858 | train_ms=0.060414 | val_ms=0.058100 | lr=5.000000e-04
# epoch 069 | train_total=0.084745 | val_total=0.081898 | train_pix=0.064211 | val_pix=0.061940 | train_grad=0.056785 | val_grad=0.055877 | train_ms=0.060083 | val_ms=0.057883 | lr=5.000000e-04
# epoch 070 | train_total=0.084361 | val_total=0.081741 | train_pix=0.063896 | val_pix=0.061829 | train_grad=0.056802 | val_grad=0.055840 | train_ms=0.059724 | val_ms=0.057681 | lr=5.000000e-04
# epoch 071 | train_total=0.083897 | val_total=0.081247 | train_pix=0.063516 | val_pix=0.061408 | train_grad=0.056819 | val_grad=0.055989 | train_ms=0.059292 | val_ms=0.057200 | lr=5.000000e-04
# epoch 072 | train_total=0.083537 | val_total=0.080794 | train_pix=0.063221 | val_pix=0.061049 | train_grad=0.056840 | val_grad=0.055911 | train_ms=0.058953 | val_ms=0.056792 | lr=5.000000e-04
# epoch 073 | train_total=0.083133 | val_total=0.080922 | train_pix=0.062886 | val_pix=0.061155 | train_grad=0.056857 | val_grad=0.055968 | train_ms=0.058592 | val_ms=0.056859 | lr=5.000000e-04
# epoch 074 | train_total=0.082717 | val_total=0.080095 | train_pix=0.062544 | val_pix=0.060473 | train_grad=0.056861 | val_grad=0.055910 | train_ms=0.058223 | val_ms=0.056180 | lr=5.000000e-04
# epoch 075 | train_total=0.082238 | val_total=0.079473 | train_pix=0.062151 | val_pix=0.059958 | train_grad=0.056878 | val_grad=0.055928 | train_ms=0.057781 | val_ms=0.055631 | lr=5.000000e-04
# epoch 076 | train_total=0.081459 | val_total=0.078817 | train_pix=0.061506 | val_pix=0.059419 | train_grad=0.056891 | val_grad=0.055930 | train_ms=0.057099 | val_ms=0.055040 | lr=5.000000e-04
# epoch 077 | train_total=0.080985 | val_total=0.078587 | train_pix=0.061115 | val_pix=0.059239 | train_grad=0.056903 | val_grad=0.055953 | train_ms=0.056672 | val_ms=0.054775 | lr=5.000000e-04
# epoch 078 | train_total=0.080565 | val_total=0.078406 | train_pix=0.060771 | val_pix=0.059069 | train_grad=0.056896 | val_grad=0.056033 | train_ms=0.056300 | val_ms=0.054660 | lr=5.000000e-04
# epoch 079 | train_total=0.080123 | val_total=0.077813 | train_pix=0.060407 | val_pix=0.058578 | train_grad=0.056887 | val_grad=0.056032 | train_ms=0.055911 | val_ms=0.054153 | lr=5.000000e-04
# epoch 080 | train_total=0.079749 | val_total=0.077673 | train_pix=0.060103 | val_pix=0.058481 | train_grad=0.056868 | val_grad=0.055949 | train_ms=0.055577 | val_ms=0.053996 | lr=5.000000e-04
# epoch 081 | train_total=0.079361 | val_total=0.077011 | train_pix=0.059787 | val_pix=0.057940 | train_grad=0.056875 | val_grad=0.055942 | train_ms=0.055214 | val_ms=0.053401 | lr=5.000000e-04
# epoch 082 | train_total=0.079050 | val_total=0.076933 | train_pix=0.059536 | val_pix=0.057870 | train_grad=0.056878 | val_grad=0.055927 | train_ms=0.054914 | val_ms=0.053372 | lr=5.000000e-04
# epoch 083 | train_total=0.078615 | val_total=0.076245 | train_pix=0.059180 | val_pix=0.057323 | train_grad=0.056884 | val_grad=0.055940 | train_ms=0.054513 | val_ms=0.052656 | lr=5.000000e-04
# epoch 084 | train_total=0.078212 | val_total=0.075894 | train_pix=0.058852 | val_pix=0.057006 | train_grad=0.056884 | val_grad=0.056012 | train_ms=0.054137 | val_ms=0.052434 | lr=5.000000e-04
# epoch 085 | train_total=0.077943 | val_total=0.075943 | train_pix=0.058634 | val_pix=0.057057 | train_grad=0.056901 | val_grad=0.056042 | train_ms=0.053871 | val_ms=0.052395 | lr=5.000000e-04
# epoch 086 | train_total=0.077389 | val_total=0.075247 | train_pix=0.058180 | val_pix=0.056467 | train_grad=0.056904 | val_grad=0.056068 | train_ms=0.053363 | val_ms=0.051845 | lr=5.000000e-04
# epoch 087 | train_total=0.077030 | val_total=0.074834 | train_pix=0.057888 | val_pix=0.056162 | train_grad=0.056918 | val_grad=0.055945 | train_ms=0.053018 | val_ms=0.051403 | lr=5.000000e-04
# epoch 088 | train_total=0.076603 | val_total=0.074460 | train_pix=0.057539 | val_pix=0.055851 | train_grad=0.056934 | val_grad=0.056027 | train_ms=0.052619 | val_ms=0.051025 | lr=5.000000e-04
# epoch 089 | train_total=0.076263 | val_total=0.074425 | train_pix=0.057262 | val_pix=0.055797 | train_grad=0.056939 | val_grad=0.056080 | train_ms=0.052298 | val_ms=0.051082 | lr=5.000000e-04
# epoch 090 | train_total=0.075904 | val_total=0.073732 | train_pix=0.056970 | val_pix=0.055254 | train_grad=0.056943 | val_grad=0.056033 | train_ms=0.051964 | val_ms=0.050364 | lr=5.000000e-04
# epoch 091 | train_total=0.075513 | val_total=0.073640 | train_pix=0.056649 | val_pix=0.055192 | train_grad=0.056946 | val_grad=0.055964 | train_ms=0.051609 | val_ms=0.050268 | lr=5.000000e-04
# epoch 092 | train_total=0.075272 | val_total=0.073266 | train_pix=0.056453 | val_pix=0.054873 | train_grad=0.056946 | val_grad=0.056030 | train_ms=0.051386 | val_ms=0.049942 | lr=5.000000e-04
# epoch 093 | train_total=0.074978 | val_total=0.073210 | train_pix=0.056213 | val_pix=0.054816 | train_grad=0.056938 | val_grad=0.056062 | train_ms=0.051120 | val_ms=0.049924 | lr=5.000000e-04
# epoch 094 | train_total=0.074660 | val_total=0.072858 | train_pix=0.055952 | val_pix=0.054537 | train_grad=0.056942 | val_grad=0.056016 | train_ms=0.050834 | val_ms=0.049593 | lr=5.000000e-04
# epoch 095 | train_total=0.074480 | val_total=0.072611 | train_pix=0.055807 | val_pix=0.054343 | train_grad=0.056931 | val_grad=0.056003 | train_ms=0.050669 | val_ms=0.049337 | lr=5.000000e-04
# epoch 096 | train_total=0.074178 | val_total=0.072411 | train_pix=0.055558 | val_pix=0.054197 | train_grad=0.056932 | val_grad=0.055917 | train_ms=0.050398 | val_ms=0.049135 | lr=5.000000e-04
# epoch 097 | train_total=0.073936 | val_total=0.072264 | train_pix=0.055361 | val_pix=0.054063 | train_grad=0.056922 | val_grad=0.055992 | train_ms=0.050181 | val_ms=0.049012 | lr=5.000000e-04
# epoch 098 | train_total=0.073719 | val_total=0.071875 | train_pix=0.055185 | val_pix=0.053738 | train_grad=0.056916 | val_grad=0.055998 | train_ms=0.049985 | val_ms=0.048684 | lr=5.000000e-04
# epoch 099 | train_total=0.073515 | val_total=0.071697 | train_pix=0.055018 | val_pix=0.053616 | train_grad=0.056916 | val_grad=0.055892 | train_ms=0.049798 | val_ms=0.048485 | lr=5.000000e-04
# epoch 100 | train_total=0.073417 | val_total=0.071595 | train_pix=0.054940 | val_pix=0.053506 | train_grad=0.056913 | val_grad=0.055931 | train_ms=0.049701 | val_ms=0.048497 | lr=5.000000e-04
# epoch 101 | train_total=0.073044 | val_total=0.071447 | train_pix=0.054633 | val_pix=0.053418 | train_grad=0.056904 | val_grad=0.055998 | train_ms=0.049375 | val_ms=0.048151 | lr=5.000000e-04
# epoch 102 | train_total=0.072936 | val_total=0.071097 | train_pix=0.054546 | val_pix=0.053117 | train_grad=0.056904 | val_grad=0.055896 | train_ms=0.049269 | val_ms=0.047979 | lr=5.000000e-04
# epoch 103 | train_total=0.072721 | val_total=0.070852 | train_pix=0.054370 | val_pix=0.052900 | train_grad=0.056898 | val_grad=0.055973 | train_ms=0.049077 | val_ms=0.047780 | lr=5.000000e-04
# epoch 104 | train_total=0.072525 | val_total=0.070893 | train_pix=0.054211 | val_pix=0.052937 | train_grad=0.056897 | val_grad=0.055977 | train_ms=0.048898 | val_ms=0.047800 | lr=5.000000e-04
# epoch 105 | train_total=0.072306 | val_total=0.070799 | train_pix=0.054032 | val_pix=0.052852 | train_grad=0.056889 | val_grad=0.056011 | train_ms=0.048705 | val_ms=0.047727 | lr=5.000000e-04
# epoch 106 | train_total=0.072168 | val_total=0.070333 | train_pix=0.053920 | val_pix=0.052481 | train_grad=0.056891 | val_grad=0.055883 | train_ms=0.048574 | val_ms=0.047350 | lr=5.000000e-04
# epoch 107 | train_total=0.071961 | val_total=0.070674 | train_pix=0.053751 | val_pix=0.052803 | train_grad=0.056882 | val_grad=0.055900 | train_ms=0.048389 | val_ms=0.047429 | lr=5.000000e-04
# epoch 108 | train_total=0.071695 | val_total=0.070584 | train_pix=0.053533 | val_pix=0.052716 | train_grad=0.056878 | val_grad=0.055955 | train_ms=0.048152 | val_ms=0.047377 | lr=5.000000e-04
# epoch 109 | train_total=0.071623 | val_total=0.069904 | train_pix=0.053475 | val_pix=0.052142 | train_grad=0.056878 | val_grad=0.055921 | train_ms=0.048079 | val_ms=0.046869 | lr=5.000000e-04
# epoch 110 | train_total=0.071412 | val_total=0.070103 | train_pix=0.053303 | val_pix=0.052316 | train_grad=0.056874 | val_grad=0.055896 | train_ms=0.047891 | val_ms=0.047009 | lr=5.000000e-04
# epoch 111 | train_total=0.071257 | val_total=0.069749 | train_pix=0.053176 | val_pix=0.052023 | train_grad=0.056872 | val_grad=0.055914 | train_ms=0.047750 | val_ms=0.046696 | lr=5.000000e-04
# epoch 112 | train_total=0.071094 | val_total=0.070240 | train_pix=0.053042 | val_pix=0.052445 | train_grad=0.056872 | val_grad=0.055952 | train_ms=0.047601 | val_ms=0.047011 | lr=5.000000e-04
# epoch 113 | train_total=0.070957 | val_total=0.069547 | train_pix=0.052932 | val_pix=0.051855 | train_grad=0.056869 | val_grad=0.055868 | train_ms=0.047477 | val_ms=0.046564 | lr=5.000000e-04
# epoch 114 | train_total=0.070797 | val_total=0.069359 | train_pix=0.052801 | val_pix=0.051687 | train_grad=0.056862 | val_grad=0.055890 | train_ms=0.047334 | val_ms=0.046445 | lr=5.000000e-04
# epoch 115 | train_total=0.070595 | val_total=0.069207 | train_pix=0.052635 | val_pix=0.051568 | train_grad=0.056862 | val_grad=0.055927 | train_ms=0.047155 | val_ms=0.046251 | lr=5.000000e-04
# epoch 116 | train_total=0.070559 | val_total=0.069164 | train_pix=0.052607 | val_pix=0.051553 | train_grad=0.056865 | val_grad=0.055880 | train_ms=0.047115 | val_ms=0.046144 | lr=5.000000e-04
# epoch 117 | train_total=0.070388 | val_total=0.068908 | train_pix=0.052468 | val_pix=0.051314 | train_grad=0.056855 | val_grad=0.055898 | train_ms=0.046962 | val_ms=0.046046 | lr=5.000000e-04
# epoch 118 | train_total=0.070229 | val_total=0.068763 | train_pix=0.052336 | val_pix=0.051196 | train_grad=0.056856 | val_grad=0.055951 | train_ms=0.046821 | val_ms=0.045871 | lr=5.000000e-04
# epoch 119 | train_total=0.070151 | val_total=0.068776 | train_pix=0.052272 | val_pix=0.051221 | train_grad=0.056859 | val_grad=0.055831 | train_ms=0.046746 | val_ms=0.045900 | lr=5.000000e-04
# epoch 120 | train_total=0.069960 | val_total=0.068551 | train_pix=0.052117 | val_pix=0.051048 | train_grad=0.056853 | val_grad=0.055834 | train_ms=0.046578 | val_ms=0.045638 | lr=5.000000e-04
# epoch 121 | train_total=0.069916 | val_total=0.068697 | train_pix=0.052081 | val_pix=0.051173 | train_grad=0.056858 | val_grad=0.055901 | train_ms=0.046532 | val_ms=0.045694 | lr=5.000000e-04
# epoch 122 | train_total=0.069669 | val_total=0.068389 | train_pix=0.051879 | val_pix=0.050900 | train_grad=0.056847 | val_grad=0.055857 | train_ms=0.046317 | val_ms=0.045556 | lr=5.000000e-04
# epoch 123 | train_total=0.069696 | val_total=0.068323 | train_pix=0.051902 | val_pix=0.050844 | train_grad=0.056853 | val_grad=0.055854 | train_ms=0.046331 | val_ms=0.045505 | lr=5.000000e-04
# epoch 124 | train_total=0.069483 | val_total=0.068038 | train_pix=0.051727 | val_pix=0.050611 | train_grad=0.056846 | val_grad=0.055867 | train_ms=0.046146 | val_ms=0.045233 | lr=5.000000e-04
# epoch 125 | train_total=0.069299 | val_total=0.068135 | train_pix=0.051576 | val_pix=0.050690 | train_grad=0.056842 | val_grad=0.055815 | train_ms=0.045984 | val_ms=0.045364 | lr=5.000000e-04
# epoch 126 | train_total=0.069244 | val_total=0.067897 | train_pix=0.051531 | val_pix=0.050520 | train_grad=0.056839 | val_grad=0.055820 | train_ms=0.045934 | val_ms=0.045017 | lr=5.000000e-04
# epoch 127 | train_total=0.069132 | val_total=0.067892 | train_pix=0.051441 | val_pix=0.050509 | train_grad=0.056833 | val_grad=0.055874 | train_ms=0.045832 | val_ms=0.045009 | lr=5.000000e-04
# epoch 128 | train_total=0.069014 | val_total=0.067824 | train_pix=0.051344 | val_pix=0.050460 | train_grad=0.056836 | val_grad=0.055822 | train_ms=0.045725 | val_ms=0.044951 | lr=5.000000e-04
# epoch 129 | train_total=0.068942 | val_total=0.067625 | train_pix=0.051286 | val_pix=0.050271 | train_grad=0.056829 | val_grad=0.055875 | train_ms=0.045660 | val_ms=0.044865 | lr=5.000000e-04
# epoch 130 | train_total=0.068769 | val_total=0.067494 | train_pix=0.051143 | val_pix=0.050175 | train_grad=0.056831 | val_grad=0.055875 | train_ms=0.045508 | val_ms=0.044690 | lr=5.000000e-04
# epoch 131 | train_total=0.068740 | val_total=0.067324 | train_pix=0.051121 | val_pix=0.050035 | train_grad=0.056825 | val_grad=0.055806 | train_ms=0.045480 | val_ms=0.044591 | lr=5.000000e-04
# epoch 132 | train_total=0.068637 | val_total=0.067330 | train_pix=0.051037 | val_pix=0.050049 | train_grad=0.056824 | val_grad=0.055845 | train_ms=0.045383 | val_ms=0.044520 | lr=5.000000e-04
# epoch 133 | train_total=0.068530 | val_total=0.067426 | train_pix=0.050949 | val_pix=0.050115 | train_grad=0.056825 | val_grad=0.055848 | train_ms=0.045287 | val_ms=0.044673 | lr=5.000000e-04
# epoch 134 | train_total=0.068393 | val_total=0.067334 | train_pix=0.050837 | val_pix=0.050055 | train_grad=0.056818 | val_grad=0.055856 | train_ms=0.045167 | val_ms=0.044504 | lr=5.000000e-04
# epoch 135 | train_total=0.068386 | val_total=0.067153 | train_pix=0.050831 | val_pix=0.049888 | train_grad=0.056823 | val_grad=0.055871 | train_ms=0.045155 | val_ms=0.044420 | lr=5.000000e-04
# epoch 136 | train_total=0.068195 | val_total=0.067057 | train_pix=0.050676 | val_pix=0.049818 | train_grad=0.056813 | val_grad=0.055885 | train_ms=0.044988 | val_ms=0.044281 | lr=5.000000e-04
# epoch 137 | train_total=0.068136 | val_total=0.066977 | train_pix=0.050628 | val_pix=0.049754 | train_grad=0.056814 | val_grad=0.055843 | train_ms=0.044933 | val_ms=0.044230 | lr=5.000000e-04
# epoch 138 | train_total=0.068049 | val_total=0.066734 | train_pix=0.050556 | val_pix=0.049554 | train_grad=0.056815 | val_grad=0.055849 | train_ms=0.044853 | val_ms=0.044015 | lr=5.000000e-04
# epoch 139 | train_total=0.067963 | val_total=0.066783 | train_pix=0.050487 | val_pix=0.049613 | train_grad=0.056808 | val_grad=0.055824 | train_ms=0.044776 | val_ms=0.043982 | lr=5.000000e-04
# epoch 140 | train_total=0.067857 | val_total=0.066563 | train_pix=0.050400 | val_pix=0.049411 | train_grad=0.056810 | val_grad=0.055816 | train_ms=0.044680 | val_ms=0.043897 | lr=5.000000e-04
# epoch 141 | train_total=0.067783 | val_total=0.066617 | train_pix=0.050339 | val_pix=0.049469 | train_grad=0.056808 | val_grad=0.055746 | train_ms=0.044612 | val_ms=0.043932 | lr=5.000000e-04
# epoch 142 | train_total=0.067656 | val_total=0.066710 | train_pix=0.050236 | val_pix=0.049530 | train_grad=0.056806 | val_grad=0.055854 | train_ms=0.044498 | val_ms=0.044011 | lr=5.000000e-04
# epoch 143 | train_total=0.067578 | val_total=0.066575 | train_pix=0.050172 | val_pix=0.049433 | train_grad=0.056800 | val_grad=0.055805 | train_ms=0.044431 | val_ms=0.043857 | lr=5.000000e-04
# epoch 144 | train_total=0.067573 | val_total=0.066449 | train_pix=0.050168 | val_pix=0.049323 | train_grad=0.056807 | val_grad=0.055833 | train_ms=0.044420 | val_ms=0.043754 | lr=5.000000e-04
# epoch 145 | train_total=0.067420 | val_total=0.066800 | train_pix=0.050043 | val_pix=0.049586 | train_grad=0.056796 | val_grad=0.055838 | train_ms=0.044286 | val_ms=0.044194 | lr=5.000000e-04
# epoch 146 | train_total=0.067371 | val_total=0.066348 | train_pix=0.050003 | val_pix=0.049242 | train_grad=0.056797 | val_grad=0.055774 | train_ms=0.044239 | val_ms=0.043703 | lr=5.000000e-04
# epoch 147 | train_total=0.067204 | val_total=0.066198 | train_pix=0.049867 | val_pix=0.049109 | train_grad=0.056791 | val_grad=0.055867 | train_ms=0.044095 | val_ms=0.043546 | lr=5.000000e-04
# epoch 148 | train_total=0.067186 | val_total=0.066181 | train_pix=0.049852 | val_pix=0.049103 | train_grad=0.056798 | val_grad=0.055826 | train_ms=0.044070 | val_ms=0.043520 | lr=5.000000e-04
# epoch 149 | train_total=0.067113 | val_total=0.066057 | train_pix=0.049794 | val_pix=0.049019 | train_grad=0.056788 | val_grad=0.055769 | train_ms=0.044008 | val_ms=0.043363 | lr=5.000000e-04
# epoch 150 | train_total=0.066960 | val_total=0.066096 | train_pix=0.049668 | val_pix=0.049023 | train_grad=0.056785 | val_grad=0.055834 | train_ms=0.043874 | val_ms=0.043490 | lr=5.000000e-04
# epoch 151 | train_total=0.067001 | val_total=0.065993 | train_pix=0.049702 | val_pix=0.048958 | train_grad=0.056786 | val_grad=0.055823 | train_ms=0.043905 | val_ms=0.043308 | lr=5.000000e-04
# epoch 152 | train_total=0.066857 | val_total=0.065936 | train_pix=0.049584 | val_pix=0.048906 | train_grad=0.056783 | val_grad=0.055845 | train_ms=0.043777 | val_ms=0.043267 | lr=5.000000e-04
# epoch 153 | train_total=0.066737 | val_total=0.065853 | train_pix=0.049486 | val_pix=0.048824 | train_grad=0.056771 | val_grad=0.055803 | train_ms=0.043674 | val_ms=0.043293 | lr=5.000000e-04
# epoch 154 | train_total=0.066731 | val_total=0.065733 | train_pix=0.049481 | val_pix=0.048740 | train_grad=0.056775 | val_grad=0.055788 | train_ms=0.043665 | val_ms=0.043120 | lr=5.000000e-04
# epoch 155 | train_total=0.066674 | val_total=0.065992 | train_pix=0.049435 | val_pix=0.048927 | train_grad=0.056772 | val_grad=0.055880 | train_ms=0.043612 | val_ms=0.043420 | lr=5.000000e-04
# epoch 156 | train_total=0.066605 | val_total=0.065393 | train_pix=0.049379 | val_pix=0.048459 | train_grad=0.056772 | val_grad=0.055751 | train_ms=0.043549 | val_ms=0.042859 | lr=5.000000e-04
# epoch 157 | train_total=0.066459 | val_total=0.065595 | train_pix=0.049260 | val_pix=0.048629 | train_grad=0.056766 | val_grad=0.055828 | train_ms=0.043422 | val_ms=0.042960 | lr=5.000000e-04
# epoch 158 | train_total=0.066467 | val_total=0.065357 | train_pix=0.049267 | val_pix=0.048445 | train_grad=0.056772 | val_grad=0.055728 | train_ms=0.043423 | val_ms=0.042765 | lr=5.000000e-04
# epoch 159 | train_total=0.066348 | val_total=0.065482 | train_pix=0.049170 | val_pix=0.048522 | train_grad=0.056757 | val_grad=0.055862 | train_ms=0.043323 | val_ms=0.042906 | lr=5.000000e-04
# epoch 160 | train_total=0.066315 | val_total=0.065380 | train_pix=0.049143 | val_pix=0.048456 | train_grad=0.056764 | val_grad=0.055771 | train_ms=0.043289 | val_ms=0.042792 | lr=5.000000e-04
# epoch 161 | train_total=0.066260 | val_total=0.065189 | train_pix=0.049099 | val_pix=0.048311 | train_grad=0.056755 | val_grad=0.055696 | train_ms=0.043239 | val_ms=0.042618 | lr=5.000000e-04
# epoch 162 | train_total=0.066119 | val_total=0.065268 | train_pix=0.048984 | val_pix=0.048355 | train_grad=0.056749 | val_grad=0.055772 | train_ms=0.043116 | val_ms=0.042735 | lr=5.000000e-04
# epoch 163 | train_total=0.066102 | val_total=0.065249 | train_pix=0.048970 | val_pix=0.048358 | train_grad=0.056747 | val_grad=0.055739 | train_ms=0.043099 | val_ms=0.042653 | lr=5.000000e-04
# epoch 164 | train_total=0.066049 | val_total=0.065394 | train_pix=0.048928 | val_pix=0.048462 | train_grad=0.056739 | val_grad=0.055770 | train_ms=0.043052 | val_ms=0.042830 | lr=5.000000e-04
# epoch 165 | train_total=0.066024 | val_total=0.065172 | train_pix=0.048907 | val_pix=0.048299 | train_grad=0.056745 | val_grad=0.055819 | train_ms=0.043026 | val_ms=0.042503 | lr=5.000000e-04
# epoch 166 | train_total=0.065905 | val_total=0.065119 | train_pix=0.048809 | val_pix=0.048224 | train_grad=0.056738 | val_grad=0.055836 | train_ms=0.042924 | val_ms=0.042597 | lr=5.000000e-04
# epoch 167 | train_total=0.065821 | val_total=0.064810 | train_pix=0.048741 | val_pix=0.047986 | train_grad=0.056731 | val_grad=0.055786 | train_ms=0.042850 | val_ms=0.042283 | lr=5.000000e-04
# epoch 168 | train_total=0.065842 | val_total=0.065435 | train_pix=0.048759 | val_pix=0.048526 | train_grad=0.056734 | val_grad=0.055829 | train_ms=0.042865 | val_ms=0.042670 | lr=5.000000e-04
# epoch 169 | train_total=0.065762 | val_total=0.064964 | train_pix=0.048694 | val_pix=0.048126 | train_grad=0.056729 | val_grad=0.055775 | train_ms=0.042794 | val_ms=0.042360 | lr=5.000000e-04
# epoch 170 | train_total=0.065696 | val_total=0.064892 | train_pix=0.048641 | val_pix=0.048042 | train_grad=0.056727 | val_grad=0.055834 | train_ms=0.042734 | val_ms=0.042377 | lr=5.000000e-04
# epoch 171 | train_total=0.065585 | val_total=0.064711 | train_pix=0.048550 | val_pix=0.047918 | train_grad=0.056716 | val_grad=0.055734 | train_ms=0.042639 | val_ms=0.042166 | lr=5.000000e-04
# epoch 172 | train_total=0.065655 | val_total=0.064867 | train_pix=0.048608 | val_pix=0.048050 | train_grad=0.056717 | val_grad=0.055820 | train_ms=0.042696 | val_ms=0.042224 | lr=5.000000e-04
# epoch 173 | train_total=0.065521 | val_total=0.064781 | train_pix=0.048498 | val_pix=0.047962 | train_grad=0.056709 | val_grad=0.055820 | train_ms=0.042581 | val_ms=0.042228 | lr=5.000000e-04
# epoch 174 | train_total=0.065409 | val_total=0.064703 | train_pix=0.048407 | val_pix=0.047890 | train_grad=0.056705 | val_grad=0.055739 | train_ms=0.042483 | val_ms=0.042258 | lr=5.000000e-04
# epoch 175 | train_total=0.065441 | val_total=0.064568 | train_pix=0.048433 | val_pix=0.047799 | train_grad=0.056705 | val_grad=0.055692 | train_ms=0.042509 | val_ms=0.042075 | lr=5.000000e-04
# epoch 176 | train_total=0.065333 | val_total=0.064458 | train_pix=0.048346 | val_pix=0.047716 | train_grad=0.056694 | val_grad=0.055737 | train_ms=0.042415 | val_ms=0.041909 | lr=5.000000e-04
# epoch 177 | train_total=0.065300 | val_total=0.064461 | train_pix=0.048319 | val_pix=0.047700 | train_grad=0.056690 | val_grad=0.055712 | train_ms=0.042386 | val_ms=0.042020 | lr=5.000000e-04
# epoch 178 | train_total=0.065274 | val_total=0.064556 | train_pix=0.048298 | val_pix=0.047795 | train_grad=0.056691 | val_grad=0.055725 | train_ms=0.042362 | val_ms=0.042010 | lr=5.000000e-04
# epoch 179 | train_total=0.065193 | val_total=0.064522 | train_pix=0.048232 | val_pix=0.047756 | train_grad=0.056682 | val_grad=0.055743 | train_ms=0.042293 | val_ms=0.042022 | lr=5.000000e-04
# epoch 180 | train_total=0.065100 | val_total=0.064208 | train_pix=0.048157 | val_pix=0.047493 | train_grad=0.056672 | val_grad=0.055751 | train_ms=0.042211 | val_ms=0.041763 | lr=5.000000e-04
# epoch 181 | train_total=0.065031 | val_total=0.064547 | train_pix=0.048100 | val_pix=0.047754 | train_grad=0.056670 | val_grad=0.055838 | train_ms=0.042151 | val_ms=0.042086 | lr=5.000000e-04
# epoch 182 | train_total=0.064988 | val_total=0.064646 | train_pix=0.048065 | val_pix=0.047881 | train_grad=0.056664 | val_grad=0.055701 | train_ms=0.042115 | val_ms=0.042050 | lr=5.000000e-04
# epoch 183 | train_total=0.064992 | val_total=0.064275 | train_pix=0.048069 | val_pix=0.047558 | train_grad=0.056667 | val_grad=0.055687 | train_ms=0.042115 | val_ms=0.041820 | lr=5.000000e-04
# epoch 184 | train_total=0.064937 | val_total=0.064149 | train_pix=0.048025 | val_pix=0.047441 | train_grad=0.056655 | val_grad=0.055746 | train_ms=0.042070 | val_ms=0.041730 | lr=5.000000e-04
# epoch 185 | train_total=0.064889 | val_total=0.064217 | train_pix=0.047986 | val_pix=0.047501 | train_grad=0.056653 | val_grad=0.055705 | train_ms=0.042027 | val_ms=0.041804 | lr=5.000000e-04
# epoch 186 | train_total=0.064853 | val_total=0.064101 | train_pix=0.047957 | val_pix=0.047415 | train_grad=0.056650 | val_grad=0.055740 | train_ms=0.041993 | val_ms=0.041626 | lr=5.000000e-04
# epoch 187 | train_total=0.064814 | val_total=0.064072 | train_pix=0.047925 | val_pix=0.047392 | train_grad=0.056648 | val_grad=0.055736 | train_ms=0.041959 | val_ms=0.041599 | lr=5.000000e-04
# epoch 188 | train_total=0.064799 | val_total=0.063984 | train_pix=0.047914 | val_pix=0.047328 | train_grad=0.056637 | val_grad=0.055694 | train_ms=0.041947 | val_ms=0.041512 | lr=5.000000e-04
# epoch 189 | train_total=0.064651 | val_total=0.063947 | train_pix=0.047792 | val_pix=0.047293 | train_grad=0.056631 | val_grad=0.055720 | train_ms=0.041819 | val_ms=0.041482 | lr=5.000000e-04
# epoch 190 | train_total=0.064623 | val_total=0.063780 | train_pix=0.047770 | val_pix=0.047151 | train_grad=0.056626 | val_grad=0.055707 | train_ms=0.041794 | val_ms=0.041366 | lr=5.000000e-04
# epoch 191 | train_total=0.064578 | val_total=0.064479 | train_pix=0.047734 | val_pix=0.047758 | train_grad=0.056616 | val_grad=0.055696 | train_ms=0.041756 | val_ms=0.041833 | lr=5.000000e-04
# epoch 192 | train_total=0.064542 | val_total=0.063719 | train_pix=0.047705 | val_pix=0.047110 | train_grad=0.056616 | val_grad=0.055642 | train_ms=0.041723 | val_ms=0.041316 | lr=5.000000e-04
# epoch 193 | train_total=0.064499 | val_total=0.063947 | train_pix=0.047670 | val_pix=0.047281 | train_grad=0.056612 | val_grad=0.055714 | train_ms=0.041686 | val_ms=0.041544 | lr=5.000000e-04
# epoch 194 | train_total=0.064402 | val_total=0.063726 | train_pix=0.047591 | val_pix=0.047112 | train_grad=0.056602 | val_grad=0.055685 | train_ms=0.041605 | val_ms=0.041310 | lr=5.000000e-04
# epoch 195 | train_total=0.064455 | val_total=0.063845 | train_pix=0.047635 | val_pix=0.047207 | train_grad=0.056602 | val_grad=0.055722 | train_ms=0.041647 | val_ms=0.041397 | lr=5.000000e-04
# epoch 196 | train_total=0.064393 | val_total=0.063604 | train_pix=0.047585 | val_pix=0.047029 | train_grad=0.056596 | val_grad=0.055642 | train_ms=0.041593 | val_ms=0.041145 | lr=5.000000e-04
# epoch 197 | train_total=0.064305 | val_total=0.063546 | train_pix=0.047513 | val_pix=0.046956 | train_grad=0.056591 | val_grad=0.055639 | train_ms=0.041518 | val_ms=0.041221 | lr=5.000000e-04
# epoch 198 | train_total=0.064271 | val_total=0.063919 | train_pix=0.047486 | val_pix=0.047290 | train_grad=0.056582 | val_grad=0.055655 | train_ms=0.041490 | val_ms=0.041407 | lr=5.000000e-04
# epoch 199 | train_total=0.064310 | val_total=0.063586 | train_pix=0.047519 | val_pix=0.046999 | train_grad=0.056583 | val_grad=0.055634 | train_ms=0.041522 | val_ms=0.041207 | lr=5.000000e-04
# epoch 200 | train_total=0.064184 | val_total=0.063612 | train_pix=0.047415 | val_pix=0.047021 | train_grad=0.056574 | val_grad=0.055637 | train_ms=0.041413 | val_ms=0.041226 | lr=5.000000e-04
# training time sec: 1550.3236689567566
# best_epoch: 197
# best_val: 0.06354625341296195

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

ax[0].plot([x["total"] for x in train_history], label="train_total")
ax[0].plot([x["total"] for x in val_history], label="val_total")
ax[0].plot([x["pixel"] for x in train_history], label="train_pixel", alpha=0.6)
ax[0].plot([x["pixel"] for x in val_history], label="val_pixel", alpha=0.6)
ax[0].set_xlabel("epoch")
ax[0].set_ylabel("loss")
ax[0].set_title("Composite loss curves")
ax[0].legend()

ax[1].plot(lr_history)
ax[1].set_xlabel("epoch")
ax[1].set_ylabel("lr")
ax[1].set_title("LR schedule")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Best checkpoint evaluation

# %%
best_ckpt = torch.load(best_ckpt_path, map_location=device)
model.load_state_dict(best_ckpt["model_state_dict"])
model.eval()

train_metrics = evaluate_dataset(model, ds_train, device, coords_device, stats["c_min"], stats["c_max"])
val_metrics = evaluate_dataset(model, ds_val, device, coords_device, stats["c_min"], stats["c_max"])
test_metrics = evaluate_dataset(model, ds_test, device, coords_device, stats["c_min"], stats["c_max"])

train_summary = summarize_metrics(train_metrics)
val_summary = summarize_metrics(val_metrics)
test_summary = summarize_metrics(test_metrics)

print("TRAIN SUMMARY")
print(json.dumps(train_summary, ensure_ascii=False, indent=2))

print("\nVAL SUMMARY")
print(json.dumps(val_summary, ensure_ascii=False, indent=2))

print("\nTEST SUMMARY")
print(json.dumps(test_summary, ensure_ascii=False, indent=2))
# Out:
# TRAIN SUMMARY
# {
#   "mse_mean": 159.3624703370371,
#   "mse_std": 75.36895045126332,
#   "rmse_mean": 12.251190168934484,
#   "rmse_std": 3.0448004435943195,
#   "relative_l2_mean": 0.008210623962954888,
#   "relative_l2_std": 0.0020403519174531167,
#   "psnr_mean": 24.287046778081923,
#   "psnr_std": 2.2696947525884923
# }
#
# VAL SUMMARY
# {
#   "mse_mean": 159.37799271392822,
#   "mse_std": 73.96919681993143,
#   "rmse_mean": 12.269159794330596,
#   "rmse_std": 2.974173923416982,
#   "relative_l2_mean": 0.008222875431645661,
#   "relative_l2_std": 0.0019904979066895697,
#   "psnr_mean": 24.25881332756149,
#   "psnr_std": 2.2044672068885927
# }
#
# TEST SUMMARY
# {
#   "mse_mean": 233.61163061618805,
#   "mse_std": 123.93340030961187,
#   "rmse_mean": 14.714542010426522,
#   "rmse_std": 4.13447504708008,
#   "relative_l2_mean": 0.00986216303834226,
#   "relative_l2_std": 0.0027702355207180943,
#   "psnr_mean": 22.777138924701283,
#   "psnr_std": 2.5770180062280255
# }

# %% [markdown]
# ## 11. Visualization

# %%
@torch.no_grad()
def show_prediction(model, dataset, idx, device, coords_device, c_min, c_max):
    x, c, meta = dataset[idx]
    pred = model(x.unsqueeze(0).to(device), coords_device)[0, 0].cpu().numpy()
    pred = np.clip(pred, -1.0, 1.0)
    target = c[0].numpy()

    pred_phys = denorm_c_from_minus1_1(pred, c_min, c_max)
    target_phys = denorm_c_from_minus1_1(target, c_min, c_max)
    err = np.abs(pred_phys - target_phys)

    fig, ax = plt.subplots(1, 3, figsize=(15, 4))

    im0 = ax[0].imshow(target_phys, origin="lower")
    ax[0].set_title(f"target | idx={idx}")
    plt.colorbar(im0, ax=ax[0])

    im1 = ax[1].imshow(pred_phys, origin="lower")
    ax[1].set_title("DeepONet v3 prediction")
    plt.colorbar(im1, ax=ax[1])

    im2 = ax[2].imshow(err, origin="lower")
    ax[2].set_title("|pred-target|")
    plt.colorbar(im2, ax=ax[2])

    plt.tight_layout()
    plt.show()
    print(meta["path"])

# %%
for idx in [0, 1, 2]:
    show_prediction(model, ds_test, idx, device, coords_device, stats["c_min"], stats["c_max"])
# Out:
# /workspace/usct_dataset_v2/test/sample_00000.npz
# /workspace/usct_dataset_v2/test/sample_00001.npz
# /workspace/usct_dataset_v2/test/sample_00002.npz

# %% [markdown]
# ## 12. Save artifacts

# %%
with open(RUN_DIR / "config.json", "w", encoding="utf-8") as f:
    json.dump(
        {
            "config": CFG,
            "stats": stats,
            "S": int(S),
            "R": int(R),
            "H": int(H),
            "W": int(W),
            "dx": [float(v) for v in dx],
            "freq_hz": float(freq_hz),
            "best_epoch": int(best_epoch),
            "best_val": float(best_val),
        },
        f,
        ensure_ascii=False,
        indent=2,
    )

with open(RUN_DIR / "train_summary.json", "w", encoding="utf-8") as f:
    json.dump(train_summary, f, ensure_ascii=False, indent=2)

with open(RUN_DIR / "val_summary.json", "w", encoding="utf-8") as f:
    json.dump(val_summary, f, ensure_ascii=False, indent=2)

with open(RUN_DIR / "test_summary.json", "w", encoding="utf-8") as f:
    json.dump(test_summary, f, ensure_ascii=False, indent=2)

with open(RUN_DIR / "train_metrics.json", "w", encoding="utf-8") as f:
    json.dump(train_metrics, f, ensure_ascii=False, indent=2)

with open(RUN_DIR / "val_metrics.json", "w", encoding="utf-8") as f:
    json.dump(val_metrics, f, ensure_ascii=False, indent=2)

with open(RUN_DIR / "test_metrics.json", "w", encoding="utf-8") as f:
    json.dump(test_metrics, f, ensure_ascii=False, indent=2)

np.savez_compressed(
    RUN_DIR / "loss_history.npz",
    train_total=np.array([x["total"] for x in train_history], dtype=np.float32),
    val_total=np.array([x["total"] for x in val_history], dtype=np.float32),
    train_pixel=np.array([x["pixel"] for x in train_history], dtype=np.float32),
    val_pixel=np.array([x["pixel"] for x in val_history], dtype=np.float32),
    train_grad=np.array([x["grad"] for x in train_history], dtype=np.float32),
    val_grad=np.array([x["grad"] for x in val_history], dtype=np.float32),
    train_ms=np.array([x["multiscale"] for x in train_history], dtype=np.float32),
    val_ms=np.array([x["multiscale"] for x in val_history], dtype=np.float32),
    lr=np.array(lr_history, dtype=np.float32),
)

print("saved to:", RUN_DIR)
# Out:
# saved to: /workspace/reference_points/deeponet_v3_sharp
